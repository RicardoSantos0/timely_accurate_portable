# %% [markdown]
# ## Notebook 2.1. Understanding and Preprocessing of Moodle Logs
#
# For all intents and purposes, this should be considered as the first real notebook that is part of the thesis work. In it, we will take the original student log file and perform the necessary manipulations to ensure that we have a dataset with the potential to be useful.
#
# #### 1. A Small overview of the logs and each column
#
# The presented logs report to interactions with the Moodle LMS:
#
#     - Each interaction with the LMS is recorded sequentially:
#         When is the action performed,
#         What is the nature of the interaction,
#         Where is the actor when the action is performed,
#         Who performed the interaction,
#         In the context of which course page,
#         What is the specific link,
#
#     - Each user is uniquely identified by the userID,
#     - Each course is uniquely identified by the courseID,
#     - Each specific interaction is recorded -> action performed and clicked url,
#     - Each click is timestamped,
#     - The actor's IP is recorded,
#
# A brief description of each column follows:
#
# ##### id
# A sequentilly numbered unique identifier interactions,
#
# ##### time
# A float number representation of the timestamp of the event,
#
# ##### userid
# Unique numerical identifier of user -> be it student, faculty or other,
#
# ##### ip
# ip adress used by the user when interactiong with the LMS system,
#
# ##### course
# Unique numerical identifier of a course,
#
# ##### cmid
# meaning unclear at the moment - to check with other Moodle Sources,
#
# ##### action
# categorization of nature of the interaction
#
# ##### url
# link user clicked on
#
# ##### info
# additional descriptors added by the user
#
# #### 2. We'll start this notebook by importing all relevant packages and data
#
# All data is stored in the csv files that were exported in the previous notebook.
#
# In order to minimize unecessary steps, as we import these csv files we will immediatly remove, from each dataset:
# 1. The first unnamed column,
# 2. All columns that are entirely made of missing values - we have detected some.
# 3. All numerical columns that are immediatly recognied as categorical (or likely to be categorical values) are also immediatly declared as categoricals - this does not mean that, upon further assessment, other features may be converted to objects,
# 4. All features that display no null values and have a single value are promptly removed as well,
# 5. No preprocessing of time related features is performed at this stage - namely because the features realted with time may require further assessment.

# %%
#import libs
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %%
#loading student log data 
student_logs = pd.read_csv('../Data/R_Gonz_data_log.csv', 
                           dtype = {
                                   'id': object,
                                   'itemid': object,
                                   'userid': object,
                                   'course': object,
                                   'cmid': object,
                                   },).drop('Unnamed: 0', axis = 1).dropna(how = 'all', axis = 1) #logs

#after checking, we note that time and stime report to the same date and differ in 1 hour, hence, we will only keep the time column
#additionally, we will make the immediate conversion of time
student_logs['time'] = pd.to_datetime(student_logs['time'], unit = 's', errors = 'coerce')
student_logs.drop('stime', axis = 1, inplace = True)

# %% [markdown]
# ### Taking a preliminary look at the logs

# %%
student_logs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47097824 entries, 0 to 47097823
# Data columns (total 10 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   id      object
#  1   time    datetime64[ns]
#  2   userid  object
#  3   ip      object
#  4   course  object
#  5   module  object
#  6   cmid    object
#  7   action  object
#  8   url     object
#  9   info    object
# dtypes: datetime64[ns](1), object(9)
# memory usage: 3.5+ GB

# %%
student_logs.describe(include ='all', datetime_is_numeric = True).T
# Out:
#            count    unique            top      freq  \
# id      47097824  47097824            1.0         1
# time    47097824       NaN            NaN       NaN
# userid  47097824     30517            0.0   3219653
# ip      47097824    161783      127.0.0.1  30508698
# course  47097824      5112            1.0  17715596
# module  47097824        39         course  17937931
# cmid    47097824    167235            0.0  34846344
# action  47097824       157           view  27239500
# url     47070765    754343  view.php?id=1   6303588
# info    42907847    693729              1   6306585
#
#                                 mean                 min  \
# id                               NaT                 NaT
# time   2015-01-20 08:00:31.016559872 2014-06-05 17:09:07
# userid                           NaT                 NaT
# ip                               NaT                 NaT
# course                           NaT                 NaT
# module                           NaT                 NaT
# cmid                             NaT                 NaT
# action                           NaT                 NaT
# url                              NaT                 NaT
# info                             NaT                 NaT
#
#                                  25%                 50%                 75%  \
# id                               NaT                 NaT                 NaT
# time   2014-11-10 12:51:08.750000128 2015-01-17 20:12:12 2015-03-27 22:43:11
# userid                           NaT                 NaT                 NaT
# ip                               NaT                 NaT                 NaT
# course                           NaT                 NaT                 NaT
# module                           NaT                 NaT                 NaT
# cmid                             NaT                 NaT                 NaT
# action                           NaT                 NaT                 NaT
# url                              NaT                 NaT                 NaT
# info                             NaT                 NaT                 NaT
#
#                        max
# id                     NaT
# time   2015-07-31 03:14:09
# userid                 NaT
# ip                     NaT
# course                 NaT
# module                 NaT
# cmid                   NaT
# action                 NaT
# url                    NaT
# info                   NaT

# %%
student_logs
# Out:
#                   id                time userid         ip  course  module  \
# 0                1.0 2014-06-05 17:09:07    2.0  127.0.0.1     1.0    user
# 1                2.0 2014-06-05 17:14:48    2.0  127.0.0.1     1.0    user
# 2                3.0 2014-06-05 17:14:48    2.0  127.0.0.1     1.0    user
# 3                4.0 2014-06-05 17:16:13    2.0  127.0.0.1     1.0  course
# 4                5.0 2014-06-06 07:37:19    2.0  127.0.0.1     1.0    user
# ...              ...                 ...    ...        ...     ...     ...
# 47097819  47116816.0 2015-07-31 03:00:59    0.0  127.0.0.1     1.0    user
# 47097820  47116817.0 2015-07-31 03:00:59    0.0  127.0.0.1     1.0    user
# 47097821  47116818.0 2015-07-31 03:00:59    0.0  127.0.0.1     1.0    user
# 47097822  47116819.0 2015-07-31 03:14:08    0.0  127.0.0.1   635.0    role
# 47097823  47116820.0 2015-07-31 03:14:09    0.0  127.0.0.1  2006.0    role
#
#          cmid    action                                              url  \
# 0         0.0     login                           view.php?id=2&course=1
# 1         0.0    update                                    view.php?id=2
# 2         0.0    update                                    view.php?id=2
# 3         0.0      view                                    view.php?id=1
# 4         0.0     login                           view.php?id=2&course=1
# ...       ...       ...                                              ...
# 47097819  0.0       add                               /view.php?id=81854
# 47097820  0.0       add                               /view.php?id=81855
# 47097821  0.0       add                               /view.php?id=81856
# 47097822  0.0  unassign  admin/roles/assign.php?contextid=24578&roleid=5
# 47097823  0.0  unassign  admin/roles/assign.php?contextid=97570&roleid=5
#
#                           info
# 0                            2
# 1                          NaN
# 2                          NaN
# 3                            1
# 4                            2
# ...                        ...
# 47097819    Cathleen Scheurich
# 47097820         Sara Gil Díez
# 47097821  Eduardo García Bermo
# 47097822            Estudiante
# 47097823            Estudiante
#
# [47097824 rows x 10 columns]

# %%
#use this cell to write any additional piece of code that may be required

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(student_logs['action'].value_counts())
# Out:
# view                                   27239500
# login                                   8072673
# update                                  7215196
# view all                                 939957
# view forum                               564309
# view discussion                          365713
# continue attempt                         356493
# assign                                   245712
# view submit assignment form              195072
# submit                                   165472
# view submission grading table            156948
# add                                      155418
# review                                   136012
# view summary                             113996
# view section                             111292
# grade submission                          97000
# attempt                                   88926
# view grading form                         88844
# close attempt                             84805
# update mod                                65240
# add mod                                   62133
# write                                     43607
# delete mod                                42274
# editquestions                             40187
# view report                               40129
# recent                                    37403
# view forums                               37326
# report                                    27020
# unassign                                  24896
# edit                                      19198
# add discussion                            18845
# view mailbox                              17791
# view confirm submit assignment form       16997
# view edit                                 16396
# submit for grading                        15678
# report log                                14416
# editsection                               13718
# user report                               10611
# manualgrade                               10289
# submission statement accepted              9612
# add post                                   9417
# view submission                            6873
# choose                                     6867
# save report                                6201
# add contact                                6114
# launch                                     5550
# edit report                                4583
# update post                                4324
# preview                                    3461
# mailer                                     3419
# add entry                                  3217
# download all submissions                   3203
# pre-view                                   3162
# message saved                              3018
# error                                      3001
# message sent                               2984
# lock submission                            2640
# map                                        2562
# comments                                   2256
# grant extension                            2227
# add assessment                             1961
# history                                    1888
# choose again                               1806
# report outline                             1684
# add category                               1438
# add item                                   1332
# update switch phase                        1323
# subscribe                                  1299
# view entry                                 1294
# view subscribers                           1178
# move                                       1167
# remove contact                             1107
# add page                                   1051
# files                                       998
# logout                                      957
# delete attempt                              918
# new                                         903
# report participation                        855
# delete                                      854
# save                                        776
# update entry                                755
# view chapter                                735
# update assessment                           719
# view example                                693
# delete discussion                           637
# add submission                              620
# delete entry                                520
# search                                      473
# block contact                               431
# report live                                 398
# revert submission to draft                  361
# unsubscribe                                 346
# approve entry                               266
# usage report                                261
# view feedback                               259
# comment                                     218
# submissioncopied                            212
# update submission                           210
# unblock contact                             191
# delete post                                 162
# diff                                        154
# start                                       153
# subscribeall                                142
# edit override                               133
# admin                                       133
# add example                                 133
# add reference assessment                    129
# edit post                                   123
# unlock submission                           122
# delete category                             112
# add example assessment                      102
# update reference assessment                 101
# save grading feedback                        78
# templates view                               67
# update category                              65
# mark read                                    65
# add comment                                  57
# unsubscribeall                               42
# view grade                                   36
# add chapter                                  35
# fields update                                32
# label created                                31
# fields add                                   28
# stop tracking                                27
# update chapter                               24
# userreport                                   23
# update example assessment                    22
# record delete                                19
# start tracking                               19
# end                                          17
# restore                                      16
# templates saved                              16
# update example                               16
# message updated                              13
# userreporttracks                             11
# add episode                                  10
# update grade                                  8
# move discussion                               8
# edit all                                      8
# delete override                               7
# update clear assessments                      7
# userreportinteractions                        5
# exportimscp                                   4
# update clear aggregated grades                4
# fields delete                                 4
# print                                         3
# tool capability                               3
# reset                                         3
# overridelocks                                 2
# mail digest error                             2
# approve episode                               2
# report questioninstances                      2
# update episode                                2
# reveal identities                             2
# prune post                                    1
# disapprove entry                              1
# print chapter                                 1
# Name: action, dtype: int64

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(student_logs['module'].value_counts())
# Out:
# course             17937931
# user               11987854
# resource            6982386
# grade               4032330
# assign              2119826
# quiz                1253218
# forum               1015649
# folder               411360
# url                  324349
# role                 270615
# page                 219949
# imscp                 71928
# label                 71295
# book                  60562
# message               51455
# choice                50348
# glossary              42067
# wiki                  37930
# workshop              31684
# questionnaire         29937
# jmail                 23837
# calendar              22306
# scorm                 11838
# bigbluebuttonbn       11130
# oublog                 6138
# notes                  4662
# data                   3691
# library                3419
# login                  3001
# recordingsbn           1378
# category               1270
# bookmark                897
# lesson                  658
# pcast                   470
# nanogong                349
# blog                     49
# discussion               44
# exaport                   9
# admin                     5
# Name: module, dtype: int64

# %%
student_logs[student_logs['module'] == 'assign'].describe(include ='all', datetime_is_numeric = True).T
# Out:
#           count   unique                                            top  \
# id      2119826  2119826                                         1632.0
# time    2119826      NaN                                            NaN
# userid  2119826    18339                                         2579.0
# ip      2119826    58390                                      127.0.0.1
# course  2119826     1512                                         3572.0
# module  2119826        1                                         assign
# cmid    2119826     9511                                            0.0
# action  2119826       22                                           view
# url     2119826     9511                       index.php?id=$course->id
# info    2066296    87360  Ver página de estado de las entregas propios.
#
#            freq                          mean                 min  \
# id            1                           NaT                 NaT
# time        NaN 2015-01-20 17:35:14.829150208 2014-07-01 13:09:38
# userid     8233                           NaT                 NaT
# ip      1221557                           NaT                 NaT
# course    72754                           NaT                 NaT
# module  2119826                           NaT                 NaT
# cmid      53530                           NaT                 NaT
# action  1297763                           NaT                 NaT
# url       53530                           NaT                 NaT
# info    1227477                           NaT                 NaT
#
#                                  25%                 50%  \
# id                               NaT                 NaT
# time   2014-11-12 11:39:37.249999872 2015-01-11 17:20:12
# userid                           NaT                 NaT
# ip                               NaT                 NaT
# course                           NaT                 NaT
# module                           NaT                 NaT
# cmid                             NaT                 NaT
# action                           NaT                 NaT
# url                              NaT                 NaT
# info                             NaT                 NaT
#
#                                  75%                 max
# id                               NaT                 NaT
# time   2015-03-28 10:29:59.249999872 2015-07-31 02:59:23
# userid                           NaT                 NaT
# ip                               NaT                 NaT
# course                           NaT                 NaT
# module                           NaT                 NaT
# cmid                             NaT                 NaT
# action                           NaT                 NaT
# url                              NaT                 NaT
# info                             NaT                 NaT

# %%
#the number of courses in these logs is different than the number of courses present in the database
#which may explain our trouble in reaching the intended 699 courses
#we will make a list of thew courses to import when woprking with the support tables

log_course_list = student_logs['course'].drop_duplicates().reset_index()
log_course_list.to_csv('../Data/R_Gonz_Courses_Logs.csv')

# %%
log_course_list
# Out:
#          index  course
# 0            0     1.0
# 1          162     4.0
# 2          171     3.0
# 3          176     5.0
# 4          182     8.0
# ...        ...     ...
# 5107  46703931  5928.0
# 5108  46703932  5929.0
# 5109  46703933  5930.0
# 5110  46703935  5931.0
# 5111  47009230  4970.0
#
# [5112 rows x 2 columns]

# %% [markdown]
# ### First step: Make it lighter.
#
# We will start by removing all letters from numerically identifiable categories: that is:
# ProductFamily_ID
# ProductCategory_ID
# ProductBrand_ID
# ProductName_ID
# ProductPackSKU_ID
#
# THE SAME PRODUCT MAY HAVE DIFFERENT SKUs!!!!!!

# %%
student_logs
# Out:
#                   id                time userid         ip  course  module  \
# 0                1.0 2014-06-05 17:09:07    2.0  127.0.0.1     1.0    user
# 1                2.0 2014-06-05 17:14:48    2.0  127.0.0.1     1.0    user
# 2                3.0 2014-06-05 17:14:48    2.0  127.0.0.1     1.0    user
# 3                4.0 2014-06-05 17:16:13    2.0  127.0.0.1     1.0  course
# 4                5.0 2014-06-06 07:37:19    2.0  127.0.0.1     1.0    user
# ...              ...                 ...    ...        ...     ...     ...
# 47097819  47116816.0 2015-07-31 03:00:59    0.0  127.0.0.1     1.0    user
# 47097820  47116817.0 2015-07-31 03:00:59    0.0  127.0.0.1     1.0    user
# 47097821  47116818.0 2015-07-31 03:00:59    0.0  127.0.0.1     1.0    user
# 47097822  47116819.0 2015-07-31 03:14:08    0.0  127.0.0.1   635.0    role
# 47097823  47116820.0 2015-07-31 03:14:09    0.0  127.0.0.1  2006.0    role
#
#          cmid    action                                              url  \
# 0         0.0     login                           view.php?id=2&course=1
# 1         0.0    update                                    view.php?id=2
# 2         0.0    update                                    view.php?id=2
# 3         0.0      view                                    view.php?id=1
# 4         0.0     login                           view.php?id=2&course=1
# ...       ...       ...                                              ...
# 47097819  0.0       add                               /view.php?id=81854
# 47097820  0.0       add                               /view.php?id=81855
# 47097821  0.0       add                               /view.php?id=81856
# 47097822  0.0  unassign  admin/roles/assign.php?contextid=24578&roleid=5
# 47097823  0.0  unassign  admin/roles/assign.php?contextid=97570&roleid=5
#
#                           info
# 0                            2
# 1                          NaN
# 2                          NaN
# 3                            1
# 4                            2
# ...                        ...
# 47097819    Cathleen Scheurich
# 47097820         Sara Gil Díez
# 47097821  Eduardo García Bermo
# 47097822            Estudiante
# 47097823            Estudiante
#
# [47097824 rows x 10 columns]

# %%
#using regex to all columns to remove unnecessary text

goliath['ProductFamily_ID'] = goliath['ProductFamily_ID'].str.extract('(\d+)', expand=False)
goliath['ProductCategory_ID'] = goliath['ProductCategory_ID'].str.extract('(\d+)', expand=False)
goliath['ProductBrand_ID'] = goliath['ProductBrand_ID'].str.extract('(\d+)', expand=False)
goliath['ProductName_ID'] = goliath['ProductName_ID'].str.extract('(\d+)', expand=False)
goliath['Point-of-Sale_ID'] = goliath['Point-of-Sale_ID'].str.extract('(\d+)', expand=False)
goliath['ProductPackSKU_ID'] = goliath['ProductPackSKU_ID'].str.extract('(\d+)', expand=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18504/698933144.py in <module>
#       1 #using regex to all columns to remove unnecessary text
#       2
# ----> 3 goliath['ProductFamily_ID'] = goliath['ProductFamily_ID'].str.extract('(\d+)', expand=False)
#       4 goliath['ProductCategory_ID'] = goliath['ProductCategory_ID'].str.extract('(\d+)', expand=False)
#       5 goliath['ProductBrand_ID'] = goliath['ProductBrand_ID'].str.extract('(\d+)', expand=False)
#
# NameError: name 'goliath' is not defined

# %%
#convert dataframe to a dataframe half its size by merging values and units on sku, store and data
values_df = goliath[goliath['Measures']=='Sell-out values']
units_df = goliath[goliath['Measures']=='Sell-out units']


goliath = pd.merge(units_df,values_df[['ProductPackSKU_ID','Point-of-Sale_ID','Date','Value']], on=['ProductPackSKU_ID','Point-of-Sale_ID','Date'],suffixes=('_units', '_price'))
goliath.drop(columns='Measures', inplace = True)

# %% [markdown]
# ### Additional Feature Engineering

# %% [markdown]
# #### Done
#
# From now on we will always work with df_treated in the future notebooks.
