# %% [markdown]
# ## Notebook 2.2. Understanding and Preprocessing of Moodle Logs
#
# For all intents and purposes, this should be considered as the first real notebook that is part of the thesis work. In it, we will take the original student log file and perform the necessary manipulations to ensure that we have a dataset with the potential to be useful.
#
# #### 1. A Small overview of the logs and each column
#
# The presented logs report to interactions with the Moodle LMS:
#
#     - Each interaction with the LMS is recorded sequentially:
#         When is the action performed,
#         What is the nature of the interaction,
#         Where is the actor when the action is performed,
#         Who performed the interaction,
#         In the context of which course page,
#         What is the specific link,
#
#     - Each user is uniquely identified by the userID,
#     - Each course is uniquely identified by the courseID,
#     - Each specific interaction is recorded -> action performed and clicked url,
#     - Each click is timestamped,
#     - The actor's IP is recorded,
#
# A brief description of each column follows:
#
# ##### id
# A sequentilly numbered unique identifier interactions,
#
# ##### time
# A float number representation of the timestamp of the event,
#
# ##### userid
# Unique numerical identifier of user -> be it student, faculty or other,
#
# ##### ip
# ip adress used by the user when interactiong with the LMS system,
#
# ##### course
# Unique numerical identifier of a course,
#
# ##### cmid
# meaning unclear at the moment - to check with other Moodle Sources,
#
# ##### action
# categorization of nature of the interaction
#
# ##### url
# link user clicked on
#
# ##### info
# additional descriptors added by the user
#
# #### 2. We'll start this notebook by importing all relevant packages and data
#
# All data is stored in the csv files that were exported in the previous notebook.
#
# In order to minimize unecessary steps, as we import these csv files we will immediatly remove, from each dataset:
# 1. The first unnamed column,
# 2. All columns that are entirely made of missing values - we have detected some.
# 3. All numerical columns that are immediatly recognied as categorical (or likely to be categorical values) are also immediatly declared as categoricals - this does not mean that, upon further assessment, other features may be converted to objects,
# 4. All features that display no null values and have a single value are promptly removed as well,
# 5. No preprocessing of time related features is performed at this stage - namely because the features realted with time may require further assessment.

# %%
#import libs
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()
import warnings
warnings.filterwarnings('ignore')

# %%
#loading student log data 
student_logs = pd.read_csv('../Data/R_Gonz_data_log.csv', 
                           dtype = {
                                   'id': object,
                                   'itemid': object,
                                   'userid': object,
                                   'course': object,
                                   'cmid': object,
                                   },).drop('Unnamed: 0', axis = 1).dropna(how = 'all', axis = 1) #logs

#loading support table
support_table = pd.read_csv('../Data/R_Gonz_support_table.csv', 
                           dtype = {
                                   'assign_id': object,
                                   'courseid': object,
                                   'userid': object,
                                   }, 
                            parse_dates = ['sup_time', 'startdate']).drop('Unnamed: 0', axis = 1).dropna(how = 'all', axis = 1) #support table

#after checking, we note that time and stime report to the same date and differ in 1 hour, hence, we will only keep the time column
#additionally, we will make the immediate conversion of time
student_logs['time'] = pd.to_datetime(student_logs['time'], unit = 's', errors = 'coerce')
student_logs.drop('stime', axis = 1, inplace = True)

# %% [markdown]
# ### Taking a preliminary look at the logs

# %%
student_logs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47097824 entries, 0 to 47097823
# Data columns (total 10 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   id      object
#  1   time    datetime64[ns]
#  2   userid  object
#  3   ip      object
#  4   course  object
#  5   module  object
#  6   cmid    object
#  7   action  object
#  8   url     object
#  9   info    object
# dtypes: datetime64[ns](1), object(9)
# memory usage: 3.5+ GB

# %%
student_logs.describe(include ='all', datetime_is_numeric = True).T
# Out:
#            count    unique            top      freq  \
# id      47097824  47097824            1.0         1
# time    47097824       NaN            NaN       NaN
# userid  47097824     30517            0.0   3219653
# ip      47097824    161783      127.0.0.1  30508698
# course  47097824      5112            1.0  17715596
# module  47097824        39         course  17937931
# cmid    47097824    167235            0.0  34846344
# action  47097824       157           view  27239500
# url     47070765    754343  view.php?id=1   6303588
# info    42907847    693729              1   6306585
#
#                                 mean                 min  \
# id                               NaT                 NaT
# time   2015-01-20 08:00:31.016559872 2014-06-05 17:09:07
# userid                           NaT                 NaT
# ip                               NaT                 NaT
# course                           NaT                 NaT
# module                           NaT                 NaT
# cmid                             NaT                 NaT
# action                           NaT                 NaT
# url                              NaT                 NaT
# info                             NaT                 NaT
#
#                                  25%                 50%                 75%  \
# id                               NaT                 NaT                 NaT
# time   2014-11-10 12:51:08.750000128 2015-01-17 20:12:12 2015-03-27 22:43:11
# userid                           NaT                 NaT                 NaT
# ip                               NaT                 NaT                 NaT
# course                           NaT                 NaT                 NaT
# module                           NaT                 NaT                 NaT
# cmid                             NaT                 NaT                 NaT
# action                           NaT                 NaT                 NaT
# url                              NaT                 NaT                 NaT
# info                             NaT                 NaT                 NaT
#
#                        max
# id                     NaT
# time   2015-07-31 03:14:09
# userid                 NaT
# ip                     NaT
# course                 NaT
# module                 NaT
# cmid                   NaT
# action                 NaT
# url                    NaT
# info                   NaT

# %%
student_logs
# Out:
#                   id                time userid         ip  course  module  \
# 0                1.0 2014-06-05 17:09:07    2.0  127.0.0.1     1.0    user
# 1                2.0 2014-06-05 17:14:48    2.0  127.0.0.1     1.0    user
# 2                3.0 2014-06-05 17:14:48    2.0  127.0.0.1     1.0    user
# 3                4.0 2014-06-05 17:16:13    2.0  127.0.0.1     1.0  course
# 4                5.0 2014-06-06 07:37:19    2.0  127.0.0.1     1.0    user
# ...              ...                 ...    ...        ...     ...     ...
# 47097819  47116816.0 2015-07-31 03:00:59    0.0  127.0.0.1     1.0    user
# 47097820  47116817.0 2015-07-31 03:00:59    0.0  127.0.0.1     1.0    user
# 47097821  47116818.0 2015-07-31 03:00:59    0.0  127.0.0.1     1.0    user
# 47097822  47116819.0 2015-07-31 03:14:08    0.0  127.0.0.1   635.0    role
# 47097823  47116820.0 2015-07-31 03:14:09    0.0  127.0.0.1  2006.0    role
#
#          cmid    action                                              url  \
# 0         0.0     login                           view.php?id=2&course=1
# 1         0.0    update                                    view.php?id=2
# 2         0.0    update                                    view.php?id=2
# 3         0.0      view                                    view.php?id=1
# 4         0.0     login                           view.php?id=2&course=1
# ...       ...       ...                                              ...
# 47097819  0.0       add                               /view.php?id=81854
# 47097820  0.0       add                               /view.php?id=81855
# 47097821  0.0       add                               /view.php?id=81856
# 47097822  0.0  unassign  admin/roles/assign.php?contextid=24578&roleid=5
# 47097823  0.0  unassign  admin/roles/assign.php?contextid=97570&roleid=5
#
#                           info
# 0                            2
# 1                          NaN
# 2                          NaN
# 3                            1
# 4                            2
# ...                        ...
# 47097819    Cathleen Scheurich
# 47097820         Sara Gil Díez
# 47097821  Eduardo García Bermo
# 47097822            Estudiante
# 47097823            Estudiante
#
# [47097824 rows x 10 columns]

# %%
#use this cell to write any additional piece of code that may be required

# %% [markdown]
# ### First step: Make it lighter.
#
# One of the first thing to do is to consider the set of students and courses we intend to use. We have, from our support table, a list of the courses and students that we are interested in. We'll then use that list of unique student-course pairs to only get logs for the courses we are interested in.

# %%
#We perform a group operation that 
student_courses = support_table.groupby([
                                        'courseid',
                                         'userid',
                                        ],
                                        as_index = False).size().rename(columns = {'courseid':'course'}).sort_values(by = 'size', ascending = False)

#then, we perform an inner merge - only keeping the rows that 
student_logs_actions = pd.merge(student_courses, student_logs, on=[
                                                        'userid',
                                                        'course',
                                                        ], 
                                                        how='inner').drop('size', axis = 1)

# %%
student_logs_actions.describe(include ='all', datetime_is_numeric = True).T
# Out:
#           count   unique                                            top  \
# course  8073418      787                                         2059.0
# userid  8073418    13723                                        61564.0
# id      8073418  8073418                                     26367149.0
# time    8073418      NaN                                            NaN
# ip      8073418    78310                                      127.0.0.1
# module  8073418       32                                         course
# cmid    8073418    34083                                            0.0
# action  8073418      127                                           view
# url     8064790   233031                               view.php?id=2059
# info    7798298    51751  Ver página de estado de las entregas propios.
#
#            freq                          mean                 min  \
# course   152140                           NaT                 NaT
# userid    16028                           NaT                 NaT
# id            1                           NaT                 NaT
# time        NaN 2015-01-22 11:30:42.195557888 2014-07-01 13:30:43
# ip      5090458                           NaT                 NaT
# module  3332811                           NaT                 NaT
# cmid    3686259                           NaT                 NaT
# action  6412568                           NaT                 NaT
# url       62213                           NaT                 NaT
# info     738590                           NaT                 NaT
#
#                        25%                     50%  \
# course                 NaT                     NaT
# userid                 NaT                     NaT
# id                     NaT                     NaT
# time   2014-11-11 07:56:32 2015-01-20 13:41:47.500
# ip                     NaT                     NaT
# module                 NaT                     NaT
# cmid                   NaT                     NaT
# action                 NaT                     NaT
# url                    NaT                     NaT
# info                   NaT                     NaT
#
#                                  75%                 max
# course                           NaT                 NaT
# userid                           NaT                 NaT
# id                               NaT                 NaT
# time   2015-04-01 14:28:01.750000128 2015-07-31 03:00:10
# ip                               NaT                 NaT
# module                           NaT                 NaT
# cmid                             NaT                 NaT
# action                           NaT                 NaT
# url                              NaT                 NaT
# info                             NaT                 NaT

# %%
student_logs_actions
# Out:
#          course   userid          id                time         ip    module  \
# 0        2272.0  72404.0  26367149.0 2015-02-01 21:28:28  127.0.0.1    course
# 1        2272.0  72404.0  26367215.0 2015-02-01 21:28:51  127.0.0.1      quiz
# 2        2272.0  72404.0  26367328.0 2015-02-01 21:29:21  127.0.0.1      quiz
# 3        2272.0  72404.0  26367455.0 2015-02-01 21:30:14  127.0.0.1      quiz
# 4        2272.0  72404.0  26367456.0 2015-02-01 21:30:14  127.0.0.1      quiz
# ...         ...      ...         ...                 ...        ...       ...
# 8073413   999.0   9203.0  42308220.0 2015-05-16 08:27:22  127.0.0.1  resource
# 8073414   999.0   9203.0  42308224.0 2015-05-16 08:27:32  127.0.0.1    course
# 8073415   999.0   9203.0  43796806.0 2015-05-25 09:26:31  127.0.0.1    course
# 8073416   999.0   9203.0  43796893.0 2015-05-25 09:26:55  127.0.0.1  resource
# 8073417   999.0   9203.0  43796953.0 2015-05-25 09:27:18  127.0.0.1    course
#
#              cmid            action                       url    info
# 0             0.0              view          view.php?id=2272    2272
# 1         98690.0              view         view.php?id=98690    1654
# 2         98706.0              view         view.php?id=98706    1657
# 3         98690.0           attempt  review.php?attempt=49216    1654
# 4         98690.0  continue attempt  review.php?attempt=49216    1654
# ...           ...               ...                       ...     ...
# 8073413  260558.0              view        view.php?id=260558  168571
# 8073414       0.0              view           view.php?id=999     999
# 8073415       0.0              view           view.php?id=999     999
# 8073416  260558.0              view        view.php?id=260558  168571
# 8073417       0.0              view           view.php?id=999     999
#
# [8073418 rows x 10 columns]

# %% [markdown]
# **Some preliminary observations of our most common interactions between the students and the systems**

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(student_logs_actions['action'].value_counts())
# Out:
# view                                   6412568
# continue attempt                        336654
# view all                                254719
# view forum                              150884
# review                                  124149
# view discussion                         115347
# view summary                            110710
# view submit assignment form             108914
# submit                                   91420
# attempt                                  86507
# close attempt                            82644
# view section                             60239
# update                                   28473
# view confirm submit assignment form      13215
# submit for grading                       12244
# view forums                              11369
# recent                                    9038
# submission statement accepted             7774
# view mailbox                              6543
# add post                                  4245
# launch                                    3733
# view submission                           3186
# view submission grading table             2621
# pre-view                                  2412
# add entry                                 2002
# add discussion                            1877
# edit                                      1821
# choose                                    1756
# update mod                                1408
# grade submission                          1394
# editquestions                             1380
# view grading form                         1280
# comments                                  1206
# manualgrade                               1094
# report                                    1005
# update post                               1002
# map                                        963
# add                                        960
# view entry                                 883
# history                                    845
# message saved                              830
# add assessment                             822
# message sent                               819
# subscribe                                  796
# update assessment                          598
# add mod                                    573
# user report                                565
# add submission                             564
# view chapter                               541
# view report                                532
# delete mod                                 524
# files                                      502
# view edit                                  495
# report log                                 483
# add page                                   345
# update entry                               323
# add category                               297
# choose again                               293
# view example                               220
# submissioncopied                           211
# update submission                          188
# unsubscribe                                187
# preview                                    179
# search                                     177
# report outline                             167
# comment                                    159
# save                                       156
# editsection                                122
# delete category                            110
# add example assessment                     100
# delete post                                 70
# update switch phase                         67
# save report                                 63
# delete discussion                           63
# update category                             61
# start                                       59
# download all submissions                    59
# add comment                                 51
# add item                                    49
# grant extension                             44
# subscribeall                                40
# edit report                                 38
# delete entry                                37
# delete attempt                              36
# lock submission                             32
# diff                                        31
# mark read                                   23
# update example assessment                   22
# view subscribers                            18
# edit post                                   14
# end                                         14
# report participation                        13
# add chapter                                 12
# record delete                               12
# delete                                      12
# revert submission to draft                   9
# templates view                               9
# edit override                                9
# unlock submission                            9
# add example                                  7
# add reference assessment                     7
# update reference assessment                  7
# fields add                                   5
# stop tracking                                5
# add episode                                  4
# start tracking                               4
# report live                                  3
# print                                        3
# admin                                        3
# restore                                      3
# userreport                                   3
# fields update                                3
# templates saved                              3
# view feedback                                3
# assign                                       2
# usage report                                 2
# unsubscribeall                               2
# view grade                                   2
# print chapter                                1
# mail digest error                            1
# prune post                                   1
# exportimscp                                  1
# message updated                              1
# label created                                1
# userreporttracks                             1
# userreportinteractions                       1
# delete override                              1
# Name: action, dtype: int64

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(student_logs_actions['module'].value_counts())
# Out:
# course             3332811
# resource           1686578
# quiz               1094432
# assign             1058987
# forum               286326
# user                123465
# folder              110551
# url                  92491
# page                 89080
# grade                28067
# glossary             28047
# imscp                21307
# book                 18804
# label                18135
# workshop             15447
# wiki                 14998
# questionnaire        14036
# choice               13342
# scorm                 8380
# jmail                 8194
# oublog                3016
# bigbluebuttonbn       2532
# data                  2202
# calendar               869
# bookmark               433
# lesson                 339
# pcast                  317
# recordingsbn           125
# nanogong                82
# discussion              13
# notes                   10
# role                     2
# Name: module, dtype: int64

# %% [markdown]
# At this stage, we only have course/student pairs with finalgrades and activity.
# For that, we will create a student-course pivot-table from each we can easily obtain the students attending each particular course.
#
# In the pivot-table, we can find the number of LMS interactions (clicks) performed by a student in the context of a given course. The count of valid entries in each column gives us the number of students attending a given curricular unit.

# %%
student_list = pd.pivot_table(student_logs_actions, index='userid', columns = 'course', values = 'url',
                    aggfunc='count')

student_list
# Out:
# course   1000.0  1002.0  1010.0  1013.0  1020.0  1024.0  1026.0  1027.0  \
# userid
# 10087.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1009.0      NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 10159.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 10184.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 10273.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ...         ...     ...     ...     ...     ...     ...     ...     ...
# 9895.0      NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 9915.0      NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 9925.0      NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 9964.0      NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 9966.0      NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# course   1028.0  1031.0  ...  845.0  90.0  918.0  922.0  961.0  984.0  985.0  \
# userid                   ...
# 10087.0     NaN     NaN  ...    NaN   NaN    NaN    NaN    NaN    NaN    NaN
# 1009.0      NaN     NaN  ...    NaN   NaN    NaN    NaN    NaN    NaN    NaN
# 10159.0     NaN     NaN  ...    NaN   NaN    NaN    NaN    NaN    NaN    NaN
# 10184.0     NaN     NaN  ...    NaN   NaN    NaN    NaN    NaN    NaN    NaN
# 10273.0     NaN     NaN  ...    NaN   NaN    NaN    NaN    NaN    NaN    NaN
# ...         ...     ...  ...    ...   ...    ...    ...    ...    ...    ...
# 9895.0      NaN     NaN  ...    NaN   NaN    NaN    NaN    NaN    NaN    NaN
# 9915.0      NaN     NaN  ...    NaN   NaN    NaN    NaN    NaN    NaN    NaN
# 9925.0      NaN     NaN  ...    NaN   NaN    NaN    NaN    NaN    NaN    NaN
# 9964.0      NaN     NaN  ...    NaN   NaN    NaN    NaN    NaN    NaN    NaN
# 9966.0      NaN     NaN  ...    NaN   NaN    NaN    NaN    NaN    NaN    NaN
#
# course   992.0  993.0  999.0
# userid
# 10087.0    NaN    NaN    NaN
# 1009.0     NaN    NaN    NaN
# 10159.0    NaN    NaN    NaN
# 10184.0    NaN    NaN    NaN
# 10273.0    NaN    NaN    NaN
# ...        ...    ...    ...
# 9895.0     NaN    NaN    NaN
# 9915.0     NaN    NaN    NaN
# 9925.0     NaN    NaN    NaN
# 9964.0     NaN    NaN    NaN
# 9966.0     NaN    NaN    NaN
#
# [13723 rows x 787 columns]

# %%
student_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13723 entries, 10087.0 to 9966.0
# Columns: 787 entries, 1000.0 to 999.0
# dtypes: float64(787)
# memory usage: 82.5+ MB

# %%
student_list.describe()
# Out:
# course      1000.0      1002.0      1010.0      1013.0       1020.0  \
# count    12.000000   22.000000   47.000000   68.000000    61.000000
# mean    218.833333  231.863636  443.425532  217.426471   356.508197
# std      81.337494   97.096072  185.565381   76.658638   258.300898
# min     115.000000   71.000000  155.000000   75.000000   135.000000
# 25%     143.750000  176.750000  299.000000  161.500000   235.000000
# 50%     233.000000  232.000000  408.000000  210.000000   291.000000
# 75%     268.000000  263.000000  572.500000  271.000000   374.000000
# max     368.000000  553.000000  982.000000  402.000000  1957.000000
#
# course      1024.0      1026.0       1027.0      1028.0      1031.0  ...  \
# count    56.000000  112.000000    55.000000    6.000000   13.000000  ...
# mean    161.178571  174.928571   768.581818  204.500000  362.307692  ...
# std     100.790892   96.185886   317.628171   89.511452  198.145311  ...
# min      10.000000   37.000000   240.000000  110.000000  149.000000  ...
# 25%      96.500000  115.750000   598.500000  130.750000  262.000000  ...
# 50%     149.500000  157.000000   698.000000  191.000000  296.000000  ...
# 75%     208.000000  215.250000   843.500000  270.000000  435.000000  ...
# max     486.000000  790.000000  2215.000000  328.000000  768.000000  ...
#
# course       845.0        90.0  918.0       922.0       961.0       984.0  \
# count    53.000000   15.000000    1.0    2.000000   12.000000   13.000000
# mean    303.773585  336.933333  636.0  416.000000  110.666667  323.230769
# std     175.296523  102.017132    NaN  172.534055   43.328205  130.449322
# min      36.000000  185.000000  636.0  294.000000   50.000000  138.000000
# 25%     189.000000  252.000000  636.0  355.000000   86.250000  235.000000
# 50%     246.000000  319.000000  636.0  416.000000  109.500000  310.000000
# 75%     367.000000  405.000000  636.0  477.000000  128.500000  373.000000
# max     828.000000  508.000000  636.0  538.000000  194.000000  549.000000
#
# course       985.0      992.0        993.0        999.0
# count    20.000000   16.00000    54.000000    56.000000
# mean    224.550000  418.37500   421.129630   498.339286
# std     105.023043  157.19367   233.602714   555.000975
# min      77.000000  202.00000   121.000000   158.000000
# 25%     144.500000  301.25000   279.000000   302.250000
# 50%     213.000000  337.00000   349.000000   386.500000
# 75%     284.000000  559.25000   514.750000   535.750000
# max     447.000000  682.00000  1584.000000  4301.000000
#
# [8 rows x 787 columns]

# %% [markdown]
# After can perform some exploratory analysis over these logs. On a very simple level, we can see, for each course, how do weekly clicks evolve over the weeks.

# %%
student_logs_actions.groupby([
                                        'course',
                                        #'userid',
                                        ],
                                        as_index = False).count()

# %% [markdown]
# Defining mandatory assignments vs non-mandatory assignments:
#
# The authors of the paper defined the mandatory assignments were all assignments with a submission rate of over 40%.

# %%
#using regex to all columns to remove unnecessary text

goliath['ProductFamily_ID'] = goliath['ProductFamily_ID'].str.extract('(\d+)', expand=False)
goliath['ProductCategory_ID'] = goliath['ProductCategory_ID'].str.extract('(\d+)', expand=False)
goliath['ProductBrand_ID'] = goliath['ProductBrand_ID'].str.extract('(\d+)', expand=False)
goliath['ProductName_ID'] = goliath['ProductName_ID'].str.extract('(\d+)', expand=False)
goliath['Point-of-Sale_ID'] = goliath['Point-of-Sale_ID'].str.extract('(\d+)', expand=False)
goliath['ProductPackSKU_ID'] = goliath['ProductPackSKU_ID'].str.extract('(\d+)', expand=False)

# %%
#convert dataframe to a dataframe half its size by merging values and units on sku, store and data
values_df = goliath[goliath['Measures']=='Sell-out values']
units_df = goliath[goliath['Measures']=='Sell-out units']


goliath = pd.merge(units_df,values_df[['ProductPackSKU_ID','Point-of-Sale_ID','Date','Value']], on=['ProductPackSKU_ID','Point-of-Sale_ID','Date'],suffixes=('_units', '_price'))
goliath.drop(columns='Measures', inplace = True)

# %% [markdown]
# ### Additional Feature Engineering

# %% [markdown]
# #### Done
#
# From now on we will always work with df_treated in the future notebooks.
