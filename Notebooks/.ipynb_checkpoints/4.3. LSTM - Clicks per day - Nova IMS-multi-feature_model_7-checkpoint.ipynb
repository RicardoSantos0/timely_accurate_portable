# %% [markdown]
# ### Thesis notebook 4.3. - NOVA IMS
#
# #### LSTM - Temporal data representation
#
# In this notebook, we will finally start our application of temporal representation using LSTMs.
# The argument for the usage of Deep Learning stems from the fact that sequences themselves encode information that can be extracted using Recurrent Neural Networks and, more specifically, Long Short Term Memory Units.
#
# #### First Step: Setup a PyTorch environment that enables the use of GPU for training.
#
# The following cell wll confirm that the GPU will be the default device to use.

# %%
import torch
import pycuda.driver as cuda

cuda.init()
## Get Id of default device
torch.cuda.current_device()
# 0
cuda.Device(0).name() # '0' is the id of your GPU

#set all tensors to gpu
torch.set_default_tensor_type('torch.cuda.FloatTensor')

# %% [markdown]
# #### Second Step: Import the relevant packages and declare global variables

# %%
#import necessary modules/libraries
import numpy as np
import scipy as sc
import pandas as pd
import datetime as dt
import warnings
import time


#tqdm to monitor progress
from tqdm.notebook import tqdm, trange
tqdm.pandas(desc="Progress")

#time related features
from datetime import timedelta
from copy import copy, deepcopy

#vizualization
import matplotlib.pyplot as plt
import seaborn as sns

#imblearn, scalers, kfold and metrics 
from sklearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler, QuantileTransformer,PowerTransformer
from sklearn.model_selection import train_test_split, RepeatedKFold, StratifiedKFold, cross_val_score, GridSearchCV, RandomizedSearchCV
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, roc_curve, recall_score, classification_report, average_precision_score, precision_recall_curve
from sklearn.pipeline import Pipeline

#import torch related
import torch.nn as nn
from torch.nn import functional as F
from torch.autograd import Variable 
from torch.utils.data import TensorDataset, DataLoader
from torch.utils.data.sampler import SubsetRandomSampler
from skorch import NeuralNetClassifier

#and optimizer of learning rate
from torch.optim.lr_scheduler import ReduceLROnPlateau

#import pytorch modules
warnings.filterwarnings('ignore')

# %%
#global variables that may come in handy


#colors for vizualizations
nova_ims_colors = ['#BFD72F', '#5C666C']

#standard color for student aggregates
student_color = '#474838'

#standard color for course aggragates
course_color = '#1B3D2F'

#standard continuous colormap
standard_cmap = 'viridis_r'

#Function designed to deal with multiindex and flatten it
def flattenHierarchicalCol(col,sep = '_'):
    '''converts multiindex columns into single index columns while retaining the hierarchical components'''
    if not type(col) is tuple:
        return col
    else:
        new_col = ''
        for leveli,level in enumerate(col):
            if not level == '':
                if not leveli == 0:
                    new_col += sep
                new_col += level
        return new_col
    
#number of replicas - number of repeats of stratified k fold - in this case 10
replicas = 30

#names to display on result figures
date_names = {
             'Date_threshold_10': '10% of Course Duration',   
             'Date_threshold_25': '25% of Course Duration', 
             'Date_threshold_33': '33% of Course Duration', 
             'Date_threshold_50': '50% of Course Duration', 
             'Date_threshold_100':'100% of Course Duration', 
            }

target_names = {
                'exam_fail' : 'At risk - Exam Grade',
                'final_fail' : 'At risk - Final Grade', 
                'exam_gifted' : 'High performer - Exam Grade', 
                'final_gifted': 'High performer - Final Grade'
                }

#targets
targets = ['exam_fail', 'exam_gifted']

#set the indexes to use for later
index = ["course_encoding", "cd_curso", "semestre", "courseid", "userid", 'exam_gifted', 'exam_fail']

#categories of objecctables
objects = ["course", "resource", "forum", "url", "folder", "quiz", "grade_grades", 
           "assignments", "groups", "user", "turnitintooltwo", "page", "choice", "other"]

# %% [markdown]
# #### Step 3: Import data and take a preliminary look at it

# %%
#imports dataframes
course_programs = pd.read_excel("../Data/Modeling Stage/Nova_IMS_Temporal_Datasets_daily_clicks.xlsx", 
                                dtype = {
                                    'course_encoding' : int,
                                    'userid' : int},
                               sheet_name = 'Date_threshold_100')

#save tables 
student_list = pd.read_csv('../Data/Modeling Stage/Nova_IMS_Filtered_targets.csv', 
                         dtype = {
                                   'course_encoding': int,
                                   'userid' : int,
                                   })

#drop unnamed 0 column
#merge with the targets we calculated on the other 
course_programs = course_programs.merge(student_list, on = ['course_encoding', 'userid'], how = 'inner')
course_programs.drop(['Unnamed: 0', 'exam_mark', 'final_mark'], axis = 1, inplace = True)
    
#convert results to object and need to convert column names to string
course_programs['course_encoding'], course_programs['userid'] = course_programs['course_encoding'].astype(object), course_programs['userid'].astype(object)
course_programs.columns = course_programs.columns.astype(str)

# %%
course_programs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 63171 entries, 0 to 63170
# Columns: 149 entries, course_encoding to exam_gifted
# dtypes: float64(95), int64(50), object(4)
# memory usage: 72.3+ MB

# %%
course_programs.describe(include = 'all')
# Out:
#         course_encoding      cd_curso semestre       courseid   userid  \
# count           63171.0  63171.000000    63171   63171.000000  63171.0
# unique            138.0           NaN        6            NaN   1590.0
# top               150.0           NaN       S1            NaN   6826.0
# freq             1821.0           NaN    28407            NaN     93.0
# mean                NaN   7906.809375      NaN  185361.922290      NaN
# std                 NaN   1986.226115      NaN   80819.428212      NaN
# min                 NaN    859.000000      NaN  100001.000000      NaN
# 25%                 NaN   7512.000000      NaN  100091.000000      NaN
# 50%                 NaN   9155.000000      NaN  200165.000000      NaN
# 75%                 NaN   9434.000000      NaN  200193.000000      NaN
# max                 NaN   9435.000000      NaN  400131.000000      NaN
#
#        objecttable             1             2             3             4  \
# count        63171  63171.000000  63171.000000  63171.000000  63171.000000
# unique          14           NaN           NaN           NaN           NaN
# top         course           NaN           NaN           NaN           NaN
# freq          9295           NaN           NaN           NaN           NaN
# mean           NaN      0.019803      0.028716      0.045638      0.052113
# std            NaN      0.276235      0.308394      0.458564      0.550856
# min            NaN      0.000000      0.000000      0.000000      0.000000
# 25%            NaN      0.000000      0.000000      0.000000      0.000000
# 50%            NaN      0.000000      0.000000      0.000000      0.000000
# 75%            NaN      0.000000      0.000000      0.000000      0.000000
# max            NaN     19.000000     17.000000     20.000000     30.000000
#
#         ...           134           135           136           137  \
# count   ...  41654.000000  39423.000000  37318.000000  34876.000000
# unique  ...           NaN           NaN           NaN           NaN
# top     ...           NaN           NaN           NaN           NaN
# freq    ...           NaN           NaN           NaN           NaN
# mean    ...      0.522903      0.293027      0.235329      0.867387
# std     ...      4.502103      2.288393      1.885921      9.354308
# min     ...      0.000000      0.000000      0.000000      0.000000
# 25%     ...      0.000000      0.000000      0.000000      0.000000
# 50%     ...      0.000000      0.000000      0.000000      0.000000
# 75%     ...      0.000000      0.000000      0.000000      0.000000
# max     ...    214.000000    118.000000    169.000000    376.000000
#
#                  138           139           140          141     exam_fail  \
# count   32366.000000  27005.000000  19821.000000  1054.000000  63171.000000
# unique           NaN           NaN           NaN          NaN           NaN
# top              NaN           NaN           NaN          NaN           NaN
# freq             NaN           NaN           NaN          NaN           NaN
# mean        0.250695      0.844844      0.339690     0.001898      0.190784
# std         1.631869      8.256497      3.054003     0.043540      0.392922
# min         0.000000      0.000000      0.000000     0.000000      0.000000
# 25%         0.000000      0.000000      0.000000     0.000000      0.000000
# 50%         0.000000      0.000000      0.000000     0.000000      0.000000
# 75%         0.000000      0.000000      0.000000     0.000000      0.000000
# max        58.000000    230.000000     96.000000     1.000000      1.000000
#
#          exam_gifted
# count   63171.000000
# unique           NaN
# top              NaN
# freq             NaN
# mean        0.287331
# std         0.452521
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000
#
# [11 rows x 149 columns]

# %% [markdown]
# In our first attempt, we will use the absolute number of clicks made by each student - scaled using standard scaler.
# Therefore, we can start by immediately placing our course encoding/userid pairings into the index.

# %%
def normalize(train, test, scaler):
    
    if scaler == 'MinMax':
        pt = MinMaxScaler()
    elif scaler == 'Standard':
        pt = StandardScaler()
    elif scaler == 'Robust':
        pt = RobustScaler()
    elif scaler == 'Quantile':
        pt = QuantileTransformer()
    else:
        pt = PowerTransformer(method='yeo-johnson')
    
    data_train = pt.fit_transform(train)
    data_test = pt.transform(test)
    # convert the array back to a dataframe
    normalized_train = pd.DataFrame(data_train,columns=train.columns)
    normalized_test = pd.DataFrame(data_test,columns=test.columns)
        
    return normalized_train, normalized_test

# %%
course_programs.objecttable.value_counts()
# Out:
# course             9295
# resource           8757
# forum              7005
# url                6769
# folder             5758
# quiz               4870
# grade_grades       4670
# assignments        3858
# groups             3525
# user               2344
# turnitintooltwo    1998
# page               1728
# choice             1373
# other              1221
# Name: objecttable, dtype: int64

# %%
test = course_programs.copy()

#The first 6 columns are index - column 141 is fully empty
columns = test.drop(targets, axis = 1).columns[6:146]

# %%
#create first pivot
placeholder_pivot = pd.pivot_table(test, index = index, values = columns, columns = "objecttable",
                  aggfunc = 'first')


#applies the function that removes multiindex
placeholder_pivot.columns = placeholder_pivot.columns.map(flattenHierarchicalCol)

#also saving index for reindexing of the remaining stuff
save_index = placeholder_pivot.index.copy()

#we will need to create the multidimensional tensors
placeholder_dict = {}

#create dataset for targets
df_targets = placeholder_pivot.reset_index().copy()[index]
df_targets.set_index(["course_encoding", "cd_curso", "semestre", "courseid", "userid"], inplace = True)

#initialize empty 3d array
nd_array_100 = np.zeros((
                               len(objects), #nbr of dimensions
                               len(placeholder_pivot), #nbr of rows
                               len(columns), #nbr of columns 
                              ))

#likely inefficient, but should do the trick
counter = 0

#create multiple dataframes based on regex - this will create ndarray for the 100 duration
for i in objects:
    #create the objects
    placeholder_dict[f'{i}'] = placeholder_pivot.filter(regex=f'_{i}')
    
    #remove text, convert column name back to numbers and sort numbers to ensure sequence
    placeholder_dict[f'{i}'].columns = placeholder_dict[f'{i}'].columns.str.replace(r"\D+", "", regex=True) 
    placeholder_dict[f'{i}'].columns = placeholder_dict[f'{i}'].columns.astype(int)
    placeholder_dict[f'{i}'] = placeholder_dict[f'{i}'][sorted(placeholder_dict[f'{i}'].columns)].fillna(0)
    
    #converting df to nd array
    nd_array_100[counter] = placeholder_dict[f'{i}'].values
    counter += 1

    #reshape to samples, rows, columns

#switching to rows, columns, features
nd_array_100 = nd_array_100.transpose(1,2,0)

# %%
nd_array_100.shape
# Out:
# (9296, 140, 14)

# %% [markdown]
# #### Implementing Cross-Validation with Deep Learning Model
#
# **1. Create the Deep Learning Model**
#
# In this instance, we will follow-up with on the approach used in Chen & Cui - CrossEntropyLoss with applied over a softmax layer.

# %%
class LSTM_Uni(nn.Module):
    def __init__(self, num_classes, input_size, hidden_size, num_layers, seq_length, dropout):
        super(LSTM_Uni, self).__init__()
        self.num_classes = num_classes #number of classes
        self.num_layers = num_layers #number of layers
        self.input_size = input_size #input size
        self.hidden_size = hidden_size #hidden state
        self.seq_length = seq_length #sequence length

        self.lstm = nn.LSTM(input_size=input_size, hidden_size=hidden_size,
                          num_layers=num_layers, batch_first = True) #lstm
        
        self.dropout = nn.Dropout(p = dropout)
    
        self.fc = nn.Linear(self.hidden_size, num_classes) #fully connected last layer

    def forward(self,x):
        h_0 = Variable(torch.zeros(self.num_layers, x.size(0), self.hidden_size)) #hidden state
        c_0 = Variable(torch.zeros(self.num_layers, x.size(0), self.hidden_size)) #internal state
        
        #Xavier_init for both H_0 and C_0
        torch.nn.init.xavier_normal_(h_0)
        torch.nn.init.xavier_normal_(c_0)
        
        # Propagate input through LSTM
        lstm_out, (hn, cn) = self.lstm(x, (h_0, c_0)) #lstm with input, hidden, and internal state
        last_output = hn.view(-1, self.hidden_size) #reshaping the data for Dense layer next
        
        #we are interested in only keeping the last output
        drop_out = self.dropout(last_output)
        pre_bce = self.fc(drop_out) #Final Output - dense
        return pre_bce

# %% [markdown]
# **2. Define the train and validation Functions**

# %%
def train_epoch(model,dataloader,loss_fn,optimizer):
    
    train_loss,train_correct=0.0,0 
    model.train()
    for X, labels in dataloader:

        optimizer.zero_grad()
        output = model(X)   
        loss = loss_fn(output,labels.unsqueeze(1))
        loss.backward()
        optimizer.step()
        train_loss += loss.item() * X.size(0)
        scores = F.sigmoid(output)
        predictions = torch.round(scores)
        #calculate % correct
        train_correct += (predictions == labels.unsqueeze(1)).sum().item()
        
    return train_loss,train_correct
  
def valid_epoch(model,dataloader,loss_fn):
    valid_loss, val_correct = 0.0, 0
    targets = []
    y_pred = []
    probability_1 = []
    
    model.eval()
    for X, labels in dataloader:

        output = model(X)
        loss=loss_fn(output,labels.unsqueeze(1))
        valid_loss+=loss.item()*X.size(0)
        scores = F.sigmoid(output)
        predictions = torch.round(scores)
        val_correct+=(predictions == labels.unsqueeze(1)).sum().item()
        targets.append(labels.unsqueeze(1))
        y_pred.append(predictions)
        probability_1.append(scores)
        
    #concat all results
    targets = torch.cat(targets).data.cpu().numpy()
    y_pred = torch.cat(y_pred).data.cpu().numpy()
    probability_1 = torch.cat(probability_1).data.cpu().numpy()
    
    #calculate precision, recall and AUC score
    
    precision = precision_score(targets, y_pred)
    recall = recall_score(targets, y_pred)
    f1 = f1_score(targets, y_pred)
    auroc = roc_auc_score(targets, probability_1)
    
    #return all
    return valid_loss,val_correct, precision, recall, auroc, f1

# %% [markdown]
# **3. Define main hyperparameters of the model, including splits**

# %%
#randomly select from params dict
params = {
    'learning_rate': [0.001, 0.01, 0.005, 0.05],
    'num_epochs' : [30, 50, 80, 100, 150, 200],
    'hidden_size': [32, 64, 128, 256],
    'batch_size': [32, 64, 128, 256, 512],
    'num_layers': [1],
    'dropout': [0.2, 0.5],
    'optimizer' : ['adam', 'rmsprop', 'adagrad', 'sgd'], 
    'scaler' : [RobustScaler()],}

from random import choice

combination = [choice(params['learning_rate']), #choose lr
               choice(params['num_epochs']), #max epochs
               choice(params['hidden_size']), #hidden layer size
               choice(params['batch_size']), #hidden batch size
               choice(params['num_layers']), #hidden batch size
               choice(params['dropout']), # select random_combination of dropout
               choice(params['optimizer']),
               choice(params['scaler']),],

#Parameters chosen are
combination
# Out:
# ([0.001, 200, 256, 512, 1, 0.5, 'adam', RobustScaler()],)

# %%
#initial configuation - the default
learning_rate = combination[0][0]
num_epochs = combination[0][1]
input_size = 14 #number of features
hidden_size = combination[0][2]
batch_size = combination[0][3]
num_layers = combination[0][4]
dropout = combination[0][5]


#Shape of Output as required for Sigmoid Classifier
num_classes = 1 #output shape

k=10
splits= StratifiedKFold(n_splits=k, random_state=15, shuffle = True) #kfold of 10 with 30 replicas
criterion = nn.BCEWithLogitsLoss()    # cross-entropy for classification

# %% [markdown]
# ### Test on data - starting with the first 25 days

# %%
#create main dict results for 25 days
target_df_dict_25 = {}

for k in tqdm(targets):
    print(k)
    
    #create main dict results
    
    target_df_dict_25[f'{(k)}'] = {}
    y = df_targets[k].values

    #create a list containing one value per row
    all_indices = list(range(len(df_targets)))
    
    #using train test split to later apply the rule accordingly
    train_ind, test_ind = train_test_split(all_indices, test_size=0.2, 
                                           random_state = 5, stratify = y)
    
    #applied train_test_split rules accordingly
    X_train_val = nd_array_100[train_ind,:26,:]
    y_train_val = y[train_ind]
    
    X_test = nd_array_100[test_ind, :26, :]
    y_test = y[test_ind]    
        
    for repeat in range(replicas):
        print('Replica {}'.format(repeat+1))
        #reset "best accuracy for treshold i and target k"
        best_f1_score = 0
        foldperf={}
        
        #make train_val split
        for fold, (train_idx,val_idx) in tqdm(enumerate(splits.split(X_train_val, y_train_val))):
            print('Split {}'.format(fold + 1))
            
            #make split between train and Val
            X_train, y_train = X_train_val[train_idx], y_train_val[train_idx]
            X_val, y_val = X_train_val[val_idx], y_train_val[val_idx]
            
            #scaling requires one scaler per channel (feature)
            scalers = {}
            for feature in range(X_train.shape[2]):
                           
                scalers[feature] = combination[0][7]
                X_train[:, :, feature] = scalers[feature].fit_transform(X_train[:, :, feature]) 

            for col in range(X_val.shape[2]):
                X_val[:, :, feature] = scalers[feature].transform(X_val[:, :, feature]) 
            
            #need to oversample - will use smote
            #will also require oneoversampler per channel (feature)
            samplers = {}
            
            #create new nd_array with the correct size - 2 * majority class 
            X_train_res = np.zeros(shape = (2* (int(sc.stats.mode(y_train)[1])), X_train.shape[1], X_train.shape[2]))
            for feature in range(X_train.shape[2]):
                           
                samplers[feature] = SMOTE()
                X_train_res[:, :, feature], y_train_res = samplers[feature].fit_resample(X_train[:, :, feature], y_train) 
            
            #second, convert everything to pytorch tensor - we will convert to tensor dataset and 
            X_train_tensors = torch.from_numpy(X_train_res)
            X_val_tensors = torch.from_numpy(X_val)
            
            #convert X tensors to format FloatTensor
            X_train_tensors = X_train_tensors.type(torch.cuda.FloatTensor)
            X_val_tensors = X_val_tensors.type(torch.cuda.FloatTensor)
            
            #create y_tensor
            y_train_tensors = torch.from_numpy(y_train_res)
            y_val_tensors = torch.from_numpy(y_val)
            
            #convert y tensors to format longtensor
            y_train_tensors = y_train_tensors.type(torch.cuda.FloatTensor)
            y_val_tensors = y_val_tensors.type(torch.cuda.FloatTensor)
            
            #create Tensor Datasets and dataloaders for both Train and Val
            train_dataset = TensorDataset(X_train_tensors, y_train_tensors)
            val_dataset = TensorDataset(X_val_tensors, y_val_tensors)
            train_loader = DataLoader(train_dataset, batch_size=batch_size)
            val_loader = DataLoader(val_dataset, batch_size=batch_size)
    
            #creates new model for each 
            model = LSTM_Uni(num_classes, input_size, hidden_size, num_layers, X_train_tensors.shape[1], dropout).to('cuda') #our lstm class
            
            #running condition on optimizer
            if combination[0][6] == 'adam':
                optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
            
            elif combination[0][6] == 'rmsprop':
                optimizer = torch.optim.RMSprop(model.parameters(), lr=learning_rate)
            
            elif combination[0][6] == 'adagrad':
                optimizer = torch.optim.Adagrad(model.parameters(), lr=learning_rate)
            
            else:
                optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
            
            scheduler = ReduceLROnPlateau(optimizer, 
                                 'min', 
                                 patience = 15,
                                 cooldown = 20,
                                threshold=0.00001,
                                factor = 0.33,
                                verbose = True)
    
            history = {'train_loss': [], 'val_loss': [],'train_acc':[],'val_acc':[], 'precision': [],
                      'recall' : [], 'auroc': [], 'f1_score' : []}

            for epoch in tqdm(range(num_epochs)):
                train_loss, train_correct=train_epoch(model,train_loader,criterion,optimizer)
                val_loss, val_correct, precision, recall, auroc, f1 = valid_epoch(model,val_loader,criterion)

                train_loss = train_loss / len(train_loader.sampler)
                train_acc = train_correct / len(train_loader.sampler) * 100
                val_loss = val_loss / len(val_loader.sampler)
                val_acc = val_correct / len(val_loader.sampler) * 100
        
        
                if (epoch+1) % 10 == 0: 
                 print("Epoch:{}/{} AVG Training Loss:{:.3f} AVG Validation Loss:{:.3f} AVG Training Acc {:.2f} % AVG Validation Acc {:.2f} %".format(epoch + 1,
                                                                                                             num_epochs,
                                                                                                             train_loss,
                                                                                                             val_loss,
                                                                                                             train_acc,
                                                                                                             val_acc))
                history['train_loss'].append(train_loss)
                history['val_loss'].append(val_loss)
                history['train_acc'].append(train_acc)
                history['val_acc'].append(val_acc)
                history['precision'].append(precision)
                history['recall'].append(recall)
                history['auroc'].append(auroc)
                history['f1_score'].append(f1)
                scheduler.step(val_loss)
    
                if f1 > best_f1_score:
            
                #replace best accuracy and save best model
                    print(f'New Best F1_score found: {f1*100:.2f}%\nEpoch: {epoch + 1}\n', 
                         f'Accuracy: {val_acc:.2f}\nAUC: {auroc*100:.2f}')
                    best_f1_score = f1
                    best = deepcopy(model)
                    curr_epoch = epoch + 1
                    
            #store fold performance
            foldperf['fold{}'.format(fold+1)] = history
    
        #create dict to store fold performance
        target_df_dict_25[f'{(k)}']['repeat{}'.format(repeat + 1)] = foldperf
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# exam_fail
# Replica 1
# 0it [00:00, ?it/s]
# Split 1
#   0%|          | 0/200 [00:00<?, ?it/s]
# New Best F1_score found: 3.80%
# Epoch: 3
#  Accuracy: 79.57
# AUC: 57.58
# New Best F1_score found: 30.67%
# Epoch: 4
#  Accuracy: 70.83
# AUC: 58.68
# New Best F1_score found: 33.33%
# Epoch: 5
#  Accuracy: 65.05
# AUC: 59.47
# New Best F1_score found: 34.50%
# Epoch: 6
#  Accuracy: 62.23
# AUC: 60.53
# New Best F1_score found: 35.36%
# Epoch: 7
#  Accuracy: 55.78
# AUC: 61.12
# New Best F1_score found: 35.69%
# Epoch: 8
#  Accuracy: 51.08
# AUC: 61.79
# New Best F1_score found: 37.08%
# Epoch: 9
#  Accuracy: 52.55
# AUC: 61.52
# Epoch:10/200 AVG Training Loss:0.683 AVG Validation Loss:0.685 AVG Training Acc 53.21 % AVG Validation Acc 45.03 %
# New Best F1_score found: 37.45%
# Epoch: 19
#  Accuracy: 56.45
# AUC: 61.37
# Epoch:20/200 AVG Training Loss:0.603 AVG Validation Loss:0.565 AVG Training Acc 71.14 % AVG Validation Acc 66.40 %
# Epoch:30/200 AVG Training Loss:0.508 AVG Validation Loss:0.572 AVG Training Acc 77.50 % AVG Validation Acc 69.22 %
# New Best F1_score found: 37.50%
# Epoch: 31
#  Accuracy: 66.40
# AUC: 65.20
# Epoch:40/200 AVG Training Loss:0.385 AVG Validation Loss:0.514 AVG Training Acc 82.48 % AVG Validation Acc 78.09 %
# Epoch:50/200 AVG Training Loss:0.340 AVG Validation Loss:0.516 AVG Training Acc 84.42 % AVG Validation Acc 78.63 %
# Epoch    59: reducing learning rate of group 0 to 3.3000e-04.
# Epoch:60/200 AVG Training Loss:0.308 AVG Validation Loss:0.519 AVG Training Acc 85.72 % AVG Validation Acc 78.36 %
# Epoch:70/200 AVG Training Loss:0.277 AVG Validation Loss:0.536 AVG Training Acc 87.01 % AVG Validation Acc 77.82 %
# Epoch:80/200 AVG Training Loss:0.276 AVG Validation Loss:0.547 AVG Training Acc 87.21 % AVG Validation Acc 77.55 %
# Epoch:90/200 AVG Training Loss:0.253 AVG Validation Loss:0.565 AVG Training Acc 88.02 % AVG Validation Acc 74.87 %
# Epoch    95: reducing learning rate of group 0 to 1.0890e-04.
# Epoch:100/200 AVG Training Loss:0.219 AVG Validation Loss:0.634 AVG Training Acc 89.55 % AVG Validation Acc 76.08 %
# Epoch:110/200 AVG Training Loss:0.207 AVG Validation Loss:0.674 AVG Training Acc 90.25 % AVG Validation Acc 74.87 %
# Epoch:120/200 AVG Training Loss:0.197 AVG Validation Loss:0.741 AVG Training Acc 90.52 % AVG Validation Acc 74.46 %
# Epoch:130/200 AVG Training Loss:0.186 AVG Validation Loss:0.780 AVG Training Acc 91.10 % AVG Validation Acc 74.46 %
# Epoch   131: reducing learning rate of group 0 to 3.5937e-05.
# Epoch:140/200 AVG Training Loss:0.179 AVG Validation Loss:0.781 AVG Training Acc 91.46 % AVG Validation Acc 74.73 %
# Epoch:150/200 AVG Training Loss:0.178 AVG Validation Loss:0.804 AVG Training Acc 91.62 % AVG Validation Acc 74.46 %
# Epoch:160/200 AVG Training Loss:0.173 AVG Validation Loss:0.818 AVG Training Acc 91.83 % AVG Validation Acc 75.27 %
# Epoch   167: reducing learning rate of group 0 to 1.1859e-05.
# Epoch:170/200 AVG Training Loss:0.172 AVG Validation Loss:0.837 AVG Training Acc 91.79 % AVG Validation Acc 74.33 %
# Epoch:180/200 AVG Training Loss:0.170 AVG Validation Loss:0.844 AVG Training Acc 91.64 % AVG Validation Acc 74.60 %
# Epoch:190/200 AVG Training Loss:0.169 AVG Validation Loss:0.850 AVG Training Acc 91.95 % AVG Validation Acc 74.46 %
# Epoch:200/200 AVG Training Loss:0.167 AVG Validation Loss:0.854 AVG Training Acc 92.07 % AVG Validation Acc 74.46 %
# Split 2
#   0%|          | 0/200 [00:00<?, ?it/s]
# Epoch:10/200 AVG Training Loss:0.683 AVG Validation Loss:0.702 AVG Training Acc 56.83 % AVG Validation Acc 34.14 %
# Epoch:20/200 AVG Training Loss:0.595 AVG Validation Loss:0.630 AVG Training Acc 71.23 % AVG Validation Acc 57.93 %
# Epoch:30/200 AVG Training Loss:0.645 AVG Validation Loss:0.589 AVG Training Acc 72.00 % AVG Validation Acc 65.86 %
# Epoch:40/200 AVG Training Loss:0.448 AVG Validation Loss:0.540 AVG Training Acc 80.06 % AVG Validation Acc 73.66 %
# Epoch:50/200 AVG Training Loss:0.341 AVG Validation Loss:0.513 AVG Training Acc 84.52 % AVG Validation Acc 76.21 %
# Epoch:60/200 AVG Training Loss:0.305 AVG Validation Loss:0.557 AVG Training Acc 86.19 % AVG Validation Acc 74.19 %
# Epoch    67: reducing learning rate of group 0 to 3.3000e-04.
# Epoch:70/200 AVG Training Loss:0.269 AVG Validation Loss:0.545 AVG Training Acc 87.77 % AVG Validation Acc 77.55 %
# Epoch:80/200 AVG Training Loss:0.248 AVG Validation Loss:0.622 AVG Training Acc 88.62 % AVG Validation Acc 76.34 %
# Epoch:90/200 AVG Training Loss:0.231 AVG Validation Loss:0.657 AVG Training Acc 89.37 % AVG Validation Acc 74.87 %
# Epoch:100/200 AVG Training Loss:0.207 AVG Validation Loss:0.679 AVG Training Acc 90.60 % AVG Validation Acc 72.18 %
# Epoch   103: reducing learning rate of group 0 to 1.0890e-04.
# Epoch:110/200 AVG Training Loss:0.183 AVG Validation Loss:0.795 AVG Training Acc 91.78 % AVG Validation Acc 74.87 %
# Epoch:120/200 AVG Training Loss:0.172 AVG Validation Loss:0.862 AVG Training Acc 92.14 % AVG Validation Acc 74.33 %
# Epoch:130/200 AVG Training Loss:0.164 AVG Validation Loss:0.923 AVG Training Acc 92.53 % AVG Validation Acc 73.52 %
# Epoch   139: reducing learning rate of group 0 to 3.5937e-05.
# Epoch:140/200 AVG Training Loss:0.168 AVG Validation Loss:0.930 AVG Training Acc 92.53 % AVG Validation Acc 73.39 %
# Epoch:150/200 AVG Training Loss:0.152 AVG Validation Loss:0.977 AVG Training Acc 92.98 % AVG Validation Acc 74.06 %
# Epoch:160/200 AVG Training Loss:0.150 AVG Validation Loss:1.005 AVG Training Acc 93.12 % AVG Validation Acc 73.66 %
# Epoch:170/200 AVG Training Loss:0.146 AVG Validation Loss:1.028 AVG Training Acc 93.14 % AVG Validation Acc 73.92 %
# Epoch   175: reducing learning rate of group 0 to 1.1859e-05.
# Epoch:180/200 AVG Training Loss:0.143 AVG Validation Loss:1.041 AVG Training Acc 93.24 % AVG Validation Acc 74.06 %
# Epoch:190/200 AVG Training Loss:0.142 AVG Validation Loss:1.049 AVG Training Acc 93.40 % AVG Validation Acc 73.79 %
# Epoch:200/200 AVG Training Loss:0.141 AVG Validation Loss:1.059 AVG Training Acc 93.39 % AVG Validation Acc 74.33 %
# Split 3
#   0%|          | 0/200 [00:00<?, ?it/s]
# New Best F1_score found: 38.33%
# Epoch: 8
#  Accuracy: 52.42
# AUC: 63.89
# Epoch:10/200 AVG Training Loss:0.673 AVG Validation Loss:0.654 AVG Training Acc 56.87 % AVG Validation Acc 57.26 %
# Epoch:20/200 AVG Training Loss:0.580 AVG Validation Loss:0.581 AVG Training Acc 72.78 % AVG Validation Acc 63.84 %
# Epoch:30/200 AVG Training Loss:0.445 AVG Validation Loss:0.581 AVG Training Acc 80.09 % AVG Validation Acc 73.52 %
# Epoch:40/200 AVG Training Loss:0.341 AVG Validation Loss:0.505 AVG Training Acc 84.28 % AVG Validation Acc 78.49 %
# Epoch:50/200 AVG Training Loss:0.306 AVG Validation Loss:0.525 AVG Training Acc 85.73 % AVG Validation Acc 77.15 %
# Epoch:60/200 AVG Training Loss:0.280 AVG Validation Loss:0.627 AVG Training Acc 87.04 % AVG Validation Acc 77.69 %
# Epoch    61: reducing learning rate of group 0 to 3.3000e-04.
# Epoch:70/200 AVG Training Loss:0.235 AVG Validation Loss:0.593 AVG Training Acc 89.28 % AVG Validation Acc 78.09 %
# Epoch:80/200 AVG Training Loss:0.218 AVG Validation Loss:0.670 AVG Training Acc 90.06 % AVG Validation Acc 75.54 %
# Epoch:90/200 AVG Training Loss:0.206 AVG Validation Loss:0.752 AVG Training Acc 90.57 % AVG Validation Acc 75.67 %
# Epoch    97: reducing learning rate of group 0 to 1.0890e-04.
# Epoch:100/200 AVG Training Loss:0.168 AVG Validation Loss:0.879 AVG Training Acc 92.32 % AVG Validation Acc 75.13 %
# Epoch:110/200 AVG Training Loss:0.157 AVG Validation Loss:0.963 AVG Training Acc 92.78 % AVG Validation Acc 75.13 %
# Epoch:120/200 AVG Training Loss:0.147 AVG Validation Loss:1.053 AVG Training Acc 93.26 % AVG Validation Acc 72.72 %
# Epoch:130/200 AVG Training Loss:0.146 AVG Validation Loss:1.102 AVG Training Acc 93.11 % AVG Validation Acc 73.79 %
# Epoch   133: reducing learning rate of group 0 to 3.5937e-05.
# Epoch:140/200 AVG Training Loss:0.135 AVG Validation Loss:1.175 AVG Training Acc 94.00 % AVG Validation Acc 73.25 %
# Epoch:150/200 AVG Training Loss:0.132 AVG Validation Loss:1.209 AVG Training Acc 93.85 % AVG Validation Acc 72.72 %
# Epoch:160/200 AVG Training Loss:0.127 AVG Validation Loss:1.239 AVG Training Acc 94.02 % AVG Validation Acc 72.31 %
# Epoch   169: reducing learning rate of group 0 to 1.1859e-05.
# Epoch:170/200 AVG Training Loss:0.124 AVG Validation Loss:1.278 AVG Training Acc 94.23 % AVG Validation Acc 71.64 %
# Epoch:180/200 AVG Training Loss:0.123 AVG Validation Loss:1.294 AVG Training Acc 94.37 % AVG Validation Acc 71.51 %
# Epoch:190/200 AVG Training Loss:0.123 AVG Validation Loss:1.305 AVG Training Acc 94.30 % AVG Validation Acc 71.37 %
# Epoch:200/200 AVG Training Loss:0.121 AVG Validation Loss:1.318 AVG Training Acc 94.41 % AVG Validation Acc 72.18 %
# Split 4
#   0%|          | 0/200 [00:00<?, ?it/s]
# Epoch:10/200 AVG Training Loss:0.680 AVG Validation Loss:0.678 AVG Training Acc 53.66 % AVG Validation Acc 45.70 %
# Epoch:20/200 AVG Training Loss:0.568 AVG Validation Loss:0.592 AVG Training Acc 72.86 % AVG Validation Acc 63.31 %
# Epoch:30/200 AVG Training Loss:0.544 AVG Validation Loss:0.540 AVG Training Acc 76.27 % AVG Validation Acc 73.12 %
# Epoch:40/200 AVG Training Loss:0.379 AVG Validation Loss:0.526 AVG Training Acc 82.91 % AVG Validation Acc 77.15 %
# Epoch:50/200 AVG Training Loss:0.332 AVG Validation Loss:0.510 AVG Training Acc 84.89 % AVG Validation Acc 77.28 %
# Epoch:60/200 AVG Training Loss:0.297 AVG Validation Loss:0.523 AVG Training Acc 86.45 % AVG Validation Acc 77.02 %
# Epoch    60: reducing learning rate of group 0 to 3.3000e-04.
# Epoch:70/200 AVG Training Loss:0.260 AVG Validation Loss:0.546 AVG Training Acc 88.16 % AVG Validation Acc 77.15 %
# Epoch:80/200 AVG Training Loss:0.242 AVG Validation Loss:0.613 AVG Training Acc 89.08 % AVG Validation Acc 74.60 %
# Epoch:90/200 AVG Training Loss:0.223 AVG Validation Loss:0.653 AVG Training Acc 89.72 % AVG Validation Acc 75.81 %
# Epoch    96: reducing learning rate of group 0 to 1.0890e-04.
# Epoch:100/200 AVG Training Loss:0.195 AVG Validation Loss:0.718 AVG Training Acc 91.23 % AVG Validation Acc 74.06 %
# Epoch:110/200 AVG Training Loss:0.179 AVG Validation Loss:0.789 AVG Training Acc 91.70 % AVG Validation Acc 74.33 %
# Epoch:120/200 AVG Training Loss:0.171 AVG Validation Loss:0.853 AVG Training Acc 92.08 % AVG Validation Acc 73.79 %
# Epoch:130/200 AVG Training Loss:0.164 AVG Validation Loss:0.842 AVG Training Acc 92.39 % AVG Validation Acc 73.25 %
# Epoch   132: reducing learning rate of group 0 to 3.5937e-05.
# Epoch:140/200 AVG Training Loss:0.157 AVG Validation Loss:0.904 AVG Training Acc 92.76 % AVG Validation Acc 73.52 %
# Epoch:150/200 AVG Training Loss:0.154 AVG Validation Loss:0.930 AVG Training Acc 92.92 % AVG Validation Acc 72.72 %
# Epoch:160/200 AVG Training Loss:0.150 AVG Validation Loss:0.954 AVG Training Acc 93.08 % AVG Validation Acc 73.79 %
# Epoch   168: reducing learning rate of group 0 to 1.1859e-05.
# Epoch:170/200 AVG Training Loss:0.146 AVG Validation Loss:0.990 AVG Training Acc 93.25 % AVG Validation Acc 73.12 %
# Epoch:180/200 AVG Training Loss:0.145 AVG Validation Loss:0.995 AVG Training Acc 93.13 % AVG Validation Acc 72.72 %
# Epoch:190/200 AVG Training Loss:0.143 AVG Validation Loss:1.006 AVG Training Acc 93.35 % AVG Validation Acc 73.12 %
# Epoch:200/200 AVG Training Loss:0.141 AVG Validation Loss:1.008 AVG Training Acc 93.30 % AVG Validation Acc 73.12 %
# Split 5
#   0%|          | 0/200 [00:00<?, ?it/s]
# Epoch:10/200 AVG Training Loss:0.684 AVG Validation Loss:0.682 AVG Training Acc 56.58 % AVG Validation Acc 43.41 %
# Epoch:20/200 AVG Training Loss:0.600 AVG Validation Loss:0.604 AVG Training Acc 70.05 % AVG Validation Acc 58.20 %
# Epoch:30/200 AVG Training Loss:0.510 AVG Validation Loss:0.601 AVG Training Acc 77.08 % AVG Validation Acc 65.73 %
# Epoch:40/200 AVG Training Loss:0.388 AVG Validation Loss:0.511 AVG Training Acc 82.16 % AVG Validation Acc 77.42 %
# Epoch:50/200 AVG Training Loss:0.331 AVG Validation Loss:0.516 AVG Training Acc 84.87 % AVG Validation Acc 75.94 %
# Epoch:60/200 AVG Training Loss:0.304 AVG Validation Loss:0.542 AVG Training Acc 86.03 % AVG Validation Acc 75.27 %
# Epoch    67: reducing learning rate of group 0 to 3.3000e-04.
# Epoch:70/200 AVG Training Loss:0.249 AVG Validation Loss:0.599 AVG Training Acc 88.58 % AVG Validation Acc 75.54 %
# Epoch:80/200 AVG Training Loss:0.222 AVG Validation Loss:0.713 AVG Training Acc 89.90 % AVG Validation Acc 74.60 %
# Epoch:90/200 AVG Training Loss:0.209 AVG Validation Loss:0.735 AVG Training Acc 90.28 % AVG Validation Acc 72.85 %
# Epoch:100/200 AVG Training Loss:0.187 AVG Validation Loss:0.973 AVG Training Acc 91.23 % AVG Validation Acc 72.58 %
# Epoch   103: reducing learning rate of group 0 to 1.0890e-04.
# Epoch:110/200 AVG Training Loss:0.167 AVG Validation Loss:0.932 AVG Training Acc 92.13 % AVG Validation Acc 71.91 %
# Epoch:120/200 AVG Training Loss:0.156 AVG Validation Loss:1.009 AVG Training Acc 92.61 % AVG Validation Acc 71.51 %
# Epoch:130/200 AVG Training Loss:0.154 AVG Validation Loss:0.978 AVG Training Acc 92.84 % AVG Validation Acc 72.31 %
# Epoch   139: reducing learning rate of group 0 to 3.5937e-05.
# Epoch:140/200 AVG Training Loss:0.139 AVG Validation Loss:1.124 AVG Training Acc 93.39 % AVG Validation Acc 71.24 %
# Epoch:150/200 AVG Training Loss:0.137 AVG Validation Loss:1.153 AVG Training Acc 93.84 % AVG Validation Acc 70.70 %
# Epoch:160/200 AVG Training Loss:0.133 AVG Validation Loss:1.191 AVG Training Acc 94.00 % AVG Validation Acc 70.43 %
# Epoch:170/200 AVG Training Loss:0.130 AVG Validation Loss:1.230 AVG Training Acc 94.12 % AVG Validation Acc 70.97 %
# Epoch   175: reducing learning rate of group 0 to 1.1859e-05.
# Epoch:180/200 AVG Training Loss:0.127 AVG Validation Loss:1.245 AVG Training Acc 94.10 % AVG Validation Acc 70.97 %
# Epoch:190/200 AVG Training Loss:0.126 AVG Validation Loss:1.260 AVG Training Acc 94.18 % AVG Validation Acc 70.97 %
# Epoch:200/200 AVG Training Loss:0.125 AVG Validation Loss:1.275 AVG Training Acc 94.19 % AVG Validation Acc 70.83 %
# Split 6
#   0%|          | 0/200 [00:00<?, ?it/s]
# Epoch:10/200 AVG Training Loss:0.679 AVG Validation Loss:0.674 AVG Training Acc 56.67 % AVG Validation Acc 47.85 %
# Epoch:20/200 AVG Training Loss:0.573 AVG Validation Loss:0.594 AVG Training Acc 72.75 % AVG Validation Acc 62.90 %
# Epoch:30/200 AVG Training Loss:0.522 AVG Validation Loss:0.546 AVG Training Acc 77.05 % AVG Validation Acc 69.49 %
# Epoch:40/200 AVG Training Loss:0.410 AVG Validation Loss:0.529 AVG Training Acc 81.36 % AVG Validation Acc 75.81 %
# Epoch:50/200 AVG Training Loss:0.329 AVG Validation Loss:0.515 AVG Training Acc 85.02 % AVG Validation Acc 76.75 %
# Epoch:60/200 AVG Training Loss:0.323 AVG Validation Loss:0.556 AVG Training Acc 85.01 % AVG Validation Acc 75.67 %
# Epoch:70/200 AVG Training Loss:0.262 AVG Validation Loss:0.547 AVG Training Acc 87.95 % AVG Validation Acc 74.33 %
# Epoch    78: reducing learning rate of group 0 to 3.3000e-04.
# Epoch:80/200 AVG Training Loss:0.232 AVG Validation Loss:0.549 AVG Training Acc 89.25 % AVG Validation Acc 76.48 %
# Epoch:90/200 AVG Training Loss:0.198 AVG Validation Loss:0.672 AVG Training Acc 90.70 % AVG Validation Acc 75.00 %
# Epoch:100/200 AVG Training Loss:0.186 AVG Validation Loss:0.807 AVG Training Acc 91.09 % AVG Validation Acc 75.67 %
# Epoch:110/200 AVG Training Loss:0.169 AVG Validation Loss:0.845 AVG Training Acc 92.17 % AVG Validation Acc 75.54 %
# Epoch   114: reducing learning rate of group 0 to 1.0890e-04.
# Epoch:120/200 AVG Training Loss:0.149 AVG Validation Loss:0.959 AVG Training Acc 92.89 % AVG Validation Acc 73.79 %
# Epoch:130/200 AVG Training Loss:0.138 AVG Validation Loss:1.024 AVG Training Acc 93.41 % AVG Validation Acc 74.73 %
# Epoch:140/200 AVG Training Loss:0.129 AVG Validation Loss:1.090 AVG Training Acc 93.91 % AVG Validation Acc 74.33 %
# Epoch:150/200 AVG Training Loss:0.121 AVG Validation Loss:1.132 AVG Training Acc 94.04 % AVG Validation Acc 72.85 %
# Epoch   150: reducing learning rate of group 0 to 3.5937e-05.
# Epoch:160/200 AVG Training Loss:0.114 AVG Validation Loss:1.142 AVG Training Acc 94.42 % AVG Validation Acc 74.73 %
# Epoch:170/200 AVG Training Loss:0.111 AVG Validation Loss:1.171 AVG Training Acc 94.37 % AVG Validation Acc 74.19 %
# Epoch:180/200 AVG Training Loss:0.109 AVG Validation Loss:1.200 AVG Training Acc 94.72 % AVG Validation Acc 73.79 %
# Epoch   186: reducing learning rate of group 0 to 1.1859e-05.
# Epoch:190/200 AVG Training Loss:0.105 AVG Validation Loss:1.225 AVG Training Acc 94.91 % AVG Validation Acc 75.27 %
# Epoch:200/200 AVG Training Loss:0.104 AVG Validation Loss:1.232 AVG Training Acc 94.86 % AVG Validation Acc 74.33 %
# Split 7
#   0%|          | 0/200 [00:00<?, ?it/s]
# Epoch:10/200 AVG Training Loss:0.651 AVG Validation Loss:0.610 AVG Training Acc 63.27 % AVG Validation Acc 54.10 %
# New Best F1_score found: 38.48%
# Epoch: 11
#  Accuracy: 60.83
# AUC: 62.68
# Epoch:20/200 AVG Training Loss:0.561 AVG Validation Loss:0.559 AVG Training Acc 73.59 % AVG Validation Acc 67.83 %
# Epoch:30/200 AVG Training Loss:0.467 AVG Validation Loss:0.598 AVG Training Acc 79.61 % AVG Validation Acc 68.51 %
# Epoch:40/200 AVG Training Loss:0.343 AVG Validation Loss:0.535 AVG Training Acc 84.43 % AVG Validation Acc 76.04 %
# Epoch    49: reducing learning rate of group 0 to 3.3000e-04.
# Epoch:50/200 AVG Training Loss:0.302 AVG Validation Loss:0.518 AVG Training Acc 86.27 % AVG Validation Acc 77.66 %
# Epoch:60/200 AVG Training Loss:0.274 AVG Validation Loss:0.576 AVG Training Acc 87.66 % AVG Validation Acc 76.04 %
# Epoch:70/200 AVG Training Loss:0.262 AVG Validation Loss:0.566 AVG Training Acc 88.21 % AVG Validation Acc 74.97 %
# Epoch:80/200 AVG Training Loss:0.241 AVG Validation Loss:0.630 AVG Training Acc 89.10 % AVG Validation Acc 73.76 %
# Epoch    85: reducing learning rate of group 0 to 1.0890e-04.
# Epoch:90/200 AVG Training Loss:0.219 AVG Validation Loss:0.631 AVG Training Acc 89.99 % AVG Validation Acc 73.62 %
# Epoch:100/200 AVG Training Loss:0.211 AVG Validation Loss:0.720 AVG Training Acc 90.25 % AVG Validation Acc 72.41 %
# Epoch:110/200 AVG Training Loss:0.200 AVG Validation Loss:0.785 AVG Training Acc 91.04 % AVG Validation Acc 72.81 %
# Epoch:120/200 AVG Training Loss:0.190 AVG Validation Loss:0.779 AVG Training Acc 91.31 % AVG Validation Acc 73.35 %
# Epoch   121: reducing learning rate of group 0 to 3.5937e-05.
# Epoch:130/200 AVG Training Loss:0.183 AVG Validation Loss:0.820 AVG Training Acc 91.53 % AVG Validation Acc 72.14 %
# Epoch:140/200 AVG Training Loss:0.179 AVG Validation Loss:0.845 AVG Training Acc 91.78 % AVG Validation Acc 71.74 %
# Epoch:150/200 AVG Training Loss:0.177 AVG Validation Loss:0.865 AVG Training Acc 91.91 % AVG Validation Acc 71.20 %
# Epoch   157: reducing learning rate of group 0 to 1.1859e-05.
# Epoch:160/200 AVG Training Loss:0.174 AVG Validation Loss:0.889 AVG Training Acc 91.99 % AVG Validation Acc 71.47 %
# Epoch:170/200 AVG Training Loss:0.172 AVG Validation Loss:0.893 AVG Training Acc 92.01 % AVG Validation Acc 71.20 %
# Epoch:180/200 AVG Training Loss:0.171 AVG Validation Loss:0.906 AVG Training Acc 92.06 % AVG Validation Acc 71.47 %
# Epoch:190/200 AVG Training Loss:0.171 AVG Validation Loss:0.916 AVG Training Acc 92.11 % AVG Validation Acc 71.33 %
# Epoch   193: reducing learning rate of group 0 to 3.9135e-06.
# Epoch:200/200 AVG Training Loss:0.168 AVG Validation Loss:0.923 AVG Training Acc 92.39 % AVG Validation Acc 71.74 %
# Split 8
#   0%|          | 0/200 [00:00<?, ?it/s]
# New Best F1_score found: 38.80%
# Epoch: 7
#  Accuracy: 53.30
# AUC: 65.17
# New Best F1_score found: 39.65%
# Epoch: 8
#  Accuracy: 53.70
# AUC: 66.36
# Epoch:10/200 AVG Training Loss:0.686 AVG Validation Loss:0.686 AVG Training Acc 53.84 % AVG Validation Acc 45.09 %
# New Best F1_score found: 39.83%
# Epoch: 17
#  Accuracy: 62.18
# AUC: 65.32
# New Best F1_score found: 41.53%
# Epoch: 18
#  Accuracy: 62.85
# AUC: 65.25
# Epoch:20/200 AVG Training Loss:0.576 AVG Validation Loss:0.526 AVG Training Acc 73.89 % AVG Validation Acc 67.97 %
# Epoch:30/200 AVG Training Loss:0.579 AVG Validation Loss:0.512 AVG Training Acc 73.93 % AVG Validation Acc 72.27 %
# Epoch:40/200 AVG Training Loss:0.389 AVG Validation Loss:0.516 AVG Training Acc 82.68 % AVG Validation Acc 76.31 %
# Epoch:50/200 AVG Training Loss:0.337 AVG Validation Loss:0.530 AVG Training Acc 84.90 % AVG Validation Acc 76.04 %
# Epoch:60/200 AVG Training Loss:0.305 AVG Validation Loss:0.515 AVG Training Acc 86.66 % AVG Validation Acc 76.31 %
# Epoch    60: reducing learning rate of group 0 to 3.3000e-04.
# Epoch:70/200 AVG Training Loss:0.267 AVG Validation Loss:0.542 AVG Training Acc 87.71 % AVG Validation Acc 73.89 %
# Epoch:80/200 AVG Training Loss:0.262 AVG Validation Loss:0.532 AVG Training Acc 87.94 % AVG Validation Acc 75.37 %
# Epoch:90/200 AVG Training Loss:0.235 AVG Validation Loss:0.566 AVG Training Acc 89.23 % AVG Validation Acc 75.10 %
# Epoch    96: reducing learning rate of group 0 to 1.0890e-04.
# Epoch:100/200 AVG Training Loss:0.204 AVG Validation Loss:0.629 AVG Training Acc 90.57 % AVG Validation Acc 73.62 %
# Epoch:110/200 AVG Training Loss:0.191 AVG Validation Loss:0.684 AVG Training Acc 91.32 % AVG Validation Acc 72.01 %
# Epoch:120/200 AVG Training Loss:0.185 AVG Validation Loss:0.725 AVG Training Acc 91.52 % AVG Validation Acc 72.68 %
# Epoch:130/200 AVG Training Loss:0.176 AVG Validation Loss:0.773 AVG Training Acc 91.85 % AVG Validation Acc 71.60 %
# Epoch   132: reducing learning rate of group 0 to 3.5937e-05.
# Epoch:140/200 AVG Training Loss:0.165 AVG Validation Loss:0.815 AVG Training Acc 92.24 % AVG Validation Acc 71.06 %
# Epoch:150/200 AVG Training Loss:0.161 AVG Validation Loss:0.832 AVG Training Acc 92.28 % AVG Validation Acc 71.06 %
# Epoch:160/200 AVG Training Loss:0.156 AVG Validation Loss:0.855 AVG Training Acc 92.75 % AVG Validation Acc 70.79 %
# Epoch   168: reducing learning rate of group 0 to 1.1859e-05.
# Epoch:170/200 AVG Training Loss:0.153 AVG Validation Loss:0.875 AVG Training Acc 92.98 % AVG Validation Acc 71.06 %
# Epoch:180/200 AVG Training Loss:0.151 AVG Validation Loss:0.882 AVG Training Acc 93.26 % AVG Validation Acc 70.79 %
# Epoch:190/200 AVG Training Loss:0.151 AVG Validation Loss:0.891 AVG Training Acc 93.20 % AVG Validation Acc 70.39 %
# Epoch:200/200 AVG Training Loss:0.149 AVG Validation Loss:0.898 AVG Training Acc 93.04 % AVG Validation Acc 70.39 %
# Split 9
#   0%|          | 0/200 [00:00<?, ?it/s]
# Epoch:10/200 AVG Training Loss:0.716 AVG Validation Loss:0.699 AVG Training Acc 52.50 % AVG Validation Acc 35.13 %
# Epoch:20/200 AVG Training Loss:0.615 AVG Validation Loss:0.575 AVG Training Acc 68.92 % AVG Validation Acc 61.51 %
# Epoch:30/200 AVG Training Loss:0.547 AVG Validation Loss:0.616 AVG Training Acc 74.67 % AVG Validation Acc 62.99 %
# Epoch:40/200 AVG Training Loss:0.462 AVG Validation Loss:0.506 AVG Training Acc 79.60 % AVG Validation Acc 74.56 %
# Epoch:50/200 AVG Training Loss:0.350 AVG Validation Loss:0.505 AVG Training Acc 83.90 % AVG Validation Acc 78.06 %
# Epoch:60/200 AVG Training Loss:0.314 AVG Validation Loss:0.522 AVG Training Acc 85.11 % AVG Validation Acc 77.79 %
# Epoch:70/200 AVG Training Loss:0.305 AVG Validation Loss:0.543 AVG Training Acc 85.65 % AVG Validation Acc 77.66 %
# Epoch    71: reducing learning rate of group 0 to 3.3000e-04.
# Epoch:80/200 AVG Training Loss:0.250 AVG Validation Loss:0.543 AVG Training Acc 88.44 % AVG Validation Acc 76.04 %
# Epoch:90/200 AVG Training Loss:0.232 AVG Validation Loss:0.602 AVG Training Acc 89.14 % AVG Validation Acc 74.56 %
# Epoch:100/200 AVG Training Loss:0.207 AVG Validation Loss:0.604 AVG Training Acc 90.18 % AVG Validation Acc 75.50 %
# Epoch   107: reducing learning rate of group 0 to 1.0890e-04.
# Epoch:110/200 AVG Training Loss:0.188 AVG Validation Loss:0.725 AVG Training Acc 91.11 % AVG Validation Acc 73.89 %
# Epoch:120/200 AVG Training Loss:0.172 AVG Validation Loss:0.773 AVG Training Acc 91.74 % AVG Validation Acc 75.37 %
# Epoch:130/200 AVG Training Loss:0.165 AVG Validation Loss:0.853 AVG Training Acc 91.96 % AVG Validation Acc 73.62 %
# Epoch:140/200 AVG Training Loss:0.153 AVG Validation Loss:0.883 AVG Training Acc 92.87 % AVG Validation Acc 71.60 %
# Epoch   143: reducing learning rate of group 0 to 3.5937e-05.
# Epoch:150/200 AVG Training Loss:0.144 AVG Validation Loss:0.956 AVG Training Acc 93.19 % AVG Validation Acc 73.76 %
# Epoch:160/200 AVG Training Loss:0.142 AVG Validation Loss:0.981 AVG Training Acc 93.15 % AVG Validation Acc 72.54 %
# Epoch:170/200 AVG Training Loss:0.137 AVG Validation Loss:1.008 AVG Training Acc 93.53 % AVG Validation Acc 72.68 %
# Epoch   179: reducing learning rate of group 0 to 1.1859e-05.
# Epoch:180/200 AVG Training Loss:0.133 AVG Validation Loss:1.026 AVG Training Acc 93.71 % AVG Validation Acc 72.27 %
# Epoch:190/200 AVG Training Loss:0.132 AVG Validation Loss:1.032 AVG Training Acc 93.64 % AVG Validation Acc 72.41 %
# Epoch:200/200 AVG Training Loss:0.132 AVG Validation Loss:1.040 AVG Training Acc 93.83 % AVG Validation Acc 72.14 %
# Split 10
#   0%|          | 0/200 [00:00<?, ?it/s]
# Epoch:10/200 AVG Training Loss:0.685 AVG Validation Loss:0.687 AVG Training Acc 56.55 % AVG Validation Acc 43.47 %
# Epoch:20/200 AVG Training Loss:0.574 AVG Validation Loss:0.805 AVG Training Acc 71.47 % AVG Validation Acc 55.05 %
# Epoch:30/200 AVG Training Loss:0.482 AVG Validation Loss:0.623 AVG Training Acc 78.44 % AVG Validation Acc 69.31 %
# Epoch:40/200 AVG Training Loss:0.361 AVG Validation Loss:0.538 AVG Training Acc 83.87 % AVG Validation Acc 74.83 %
# Epoch:50/200 AVG Training Loss:0.318 AVG Validation Loss:0.517 AVG Training Acc 85.37 % AVG Validation Acc 76.31 %
# Epoch    58: reducing learning rate of group 0 to 3.3000e-04.
# Epoch:60/200 AVG Training Loss:0.272 AVG Validation Loss:0.543 AVG Training Acc 87.13 % AVG Validation Acc 76.45 %
# Epoch:70/200 AVG Training Loss:0.244 AVG Validation Loss:0.631 AVG Training Acc 88.48 % AVG Validation Acc 76.45 %
# Epoch:80/200 AVG Training Loss:0.237 AVG Validation Loss:0.735 AVG Training Acc 88.65 % AVG Validation Acc 72.95 %
# Epoch:90/200 AVG Training Loss:0.197 AVG Validation Loss:0.690 AVG Training Acc 90.64 % AVG Validation Acc 72.95 %
# Epoch    94: reducing learning rate of group 0 to 1.0890e-04.
# Epoch:100/200 AVG Training Loss:0.178 AVG Validation Loss:0.866 AVG Training Acc 91.55 % AVG Validation Acc 73.35 %
# Epoch:110/200 AVG Training Loss:0.166 AVG Validation Loss:0.973 AVG Training Acc 92.29 % AVG Validation Acc 72.81 %
# Epoch:120/200 AVG Training Loss:0.167 AVG Validation Loss:1.004 AVG Training Acc 92.12 % AVG Validation Acc 70.66 %
# Epoch:130/200 AVG Training Loss:0.152 AVG Validation Loss:1.071 AVG Training Acc 92.51 % AVG Validation Acc 72.95 %
# Epoch   130: reducing learning rate of group 0 to 3.5937e-05.
# Epoch:140/200 AVG Training Loss:0.147 AVG Validation Loss:1.109 AVG Training Acc 92.97 % AVG Validation Acc 72.68 %
# Epoch:150/200 AVG Training Loss:0.144 AVG Validation Loss:1.134 AVG Training Acc 92.89 % AVG Validation Acc 72.81 %
# Epoch:160/200 AVG Training Loss:0.141 AVG Validation Loss:1.162 AVG Training Acc 93.12 % AVG Validation Acc 73.08 %
# Epoch   166: reducing learning rate of group 0 to 1.1859e-05.
# Epoch:170/200 AVG Training Loss:0.138 AVG Validation Loss:1.172 AVG Training Acc 93.47 % AVG Validation Acc 73.08 %
# Epoch:180/200 AVG Training Loss:0.137 AVG Validation Loss:1.183 AVG Training Acc 93.36 % AVG Validation Acc 72.54 %
# Epoch:190/200 AVG Training Loss:0.136 AVG Validation Loss:1.198 AVG Training Acc 93.39 % AVG Validation Acc 72.41 %
# Epoch:200/200 AVG Training Loss:0.134 AVG Validation Loss:1.207 AVG Training Acc 93.56 % AVG Validation Acc 72.14 %
# Replica 2
# 0it [00:00, ?it/s]
# Split 1
#   0%|          | 0/200 [00:00<?, ?it/s]
# New Best F1_score found: 2.55%
# Epoch: 3
#  Accuracy: 79.44
# AUC: 58.04
# New Best F1_score found: 4.97%
# Epoch: 4
#  Accuracy: 79.44
# AUC: 59.25
# New Best F1_score found: 25.42%
# Epoch: 5
#  Accuracy: 76.34
# AUC: 60.00
# New Best F1_score found: 34.83%
# Epoch: 6
#  Accuracy: 68.82
# AUC: 60.99
# New Best F1_score found: 36.36%
# Epoch: 7
#  Accuracy: 58.60
# AUC: 61.67
# New Best F1_score found: 36.63%
# Epoch: 8
#  Accuracy: 53.49
# AUC: 61.41
# Epoch:10/200 AVG Training Loss:0.690 AVG Validation Loss:0.667 AVG Training Acc 58.18 % AVG Validation Acc 49.60 %
# New Best F1_score found: 36.72%
# Epoch: 15
#  Accuracy: 56.45
# AUC: 63.83
# Epoch:20/200 AVG Training Loss:0.577 AVG Validation Loss:0.568 AVG Training Acc 71.66 % AVG Validation Acc 63.71 %
# New Best F1_score found: 36.97%
# Epoch: 22
#  Accuracy: 59.68
# AUC: 62.18
# Epoch:30/200 AVG Training Loss:0.552 AVG Validation Loss:0.534 AVG Training Acc 74.72 % AVG Validation Acc 74.19 %
# Epoch:40/200 AVG Training Loss:0.363 AVG Validation Loss:0.504 AVG Training Acc 83.26 % AVG Validation Acc 78.09 %
# Epoch:50/200 AVG Training Loss:0.319 AVG Validation Loss:0.519 AVG Training Acc 85.38 % AVG Validation Acc 76.88 %
# Epoch    54: reducing learning rate of group 0 to 3.3000e-04.
# Epoch:60/200 AVG Training Loss:0.284 AVG Validation Loss:0.526 AVG Training Acc 86.56 % AVG Validation Acc 78.63 %
# Epoch:70/200 AVG Training Loss:0.262 AVG Validation Loss:0.562 AVG Training Acc 87.82 % AVG Validation Acc 77.02 %
# Epoch:80/200 AVG Training Loss:0.251 AVG Validation Loss:0.657 AVG Training Acc 88.64 % AVG Validation Acc 77.96 %
# Epoch:90/200 AVG Training Loss:0.238 AVG Validation Loss:0.709 AVG Training Acc 88.86 % AVG Validation Acc 72.04 %
# Epoch    90: reducing learning rate of group 0 to 1.0890e-04.
# Epoch:100/200 AVG Training Loss:0.208 AVG Validation Loss:0.668 AVG Training Acc 90.43 % AVG Validation Acc 76.21 %
# Epoch:110/200 AVG Training Loss:0.198 AVG Validation Loss:0.712 AVG Training Acc 90.66 % AVG Validation Acc 76.21 %
# Epoch:120/200 AVG Training Loss:0.190 AVG Validation Loss:0.790 AVG Training Acc 90.79 % AVG Validation Acc 74.46 %
# Epoch   126: reducing learning rate of group 0 to 3.5937e-05.
# Epoch:130/200 AVG Training Loss:0.181 AVG Validation Loss:0.780 AVG Training Acc 91.46 % AVG Validation Acc 76.08 %
# Epoch:140/200 AVG Training Loss:0.175 AVG Validation Loss:0.799 AVG Training Acc 91.69 % AVG Validation Acc 75.27 %
# Epoch:150/200 AVG Training Loss:0.174 AVG Validation Loss:0.796 AVG Training Acc 91.80 % AVG Validation Acc 74.87 %
# Epoch:160/200 AVG Training Loss:0.169 AVG Validation Loss:0.813 AVG Training Acc 92.03 % AVG Validation Acc 75.13 %
# Epoch   162: reducing learning rate of group 0 to 1.1859e-05.
# Epoch:170/200 AVG Training Loss:0.167 AVG Validation Loss:0.817 AVG Training Acc 92.05 % AVG Validation Acc 74.73 %
# Epoch:180/200 AVG Training Loss:0.165 AVG Validation Loss:0.821 AVG Training Acc 92.19 % AVG Validation Acc 75.00 %
# Epoch:190/200 AVG Training Loss:0.164 AVG Validation Loss:0.822 AVG Training Acc 91.92 % AVG Validation Acc 75.67 %
# Epoch   198: reducing learning rate of group 0 to 3.9135e-06.
# Epoch:200/200 AVG Training Loss:0.163 AVG Validation Loss:0.828 AVG Training Acc 92.20 % AVG Validation Acc 75.13 %
# Split 2
#   0%|          | 0/200 [00:00<?, ?it/s]
# Epoch:10/200 AVG Training Loss:0.683 AVG Validation Loss:0.674 AVG Training Acc 55.14 % AVG Validation Acc 55.51 %
# Epoch:20/200 AVG Training Loss:0.590 AVG Validation Loss:0.586 AVG Training Acc 71.99 % AVG Validation Acc 62.90 %
# Epoch:30/200 AVG Training Loss:0.574 AVG Validation Loss:0.563 AVG Training Acc 73.86 % AVG Validation Acc 67.61 %
# Epoch:40/200 AVG Training Loss:0.492 AVG Validation Loss:0.560 AVG Training Acc 78.61 % AVG Validation Acc 71.77 %
# Epoch:50/200 AVG Training Loss:0.368 AVG Validation Loss:0.540 AVG Training Acc 84.21 % AVG Validation Acc 75.00 %
# Epoch:60/200 AVG Training Loss:0.337 AVG Validation Loss:0.508 AVG Training Acc 85.09 % AVG Validation Acc 77.42 %
# Epoch:70/200 AVG Training Loss:0.315 AVG Validation Loss:0.518 AVG Training Acc 85.87 % AVG Validation Acc 77.55 %
# Epoch    75: reducing learning rate of group 0 to 3.3000e-04.
# Epoch:80/200 AVG Training Loss:0.285 AVG Validation Loss:0.547 AVG Training Acc 86.86 % AVG Validation Acc 77.96 %
# Epoch:90/200 AVG Training Loss:0.272 AVG Validation Loss:0.573 AVG Training Acc 87.32 % AVG Validation Acc 77.69 %
# Epoch:100/200 AVG Training Loss:0.262 AVG Validation Loss:0.603 AVG Training Acc 87.90 % AVG Validation Acc 78.49 %
# Epoch:110/200 AVG Training Loss:0.236 AVG Validation Loss:0.672 AVG Training Acc 89.12 % AVG Validation Acc 77.55 %
# Epoch   111: reducing learning rate of group 0 to 1.0890e-04.
# Epoch:120/200 AVG Training Loss:0.219 AVG Validation Loss:0.678 AVG Training Acc 89.78 % AVG Validation Acc 74.73 %
# Epoch:130/200 AVG Training Loss:0.211 AVG Validation Loss:0.724 AVG Training Acc 90.33 % AVG Validation Acc 73.92 %
# Epoch:140/200 AVG Training Loss:0.212 AVG Validation Loss:0.804 AVG Training Acc 89.93 % AVG Validation Acc 71.24 %
# Epoch   147: reducing learning rate of group 0 to 3.5937e-05.
# Epoch:150/200 AVG Training Loss:0.190 AVG Validation Loss:0.801 AVG Training Acc 91.19 % AVG Validation Acc 74.60 %
# Epoch:160/200 AVG Training Loss:0.187 AVG Validation Loss:0.820 AVG Training Acc 91.41 % AVG Validation Acc 74.73 %
# Epoch:170/200 AVG Training Loss:0.183 AVG Validation Loss:0.835 AVG Training Acc 91.77 % AVG Validation Acc 74.60 %
# Epoch:180/200 AVG Training Loss:0.182 AVG Validation Loss:0.854 AVG Training Acc 91.78 % AVG Validation Acc 74.06 %
# Epoch   183: reducing learning rate of group 0 to 1.1859e-05.
# Epoch:190/200 AVG Training Loss:0.178 AVG Validation Loss:0.864 AVG Training Acc 91.75 % AVG Validation Acc 74.06 %
# Epoch:200/200 AVG Training Loss:0.177 AVG Validation Loss:0.871 AVG Training Acc 91.83 % AVG Validation Acc 74.06 %
# Split 3
#   0%|          | 0/200 [00:00<?, ?it/s]
# New Best F1_score found: 38.65%
# Epoch: 8
#  Accuracy: 53.49
# AUC: 63.89
# Epoch:10/200 AVG Training Loss:0.690 AVG Validation Loss:0.658 AVG Training Acc 58.44 % AVG Validation Acc 50.94 %
# Epoch:20/200 AVG Training Loss:0.598 AVG Validation Loss:0.601 AVG Training Acc 70.65 % AVG Validation Acc 60.62 %
# Epoch:30/200 AVG Training Loss:0.529 AVG Validation Loss:0.543 AVG Training Acc 75.19 % AVG Validation Acc 70.70 %
# Epoch:40/200 AVG Training Loss:0.367 AVG Validation Loss:0.510 AVG Training Acc 83.17 % AVG Validation Acc 77.42 %
# Epoch:50/200 AVG Training Loss:0.326 AVG Validation Loss:0.514 AVG Training Acc 85.54 % AVG Validation Acc 76.34 %
# Epoch    53: reducing learning rate of group 0 to 3.3000e-04.
# Epoch:60/200 AVG Training Loss:0.281 AVG Validation Loss:0.518 AVG Training Acc 87.41 % AVG Validation Acc 76.34 %
# Epoch:70/200 AVG Training Loss:0.261 AVG Validation Loss:0.572 AVG Training Acc 88.03 % AVG Validation Acc 75.00 %
# Epoch:80/200 AVG Training Loss:0.237 AVG Validation Loss:0.565 AVG Training Acc 89.08 % AVG Validation Acc 75.13 %
# Epoch    89: reducing learning rate of group 0 to 1.0890e-04.
# Epoch:90/200 AVG Training Loss:0.222 AVG Validation Loss:0.582 AVG Training Acc 89.58 % AVG Validation Acc 75.27 %
# Epoch:100/200 AVG Training Loss:0.200 AVG Validation Loss:0.619 AVG Training Acc 90.76 % AVG Validation Acc 76.08 %
# Epoch:110/200 AVG Training Loss:0.191 AVG Validation Loss:0.656 AVG Training Acc 91.32 % AVG Validation Acc 77.02 %
# Epoch:120/200 AVG Training Loss:0.180 AVG Validation Loss:0.680 AVG Training Acc 91.94 % AVG Validation Acc 76.88 %
# Epoch   125: reducing learning rate of group 0 to 3.5937e-05.
# Epoch:130/200 AVG Training Loss:0.171 AVG Validation Loss:0.702 AVG Training Acc 92.13 % AVG Validation Acc 76.88 %
# Epoch:140/200 AVG Training Loss:0.166 AVG Validation Loss:0.716 AVG Training Acc 92.38 % AVG Validation Acc 76.48 %
# Epoch:150/200 AVG Training Loss:0.162 AVG Validation Loss:0.724 AVG Training Acc 92.64 % AVG Validation Acc 76.61 %
# Epoch:160/200 AVG Training Loss:0.159 AVG Validation Loss:0.740 AVG Training Acc 92.75 % AVG Validation Acc 77.02 %
# Epoch   161: reducing learning rate of group 0 to 1.1859e-05.
# Epoch:170/200 AVG Training Loss:0.158 AVG Validation Loss:0.747 AVG Training Acc 92.86 % AVG Validation Acc 77.02 %
# Epoch:180/200 AVG Training Loss:0.158 AVG Validation Loss:0.757 AVG Training Acc 92.83 % AVG Validation Acc 77.02 %
# Epoch:190/200 AVG Training Loss:0.155 AVG Validation Loss:0.761 AVG Training Acc 92.91 % AVG Validation Acc 77.15 %
# Epoch   197: reducing learning rate of group 0 to 3.9135e-06.
# Epoch:200/200 AVG Training Loss:0.154 AVG Validation Loss:0.769 AVG Training Acc 93.04 % AVG Validation Acc 76.88 %
# Split 4
#   0%|          | 0/200 [00:00<?, ?it/s]
# Epoch:10/200 AVG Training Loss:0.669 AVG Validation Loss:0.623 AVG Training Acc 58.21 % AVG Validation Acc 51.21 %
# Epoch:20/200 AVG Training Loss:0.562 AVG Validation Loss:0.602 AVG Training Acc 74.20 % AVG Validation Acc 62.63 %
# Epoch:30/200 AVG Training Loss:0.489 AVG Validation Loss:0.537 AVG Training Acc 78.11 % AVG Validation Acc 74.87 %
# Epoch:40/200 AVG Training Loss:0.342 AVG Validation Loss:0.521 AVG Training Acc 84.73 % AVG Validation Acc 77.69 %
# Epoch:50/200 AVG Training Loss:0.295 AVG Validation Loss:0.529 AVG Training Acc 86.42 % AVG Validation Acc 77.02 %
# Epoch:60/200 AVG Training Loss:0.266 AVG Validation Loss:0.662 AVG Training Acc 87.82 % AVG Validation Acc 73.92 %
# Epoch    62: reducing learning rate of group 0 to 3.3000e-04.
# Epoch:70/200 AVG Training Loss:0.224 AVG Validation Loss:0.648 AVG Training Acc 89.77 % AVG Validation Acc 77.69 %
# Epoch:80/200 AVG Training Loss:0.205 AVG Validation Loss:0.714 AVG Training Acc 90.65 % AVG Validation Acc 74.73 %
# Epoch:90/200 AVG Training Loss:0.188 AVG Validation Loss:0.761 AVG Training Acc 91.28 % AVG Validation Acc 70.70 %
# Epoch    98: reducing learning rate of group 0 to 1.0890e-04.
# Epoch:100/200 AVG Training Loss:0.153 AVG Validation Loss:0.890 AVG Training Acc 92.80 % AVG Validation Acc 73.79 %
# Epoch:110/200 AVG Training Loss:0.142 AVG Validation Loss:0.975 AVG Training Acc 93.37 % AVG Validation Acc 73.92 %
# Epoch:120/200 AVG Training Loss:0.132 AVG Validation Loss:1.065 AVG Training Acc 93.65 % AVG Validation Acc 74.19 %
# Epoch:130/200 AVG Training Loss:0.129 AVG Validation Loss:1.050 AVG Training Acc 93.80 % AVG Validation Acc 74.87 %
# Epoch   134: reducing learning rate of group 0 to 3.5937e-05.
# Epoch:140/200 AVG Training Loss:0.120 AVG Validation Loss:1.139 AVG Training Acc 94.19 % AVG Validation Acc 74.19 %
# Epoch:150/200 AVG Training Loss:0.117 AVG Validation Loss:1.178 AVG Training Acc 94.42 % AVG Validation Acc 74.73 %
# Epoch:160/200 AVG Training Loss:0.113 AVG Validation Loss:1.216 AVG Training Acc 94.54 % AVG Validation Acc 74.87 %
# Epoch:170/200 AVG Training Loss:0.111 AVG Validation Loss:1.236 AVG Training Acc 94.62 % AVG Validation Acc 74.87 %
# Epoch   170: reducing learning rate of group 0 to 1.1859e-05.
# Epoch:180/200 AVG Training Loss:0.109 AVG Validation Loss:1.253 AVG Training Acc 94.70 % AVG Validation Acc 74.60 %
# Epoch:190/200 AVG Training Loss:0.108 AVG Validation Loss:1.260 AVG Training Acc 94.84 % AVG Validation Acc 74.73 %
# Epoch:200/200 AVG Training Loss:0.107 AVG Validation Loss:1.272 AVG Training Acc 94.84 % AVG Validation Acc 74.87 %
# Split 5
#   0%|          | 0/200 [00:00<?, ?it/s]
# Epoch:10/200 AVG Training Loss:0.672 AVG Validation Loss:0.645 AVG Training Acc 57.01 % AVG Validation Acc 47.45 %
# Epoch:20/200 AVG Training Loss:0.568 AVG Validation Loss:0.592 AVG Training Acc 73.16 % AVG Validation Acc 62.10 %
# Epoch:30/200 AVG Training Loss:0.472 AVG Validation Loss:0.795 AVG Training Acc 77.81 % AVG Validation Acc 65.59 %
# Epoch:40/200 AVG Training Loss:0.339 AVG Validation Loss:0.515 AVG Training Acc 84.44 % AVG Validation Acc 77.82 %
# Epoch:50/200 AVG Training Loss:0.312 AVG Validation Loss:0.524 AVG Training Acc 85.83 % AVG Validation Acc 77.69 %
# Epoch    53: reducing learning rate of group 0 to 3.3000e-04.
# Epoch:60/200 AVG Training Loss:0.258 AVG Validation Loss:0.564 AVG Training Acc 88.06 % AVG Validation Acc 75.94 %
# Epoch:70/200 AVG Training Loss:0.253 AVG Validation Loss:0.570 AVG Training Acc 88.40 % AVG Validation Acc 76.08 %
# Epoch:80/200 AVG Training Loss:0.226 AVG Validation Loss:0.696 AVG Training Acc 89.68 % AVG Validation Acc 72.72 %
# Epoch    89: reducing learning rate of group 0 to 1.0890e-04.
# Epoch:90/200 AVG Training Loss:0.197 AVG Validation Loss:0.697 AVG Training Acc 90.97 % AVG Validation Acc 73.52 %
# Epoch:100/200 AVG Training Loss:0.179 AVG Validation Loss:0.787 AVG Training Acc 91.91 % AVG Validation Acc 73.39 %
# Epoch:110/200 AVG Training Loss:0.167 AVG Validation Loss:0.863 AVG Training Acc 92.30 % AVG Validation Acc 73.52 %
# Epoch:120/200 AVG Training Loss:0.157 AVG Validation Loss:0.965 AVG Training Acc 92.73 % AVG Validation Acc 73.25 %
# Epoch   125: reducing learning rate of group 0 to 3.5937e-05.
# Epoch:130/200 AVG Training Loss:0.149 AVG Validation Loss:0.996 AVG Training Acc 93.15 % AVG Validation Acc 72.04 %
# Epoch:140/200 AVG Training Loss:0.144 AVG Validation Loss:1.025 AVG Training Acc 93.40 % AVG Validation Acc 72.18 %
# Epoch:150/200 AVG Training Loss:0.140 AVG Validation Loss:1.063 AVG Training Acc 93.46 % AVG Validation Acc 72.58 %
# Epoch:160/200 AVG Training Loss:0.137 AVG Validation Loss:1.096 AVG Training Acc 93.63 % AVG Validation Acc 72.18 %
# Epoch   161: reducing learning rate of group 0 to 1.1859e-05.
# Epoch:170/200 AVG Training Loss:0.136 AVG Validation Loss:1.100 AVG Training Acc 93.75 % AVG Validation Acc 72.58 %
# Epoch:180/200 AVG Training Loss:0.134 AVG Validation Loss:1.115 AVG Training Acc 93.80 % AVG Validation Acc 72.58 %
# Epoch:190/200 AVG Training Loss:0.134 AVG Validation Loss:1.128 AVG Training Acc 93.77 % AVG Validation Acc 72.58 %
# Epoch   197: reducing learning rate of group 0 to 3.9135e-06.
# Epoch:200/200 AVG Training Loss:0.132 AVG Validation Loss:1.133 AVG Training Acc 93.75 % AVG Validation Acc 72.45 %
# Split 6
#   0%|          | 0/200 [00:00<?, ?it/s]
# Epoch:10/200 AVG Training Loss:0.685 AVG Validation Loss:0.687 AVG Training Acc 57.63 % AVG Validation Acc 45.16 %
# Epoch:20/200 AVG Training Loss:0.589 AVG Validation Loss:0.581 AVG Training Acc 70.98 % AVG Validation Acc 61.83 %
# Epoch:30/200 AVG Training Loss:0.588 AVG Validation Loss:0.523 AVG Training Acc 74.38 % AVG Validation Acc 71.51 %
# Epoch:40/200 AVG Training Loss:0.386 AVG Validation Loss:0.532 AVG Training Acc 82.77 % AVG Validation Acc 77.02 %
# Epoch    46: reducing learning rate of group 0 to 3.3000e-04.
# Epoch:50/200 AVG Training Loss:0.323 AVG Validation Loss:0.521 AVG Training Acc 85.18 % AVG Validation Acc 77.15 %
# Epoch:60/200 AVG Training Loss:0.309 AVG Validation Loss:0.522 AVG Training Acc 85.72 % AVG Validation Acc 76.75 %
# Epoch:70/200 AVG Training Loss:0.292 AVG Validation Loss:0.533 AVG Training Acc 86.59 % AVG Validation Acc 76.08 %
# Epoch:80/200 AVG Training Loss:0.276 AVG Validation Loss:0.526 AVG Training Acc 87.03 % AVG Validation Acc 77.15 %
# Epoch:90/200 AVG Training Loss:0.271 AVG Validation Loss:0.542 AVG Training Acc 87.36 % AVG Validation Acc 76.48 %
# Epoch    93: reducing learning rate of group 0 to 1.0890e-04.
# Epoch:100/200 AVG Training Loss:0.240 AVG Validation Loss:0.571 AVG Training Acc 88.85 % AVG Validation Acc 77.42 %
# Epoch:110/200 AVG Training Loss:0.230 AVG Validation Loss:0.598 AVG Training Acc 89.06 % AVG Validation Acc 76.34 %
# Epoch:120/200 AVG Training Loss:0.223 AVG Validation Loss:0.654 AVG Training Acc 89.63 % AVG Validation Acc 74.73 %
# Epoch   129: reducing learning rate of group 0 to 3.5937e-05.
# Epoch:130/200 AVG Training Loss:0.219 AVG Validation Loss:0.651 AVG Training Acc 89.63 % AVG Validation Acc 75.94 %
# Epoch:140/200 AVG Training Loss:0.206 AVG Validation Loss:0.689 AVG Training Acc 90.32 % AVG Validation Acc 75.81 %
# Epoch:150/200 AVG Training Loss:0.204 AVG Validation Loss:0.713 AVG Training Acc 90.50 % AVG Validation Acc 75.27 %
# Epoch:160/200 AVG Training Loss:0.201 AVG Validation Loss:0.734 AVG Training Acc 90.48 % AVG Validation Acc 75.13 %
# Epoch   165: reducing learning rate of group 0 to 1.1859e-05.
# Epoch:170/200 AVG Training Loss:0.197 AVG Validation Loss:0.749 AVG Training Acc 90.79 % AVG Validation Acc 75.27 %
# Epoch:180/200 AVG Training Loss:0.196 AVG Validation Loss:0.758 AVG Training Acc 90.72 % AVG Validation Acc 75.27 %
# Epoch:190/200 AVG Training Loss:0.195 AVG Validation Loss:0.770 AVG Training Acc 90.79 % AVG Validation Acc 74.33 %
# Epoch:200/200 AVG Training Loss:0.194 AVG Validation Loss:0.776 AVG Training Acc 90.75 % AVG Validation Acc 74.73 %
# Split 7
#   0%|          | 0/200 [00:00<?, ?it/s]
# Epoch:10/200 AVG Training Loss:0.676 AVG Validation Loss:0.681 AVG Training Acc 57.58 % AVG Validation Acc 47.64 %
# Epoch:20/200 AVG Training Loss:0.575 AVG Validation Loss:0.572 AVG Training Acc 71.77 % AVG Validation Acc 64.33 %
# Epoch:30/200 AVG Training Loss:0.466 AVG Validation Loss:0.728 AVG Training Acc 78.83 % AVG Validation Acc 67.56 %
# Epoch:40/200 AVG Training Loss:0.355 AVG Validation Loss:0.531 AVG Training Acc 83.92 % AVG Validation Acc 77.12 %
# Epoch:50/200 AVG Training Loss:0.322 AVG Validation Loss:0.533 AVG Training Acc 85.36 % AVG Validation Acc 76.18 %
# Epoch    52: reducing learning rate of group 0 to 3.3000e-04.
# Epoch:60/200 AVG Training Loss:0.290 AVG Validation Loss:0.531 AVG Training Acc 86.38 % AVG Validation Acc 77.25 %
# Epoch:70/200 AVG Training Loss:0.272 AVG Validation Loss:0.529 AVG Training Acc 87.30 % AVG Validation Acc 77.66 %
# Epoch:80/200 AVG Training Loss:0.256 AVG Validation Loss:0.588 AVG Training Acc 87.74 % AVG Validation Acc 76.18 %
# Epoch    88: reducing learning rate of group 0 to 1.0890e-04.
# Epoch:90/200 AVG Training Loss:0.234 AVG Validation Loss:0.615 AVG Training Acc 88.73 % AVG Validation Acc 73.49 %
# Epoch:100/200 AVG Training Loss:0.219 AVG Validation Loss:0.685 AVG Training Acc 89.55 % AVG Validation Acc 72.81 %
# Epoch:110/200 AVG Training Loss:0.219 AVG Validation Loss:0.685 AVG Training Acc 89.49 % AVG Validation Acc 73.35 %
# Epoch:120/200 AVG Training Loss:0.199 AVG Validation Loss:0.784 AVG Training Acc 90.65 % AVG Validation Acc 72.68 %
# Epoch   124: reducing learning rate of group 0 to 3.5937e-05.
# Epoch:130/200 AVG Training Loss:0.192 AVG Validation Loss:0.834 AVG Training Acc 90.88 % AVG Validation Acc 72.27 %
# Epoch:140/200 AVG Training Loss:0.188 AVG Validation Loss:0.848 AVG Training Acc 91.12 % AVG Validation Acc 72.27 %
# Epoch:150/200 AVG Training Loss:0.185 AVG Validation Loss:0.869 AVG Training Acc 91.24 % AVG Validation Acc 72.54 %
# Epoch:160/200 AVG Training Loss:0.181 AVG Validation Loss:0.903 AVG Training Acc 91.38 % AVG Validation Acc 72.01 %
# Epoch   160: reducing learning rate of group 0 to 1.1859e-05.
# Epoch:170/200 AVG Training Loss:0.179 AVG Validation Loss:0.908 AVG Training Acc 91.34 % AVG Validation Acc 72.27 %
# Epoch:180/200 AVG Training Loss:0.178 AVG Validation Loss:0.918 AVG Training Acc 91.27 % AVG Validation Acc 72.14 %
# Epoch:190/200 AVG Training Loss:0.177 AVG Validation Loss:0.931 AVG Training Acc 91.51 % AVG Validation Acc 72.41 %
# Epoch   196: reducing learning rate of group 0 to 3.9135e-06.
# Epoch:200/200 AVG Training Loss:0.176 AVG Validation Loss:0.938 AVG Training Acc 91.48 % AVG Validation Acc 71.87 %
# Split 8
#   0%|          | 0/200 [00:00<?, ?it/s]
# New Best F1_score found: 40.54%
# Epoch: 7
#  Accuracy: 70.39
# AUC: 64.32
# Epoch:10/200 AVG Training Loss:0.678 AVG Validation Loss:0.640 AVG Training Acc 54.84 % AVG Validation Acc 59.35 %
# Epoch:20/200 AVG Training Loss:0.619 AVG Validation Loss:0.538 AVG Training Acc 68.43 % AVG Validation Acc 68.10 %
# New Best F1_score found: 41.07%
# Epoch: 28
#  Accuracy: 61.37
# AUC: 64.24
# Epoch:30/200 AVG Training Loss:0.595 AVG Validation Loss:0.535 AVG Training Acc 73.42 % AVG Validation Acc 75.10 %
# Epoch:40/200 AVG Training Loss:0.365 AVG Validation Loss:0.505 AVG Training Acc 83.88 % AVG Validation Acc 77.39 %
# Epoch:50/200 AVG Training Loss:0.333 AVG Validation Loss:0.510 AVG Training Acc 85.10 % AVG Validation Acc 76.72 %
# Epoch    57: reducing learning rate of group 0 to 3.3000e-04.
# Epoch:60/200 AVG Training Loss:0.285 AVG Validation Loss:0.505 AVG Training Acc 86.82 % AVG Validation Acc 76.99 %
# Epoch:70/200 AVG Training Loss:0.263 AVG Validation Loss:0.531 AVG Training Acc 87.85 % AVG Validation Acc 74.56 %
# Epoch:80/200 AVG Training Loss:0.244 AVG Validation Loss:0.596 AVG Training Acc 88.78 % AVG Validation Acc 75.77 %
# Epoch:90/200 AVG Training Loss:0.228 AVG Validation Loss:0.618 AVG Training Acc 89.49 % AVG Validation Acc 72.68 %
# Epoch    93: reducing learning rate of group 0 to 1.0890e-04.
# Epoch:100/200 AVG Training Loss:0.206 AVG Validation Loss:0.618 AVG Training Acc 90.58 % AVG Validation Acc 74.97 %
# Epoch:110/200 AVG Training Loss:0.195 AVG Validation Loss:0.656 AVG Training Acc 91.12 % AVG Validation Acc 73.89 %
# ...
# AUC: 59.63
# New Best F1_score found: 44.28%
# Epoch: 11
#  Accuracy: 59.41
# AUC: 60.27
# Epoch    17: reducing learning rate of group 0 to 3.3000e-04.
# Epoch:20/200 AVG Training Loss:0.610 AVG Validation Loss:0.695 AVG Training Acc 68.85 % AVG Validation Acc 59.54 %
# Epoch:30/200 AVG Training Loss:0.487 AVG Validation Loss:0.629 AVG Training Acc 76.57 % AVG Validation Acc 70.97 %
# Epoch:40/200 AVG Training Loss:0.457 AVG Validation Loss:0.594 AVG Training Acc 78.78 % AVG Validation Acc 71.24 %
# Epoch:50/200 AVG Training Loss:0.429 AVG Validation Loss:0.601 AVG Training Acc 79.65 % AVG Validation Acc 71.77 %
# Epoch    53: reducing learning rate of group 0 to 1.0890e-04.
# Epoch:60/200 AVG Training Loss:0.414 AVG Validation Loss:0.597 AVG Training Acc 80.61 % AVG Validation Acc 71.64 %
# Epoch:70/200 AVG Training Loss:0.408 AVG Validation Loss:0.603 AVG Training Acc 80.95 % AVG Validation Acc 71.91 %
# Epoch:80/200 AVG Training Loss:0.402 AVG Validation Loss:0.612 AVG Training Acc 81.23 % AVG Validation Acc 72.04 %
# Epoch    89: reducing learning rate of group 0 to 3.5937e-05.
# Epoch:90/200 AVG Training Loss:0.393 AVG Validation Loss:0.618 AVG Training Acc 81.79 % AVG Validation Acc 71.77 %
# Epoch:100/200 AVG Training Loss:0.390 AVG Validation Loss:0.629 AVG Training Acc 81.88 % AVG Validation Acc 72.04 %
# Epoch:110/200 AVG Training Loss:0.389 AVG Validation Loss:0.637 AVG Training Acc 81.99 % AVG Validation Acc 71.64 %
# Epoch:120/200 AVG Training Loss:0.385 AVG Validation Loss:0.644 AVG Training Acc 82.26 % AVG Validation Acc 71.64 %
# Epoch   125: reducing learning rate of group 0 to 1.1859e-05.
# Epoch:130/200 AVG Training Loss:0.385 AVG Validation Loss:0.650 AVG Training Acc 82.46 % AVG Validation Acc 71.77 %
# Epoch:140/200 AVG Training Loss:0.382 AVG Validation Loss:0.652 AVG Training Acc 82.53 % AVG Validation Acc 71.64 %
# Epoch:150/200 AVG Training Loss:0.380 AVG Validation Loss:0.655 AVG Training Acc 82.66 % AVG Validation Acc 71.37 %
# Epoch:160/200 AVG Training Loss:0.380 AVG Validation Loss:0.657 AVG Training Acc 82.40 % AVG Validation Acc 71.64 %
# Epoch   161: reducing learning rate of group 0 to 3.9135e-06.
# Epoch:170/200 AVG Training Loss:0.379 AVG Validation Loss:0.660 AVG Training Acc 82.58 % AVG Validation Acc 71.64 %
# Epoch:180/200 AVG Training Loss:0.379 AVG Validation Loss:0.660 AVG Training Acc 82.63 % AVG Validation Acc 71.64 %
# Epoch:190/200 AVG Training Loss:0.380 AVG Validation Loss:0.661 AVG Training Acc 82.65 % AVG Validation Acc 71.64 %
# Epoch   197: reducing learning rate of group 0 to 1.2915e-06.
# Epoch:200/200 AVG Training Loss:0.378 AVG Validation Loss:0.661 AVG Training Acc 82.80 % AVG Validation Acc 71.64 %
# Split 6
#   0%|          | 0/200 [00:00<?, ?it/s]
# Epoch:10/200 AVG Training Loss:0.689 AVG Validation Loss:0.684 AVG Training Acc 53.43 % AVG Validation Acc 58.33 %
# Epoch    17: reducing learning rate of group 0 to 3.3000e-04.
# Epoch:20/200 AVG Training Loss:0.586 AVG Validation Loss:0.652 AVG Training Acc 71.96 % AVG Validation Acc 68.15 %
# Epoch:30/200 AVG Training Loss:0.486 AVG Validation Loss:0.621 AVG Training Acc 76.79 % AVG Validation Acc 70.70 %
# Epoch:40/200 AVG Training Loss:0.450 AVG Validation Loss:0.608 AVG Training Acc 78.07 % AVG Validation Acc 71.37 %
# Epoch:50/200 AVG Training Loss:0.439 AVG Validation Loss:0.598 AVG Training Acc 79.28 % AVG Validation Acc 71.51 %
# Epoch:60/200 AVG Training Loss:0.427 AVG Validation Loss:0.597 AVG Training Acc 79.85 % AVG Validation Acc 71.77 %
# Epoch:70/200 AVG Training Loss:0.408 AVG Validation Loss:0.600 AVG Training Acc 80.73 % AVG Validation Acc 71.24 %
# Epoch    77: reducing learning rate of group 0 to 1.0890e-04.
# Epoch:80/200 AVG Training Loss:0.394 AVG Validation Loss:0.609 AVG Training Acc 81.66 % AVG Validation Acc 71.51 %
# Epoch:90/200 AVG Training Loss:0.387 AVG Validation Loss:0.629 AVG Training Acc 82.07 % AVG Validation Acc 71.10 %
# Epoch:100/200 AVG Training Loss:0.379 AVG Validation Loss:0.656 AVG Training Acc 82.48 % AVG Validation Acc 70.16 %
# Epoch:110/200 AVG Training Loss:0.378 AVG Validation Loss:0.647 AVG Training Acc 82.50 % AVG Validation Acc 70.56 %
# Epoch   113: reducing learning rate of group 0 to 3.5937e-05.
# Epoch:120/200 AVG Training Loss:0.366 AVG Validation Loss:0.701 AVG Training Acc 83.29 % AVG Validation Acc 70.70 %
# Epoch:130/200 AVG Training Loss:0.362 AVG Validation Loss:0.724 AVG Training Acc 83.58 % AVG Validation Acc 71.10 %
# Epoch:140/200 AVG Training Loss:0.359 AVG Validation Loss:0.735 AVG Training Acc 83.66 % AVG Validation Acc 71.10 %
# Epoch   149: reducing learning rate of group 0 to 1.1859e-05.
# Epoch:150/200 AVG Training Loss:0.356 AVG Validation Loss:0.750 AVG Training Acc 83.78 % AVG Validation Acc 70.70 %
# Epoch:160/200 AVG Training Loss:0.355 AVG Validation Loss:0.753 AVG Training Acc 83.91 % AVG Validation Acc 70.56 %
# Epoch:170/200 AVG Training Loss:0.354 AVG Validation Loss:0.755 AVG Training Acc 83.91 % AVG Validation Acc 70.70 %
# Epoch:180/200 AVG Training Loss:0.351 AVG Validation Loss:0.764 AVG Training Acc 83.99 % AVG Validation Acc 70.70 %
# Epoch   185: reducing learning rate of group 0 to 3.9135e-06.
# Epoch:190/200 AVG Training Loss:0.352 AVG Validation Loss:0.768 AVG Training Acc 84.18 % AVG Validation Acc 70.70 %
# Epoch:200/200 AVG Training Loss:0.352 AVG Validation Loss:0.770 AVG Training Acc 84.00 % AVG Validation Acc 70.56 %
# Split 7
#   0%|          | 0/200 [00:00<?, ?it/s]
# Epoch:10/200 AVG Training Loss:0.688 AVG Validation Loss:0.695 AVG Training Acc 54.31 % AVG Validation Acc 52.49 %
# Epoch    17: reducing learning rate of group 0 to 3.3000e-04.
# Epoch:20/200 AVG Training Loss:0.588 AVG Validation Loss:0.682 AVG Training Acc 71.92 % AVG Validation Acc 63.53 %
# Epoch:30/200 AVG Training Loss:0.475 AVG Validation Loss:0.618 AVG Training Acc 77.58 % AVG Validation Acc 70.12 %
# Epoch:40/200 AVG Training Loss:0.439 AVG Validation Loss:0.610 AVG Training Acc 78.93 % AVG Validation Acc 70.39 %
# Epoch:50/200 AVG Training Loss:0.424 AVG Validation Loss:0.617 AVG Training Acc 79.82 % AVG Validation Acc 69.99 %
# Epoch    58: reducing learning rate of group 0 to 1.0890e-04.
# Epoch:60/200 AVG Training Loss:0.406 AVG Validation Loss:0.617 AVG Training Acc 80.80 % AVG Validation Acc 69.99 %
# Epoch:70/200 AVG Training Loss:0.401 AVG Validation Loss:0.625 AVG Training Acc 81.15 % AVG Validation Acc 69.58 %
# Epoch:80/200 AVG Training Loss:0.396 AVG Validation Loss:0.633 AVG Training Acc 81.55 % AVG Validation Acc 68.91 %
# Epoch:90/200 AVG Training Loss:0.394 AVG Validation Loss:0.628 AVG Training Acc 81.76 % AVG Validation Acc 68.91 %
# Epoch    94: reducing learning rate of group 0 to 3.5937e-05.
# Epoch:100/200 AVG Training Loss:0.387 AVG Validation Loss:0.642 AVG Training Acc 82.13 % AVG Validation Acc 69.18 %
# Epoch:110/200 AVG Training Loss:0.386 AVG Validation Loss:0.649 AVG Training Acc 82.15 % AVG Validation Acc 68.78 %
# Epoch:120/200 AVG Training Loss:0.386 AVG Validation Loss:0.652 AVG Training Acc 82.30 % AVG Validation Acc 69.18 %
# Epoch:130/200 AVG Training Loss:0.384 AVG Validation Loss:0.655 AVG Training Acc 82.24 % AVG Validation Acc 69.45 %
# Epoch   130: reducing learning rate of group 0 to 1.1859e-05.
# Epoch:140/200 AVG Training Loss:0.382 AVG Validation Loss:0.657 AVG Training Acc 82.36 % AVG Validation Acc 69.58 %
# Epoch:150/200 AVG Training Loss:0.381 AVG Validation Loss:0.659 AVG Training Acc 82.48 % AVG Validation Acc 69.58 %
# Epoch:160/200 AVG Training Loss:0.380 AVG Validation Loss:0.660 AVG Training Acc 82.55 % AVG Validation Acc 69.72 %
# Epoch   166: reducing learning rate of group 0 to 3.9135e-06.
# Epoch:170/200 AVG Training Loss:0.379 AVG Validation Loss:0.660 AVG Training Acc 82.39 % AVG Validation Acc 69.99 %
# Epoch:180/200 AVG Training Loss:0.379 AVG Validation Loss:0.662 AVG Training Acc 82.46 % AVG Validation Acc 69.58 %
# Epoch:190/200 AVG Training Loss:0.380 AVG Validation Loss:0.663 AVG Training Acc 82.35 % AVG Validation Acc 69.31 %
# Epoch:200/200 AVG Training Loss:0.380 AVG Validation Loss:0.661 AVG Training Acc 82.40 % AVG Validation Acc 69.85 %
# Split 8
#   0%|          | 0/200 [00:00<?, ?it/s]
# Epoch:10/200 AVG Training Loss:0.688 AVG Validation Loss:0.695 AVG Training Acc 53.88 % AVG Validation Acc 54.37 %
# Epoch    17: reducing learning rate of group 0 to 3.3000e-04.
# Epoch:20/200 AVG Training Loss:0.653 AVG Validation Loss:0.707 AVG Training Acc 64.63 % AVG Validation Acc 51.82 %
# Epoch:30/200 AVG Training Loss:0.505 AVG Validation Loss:0.637 AVG Training Acc 76.31 % AVG Validation Acc 69.18 %
# Epoch:40/200 AVG Training Loss:0.456 AVG Validation Loss:0.597 AVG Training Acc 78.90 % AVG Validation Acc 70.93 %
# Epoch:50/200 AVG Training Loss:0.440 AVG Validation Loss:0.588 AVG Training Acc 79.19 % AVG Validation Acc 71.20 %
# Epoch:60/200 AVG Training Loss:0.428 AVG Validation Loss:0.583 AVG Training Acc 79.76 % AVG Validation Acc 71.47 %
# Epoch:70/200 AVG Training Loss:0.416 AVG Validation Loss:0.586 AVG Training Acc 80.35 % AVG Validation Acc 71.60 %
# Epoch    79: reducing learning rate of group 0 to 1.0890e-04.
# Epoch:80/200 AVG Training Loss:0.407 AVG Validation Loss:0.592 AVG Training Acc 80.95 % AVG Validation Acc 71.20 %
# Epoch:90/200 AVG Training Loss:0.391 AVG Validation Loss:0.593 AVG Training Acc 81.85 % AVG Validation Acc 71.87 %
# Epoch:100/200 AVG Training Loss:0.385 AVG Validation Loss:0.601 AVG Training Acc 82.15 % AVG Validation Acc 72.41 %
# Epoch:110/200 AVG Training Loss:0.381 AVG Validation Loss:0.610 AVG Training Acc 82.47 % AVG Validation Acc 72.14 %
# Epoch   115: reducing learning rate of group 0 to 3.5937e-05.
# Epoch:120/200 AVG Training Loss:0.375 AVG Validation Loss:0.618 AVG Training Acc 82.78 % AVG Validation Acc 71.47 %
# Epoch:130/200 AVG Training Loss:0.372 AVG Validation Loss:0.624 AVG Training Acc 82.91 % AVG Validation Acc 71.33 %
# Epoch:140/200 AVG Training Loss:0.370 AVG Validation Loss:0.628 AVG Training Acc 83.14 % AVG Validation Acc 71.47 %
# Epoch:150/200 AVG Training Loss:0.368 AVG Validation Loss:0.635 AVG Training Acc 83.13 % AVG Validation Acc 71.60 %
# Epoch   151: reducing learning rate of group 0 to 1.1859e-05.
# Epoch:160/200 AVG Training Loss:0.365 AVG Validation Loss:0.639 AVG Training Acc 83.15 % AVG Validation Acc 71.87 %
# Epoch:170/200 AVG Training Loss:0.366 AVG Validation Loss:0.643 AVG Training Acc 83.34 % AVG Validation Acc 71.87 %
# Epoch:180/200 AVG Training Loss:0.365 AVG Validation Loss:0.640 AVG Training Acc 83.34 % AVG Validation Acc 71.87 %
# Epoch   187: reducing learning rate of group 0 to 3.9135e-06.
# Epoch:190/200 AVG Training Loss:0.364 AVG Validation Loss:0.645 AVG Training Acc 83.42 % AVG Validation Acc 71.87 %
# Epoch:200/200 AVG Training Loss:0.364 AVG Validation Loss:0.645 AVG Training Acc 83.26 % AVG Validation Acc 71.87 %
# Split 9
#   0%|          | 0/200 [00:00<?, ?it/s]
# Epoch:10/200 AVG Training Loss:0.687 AVG Validation Loss:0.691 AVG Training Acc 53.38 % AVG Validation Acc 55.59 %
# Epoch    17: reducing learning rate of group 0 to 3.3000e-04.
# Epoch:20/200 AVG Training Loss:0.626 AVG Validation Loss:0.710 AVG Training Acc 68.20 % AVG Validation Acc 61.24 %
# Epoch:30/200 AVG Training Loss:0.501 AVG Validation Loss:0.633 AVG Training Acc 77.18 % AVG Validation Acc 70.12 %
# Epoch:40/200 AVG Training Loss:0.452 AVG Validation Loss:0.615 AVG Training Acc 78.78 % AVG Validation Acc 70.39 %
# Epoch:50/200 AVG Training Loss:0.441 AVG Validation Loss:0.605 AVG Training Acc 78.80 % AVG Validation Acc 70.79 %
# Epoch:60/200 AVG Training Loss:0.433 AVG Validation Loss:0.611 AVG Training Acc 79.34 % AVG Validation Acc 71.47 %
# Epoch:70/200 AVG Training Loss:0.417 AVG Validation Loss:0.608 AVG Training Acc 79.95 % AVG Validation Acc 70.79 %
# Epoch:80/200 AVG Training Loss:0.405 AVG Validation Loss:0.628 AVG Training Acc 80.85 % AVG Validation Acc 67.56 %
# Epoch    81: reducing learning rate of group 0 to 1.0890e-04.
# Epoch:90/200 AVG Training Loss:0.393 AVG Validation Loss:0.647 AVG Training Acc 81.56 % AVG Validation Acc 69.45 %
# Epoch:100/200 AVG Training Loss:0.388 AVG Validation Loss:0.657 AVG Training Acc 81.94 % AVG Validation Acc 68.78 %
# Epoch:110/200 AVG Training Loss:0.383 AVG Validation Loss:0.666 AVG Training Acc 82.15 % AVG Validation Acc 68.51 %
# Epoch   117: reducing learning rate of group 0 to 3.5937e-05.
# Epoch:120/200 AVG Training Loss:0.374 AVG Validation Loss:0.676 AVG Training Acc 82.91 % AVG Validation Acc 68.24 %
# Epoch:130/200 AVG Training Loss:0.371 AVG Validation Loss:0.690 AVG Training Acc 83.16 % AVG Validation Acc 68.24 %
# Epoch:140/200 AVG Training Loss:0.368 AVG Validation Loss:0.701 AVG Training Acc 83.31 % AVG Validation Acc 68.24 %
# Epoch:150/200 AVG Training Loss:0.366 AVG Validation Loss:0.708 AVG Training Acc 83.37 % AVG Validation Acc 68.64 %
# Epoch   153: reducing learning rate of group 0 to 1.1859e-05.
# Epoch:160/200 AVG Training Loss:0.364 AVG Validation Loss:0.714 AVG Training Acc 83.45 % AVG Validation Acc 68.37 %
# Epoch:170/200 AVG Training Loss:0.363 AVG Validation Loss:0.715 AVG Training Acc 83.71 % AVG Validation Acc 68.37 %
# Epoch:180/200 AVG Training Loss:0.363 AVG Validation Loss:0.717 AVG Training Acc 83.73 % AVG Validation Acc 68.24 %
# Epoch   189: reducing learning rate of group 0 to 3.9135e-06.
# Epoch:190/200 AVG Training Loss:0.362 AVG Validation Loss:0.719 AVG Training Acc 83.70 % AVG Validation Acc 68.10 %
# Epoch:200/200 AVG Training Loss:0.360 AVG Validation Loss:0.720 AVG Training Acc 83.88 % AVG Validation Acc 68.24 %
# Split 10
#   0%|          | 0/200 [00:00<?, ?it/s]
# Epoch:10/200 AVG Training Loss:0.689 AVG Validation Loss:0.692 AVG Training Acc 52.72 % AVG Validation Acc 55.32 %
# Epoch    17: reducing learning rate of group 0 to 3.3000e-04.
# Epoch:20/200 AVG Training Loss:0.598 AVG Validation Loss:0.619 AVG Training Acc 71.35 % AVG Validation Acc 69.72 %
# Epoch:30/200 AVG Training Loss:0.472 AVG Validation Loss:0.610 AVG Training Acc 77.85 % AVG Validation Acc 70.39 %
# Epoch:40/200 AVG Training Loss:0.441 AVG Validation Loss:0.602 AVG Training Acc 78.89 % AVG Validation Acc 71.47 %
# Epoch:50/200 AVG Training Loss:0.425 AVG Validation Loss:0.597 AVG Training Acc 79.73 % AVG Validation Acc 71.33 %
# Epoch:60/200 AVG Training Loss:0.411 AVG Validation Loss:0.591 AVG Training Acc 80.65 % AVG Validation Acc 71.47 %
# Epoch:70/200 AVG Training Loss:0.399 AVG Validation Loss:0.696 AVG Training Acc 81.26 % AVG Validation Acc 69.72 %
# Epoch    76: reducing learning rate of group 0 to 1.0890e-04.
# Epoch:80/200 AVG Training Loss:0.381 AVG Validation Loss:0.611 AVG Training Acc 82.50 % AVG Validation Acc 71.47 %
# Epoch:90/200 AVG Training Loss:0.375 AVG Validation Loss:0.624 AVG Training Acc 82.85 % AVG Validation Acc 71.60 %
# Epoch:100/200 AVG Training Loss:0.366 AVG Validation Loss:0.645 AVG Training Acc 83.38 % AVG Validation Acc 71.60 %
# Epoch:110/200 AVG Training Loss:0.361 AVG Validation Loss:0.663 AVG Training Acc 83.74 % AVG Validation Acc 71.87 %
# Epoch   112: reducing learning rate of group 0 to 3.5937e-05.
# Epoch:120/200 AVG Training Loss:0.351 AVG Validation Loss:0.672 AVG Training Acc 84.36 % AVG Validation Acc 71.47 %
# Epoch:130/200 AVG Training Loss:0.348 AVG Validation Loss:0.681 AVG Training Acc 84.45 % AVG Validation Acc 71.20 %
# Epoch:140/200 AVG Training Loss:0.345 AVG Validation Loss:0.694 AVG Training Acc 84.73 % AVG Validation Acc 71.47 %
# Epoch   148: reducing learning rate of group 0 to 1.1859e-05.
# Epoch:150/200 AVG Training Loss:0.340 AVG Validation Loss:0.707 AVG Training Acc 84.93 % AVG Validation Acc 71.20 %
# Epoch:160/200 AVG Training Loss:0.340 AVG Validation Loss:0.713 AVG Training Acc 84.80 % AVG Validation Acc 71.33 %
# Epoch:170/200 AVG Training Loss:0.339 AVG Validation Loss:0.715 AVG Training Acc 85.01 % AVG Validation Acc 71.47 %
# Epoch:180/200 AVG Training Loss:0.338 AVG Validation Loss:0.719 AVG Training Acc 84.91 % AVG Validation Acc 71.60 %
# Epoch   184: reducing learning rate of group 0 to 3.9135e-06.
# Epoch:190/200 AVG Training Loss:0.337 AVG Validation Loss:0.723 AVG Training Acc 85.07 % AVG Validation Acc 71.60 %
# Epoch:200/200 AVG Training Loss:0.337 AVG Validation Loss:0.726 AVG Training Acc 85.14 % AVG Validation Acc 71.47 %

# %%
#for each target and number of replicas
results_25 = {}

total_results_25 = pd.DataFrame(columns =['Target', 'Repeat', 'Fold', 'Accuracy', 'Precision_(Binary)', 'Recall_(Binary)', 
                                       'F1-score_(Binary)', 'AUC'])

for i in targets:
    results_25[i] = {}
    for k in range(1, replicas + 1):
        results_25[i][f'repeat{k}'] = pd.DataFrame.from_dict(target_df_dict_25[i][f'repeat{k}'], orient = 'index') # convert dict to dataframe
        
        #explode to get eacxh epoch as a row
        results_25[i][f'repeat{k}'] = results_25[i][f'repeat{k}'].explode(list(results_25[i][f'repeat{k}'].columns))
        results_25[i][f'repeat{k}']['fold'] = results_25[i][f'repeat{k}'].index
        results_25[i][f'repeat{k}'].reset_index(drop = True, inplace = True)
        
        #obtain the result that was obtained at the last possible choice
        placeholder_df = results_25[i][f'repeat{k}'].groupby('fold')[['val_acc', 'precision',
                                                                      'recall', 'f1_score', 'auroc']].last().reset_index()
        
        #making adjustments to concat with total_results properly
        placeholder_df.columns = ['Fold', 'Accuracy', 'Precision_(Binary)', 'Recall_(Binary)', 'F1-score_(Binary)', 'AUC']
        placeholder_df = placeholder_df.reindex(columns = total_results_25.columns)
        
        #fill new missing values
        placeholder_df['Target'], placeholder_df['Repeat'] = i, k
        total_results_25 = total_results_25.append(placeholder_df, ignore_index = True)

# %% [markdown]
# ### Test on data - The first 50 days
#
# Same hyper-parameters.

# %%
#create main dict results for 50 days
target_df_dict_50 = {}

for k in tqdm(targets):
    print(k)
    
    #create main dict results
    
    target_df_dict_50[f'{(k)}'] = {}
    y = df_targets[k].values

    #create a list containing one value per row
    all_indices = list(range(len(df_targets)))
    
    #using train test split to later apply the rule accordingly
    train_ind, test_ind = train_test_split(all_indices, test_size=0.2, 
                                           random_state = 5, stratify = y)
    
    #applied train_test_split rules accordingly
    X_train_val = nd_array_100[train_ind,:51,:]
    y_train_val = y[train_ind]
    
    X_test = nd_array_100[test_ind, :51, :]
    y_test = y[test_ind]    
        
    #reset "best accuracy for treshold i and target k"     
    for repeat in range(replicas):
        print('Replica {}'.format(repeat+1))
        
        foldperf={}
        best_f1_score = 0
        
        #make train_val split
        for fold, (train_idx,val_idx) in tqdm(enumerate(splits.split(X_train_val, y_train_val))):
            print('Split {}'.format(fold + 1))
            
            #make split between train and Val
            X_train, y_train = X_train_val[train_idx], y_train_val[train_idx]
            X_val, y_val = X_train_val[val_idx], y_train_val[val_idx]
            
            #scaling requires one scaler per channel (feature)
            scalers = {}
            for feature in range(X_train.shape[2]):
                           
                scalers[feature] = combination[0][7]
                X_train[:, :, feature] = scalers[feature].fit_transform(X_train[:, :, feature]) 

            for col in range(X_val.shape[2]):
                X_val[:, :, feature] = scalers[feature].transform(X_val[:, :, feature]) 
            
            #need to oversample - will use smote
            #will also require oneoversampler per channel (feature)
            samplers = {}
            
            #create new nd_array with the correct size - 2 * majority class 
            X_train_res = np.zeros(shape = (2* (int(sc.stats.mode(y_train)[1])), X_train.shape[1], X_train.shape[2]))
            for feature in range(X_train.shape[2]):
                           
                samplers[feature] = SMOTE()
                X_train_res[:, :, feature], y_train_res = samplers[feature].fit_resample(X_train[:, :, feature], y_train) 
            
            #second, convert everything to pytorch tensor - we will convert to tensor dataset and 
            X_train_tensors = torch.from_numpy(X_train_res)
            X_val_tensors = torch.from_numpy(X_val)
            
            #convert X tensors to format FloatTensor
            X_train_tensors = X_train_tensors.type(torch.cuda.FloatTensor)
            X_val_tensors = X_val_tensors.type(torch.cuda.FloatTensor)
            
            #create y_tensor
            y_train_tensors = torch.from_numpy(y_train_res)
            y_val_tensors = torch.from_numpy(y_val)
            
            #convert y tensors to format longtensor
            y_train_tensors = y_train_tensors.type(torch.cuda.FloatTensor)
            y_val_tensors = y_val_tensors.type(torch.cuda.FloatTensor)
            
            #create Tensor Datasets and dataloaders for both Train and Val
            train_dataset = TensorDataset(X_train_tensors, y_train_tensors)
            val_dataset = TensorDataset(X_val_tensors, y_val_tensors)
            train_loader = DataLoader(train_dataset, batch_size=batch_size)
            val_loader = DataLoader(val_dataset, batch_size=batch_size)
    
            #creates new model for each 
            model = LSTM_Uni(num_classes, input_size, hidden_size, num_layers, X_train_tensors.shape[1], dropout).to('cuda') #our lstm class
  
            #running condition on optimizer
            if combination[0][6] == 'adam':
                optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
            
            elif combination[0][6] == 'rmsprop':
                optimizer = torch.optim.RMSprop(model.parameters(), lr=learning_rate)
            
            elif combination[0][6] == 'adagrad':
                optimizer = torch.optim.Adagrad(model.parameters(), lr=learning_rate)
            
            else:
                optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
            
            scheduler = ReduceLROnPlateau(optimizer, 
                                 'min', 
                                 patience = 15,
                                 cooldown = 20,
                                threshold=0.00001,
                                factor = 0.33,
                                verbose = True)
            
            history = {'train_loss': [], 'val_loss': [],'train_acc':[],'val_acc':[], 'precision': [],
                      'recall' : [], 'auroc': [], 'f1_score' : []}

            for epoch in tqdm(range(num_epochs)):
                train_loss, train_correct=train_epoch(model,train_loader,criterion,optimizer)
                val_loss, val_correct, precision, recall, auroc, f1 = valid_epoch(model,val_loader,criterion)

                train_loss = train_loss / len(train_loader.sampler)
                train_acc = train_correct / len(train_loader.sampler) * 100
                val_loss = val_loss / len(val_loader.sampler)
                val_acc = val_correct / len(val_loader.sampler) * 100
        
        
                if (epoch+1) % 10 == 0: 
                 print("Epoch:{}/{} AVG Training Loss:{:.3f} AVG Validation Loss:{:.3f} AVG Training Acc {:.2f} % AVG Validation Acc {:.2f} %".format(epoch + 1,
                                                                                                             num_epochs,
                                                                                                             train_loss,
                                                                                                             val_loss,
                                                                                                             train_acc,
                                                                                                             val_acc))
                history['train_loss'].append(train_loss)
                history['val_loss'].append(val_loss)
                history['train_acc'].append(train_acc)
                history['val_acc'].append(val_acc)
                history['precision'].append(precision)
                history['recall'].append(recall)
                history['auroc'].append(auroc)
                history['f1_score'].append(f1)
                scheduler.step(val_loss)
    
                if f1 > best_f1_score:
            
                #replace best accuracy and save best model
                    print(f'New Best F1_score found: {f1*100:.2f}%\nEpoch: {epoch + 1}\n', 
                         f'Accuracy: {val_acc:.2f}\nAUC: {auroc*100:.2f}')
                    best_f1_score = f1
                    best = deepcopy(model)
                    curr_epoch = epoch + 1
                    
            #store fold performance
            foldperf['fold{}'.format(fold+1)] = history
    
        #create dict to store fold performance
        target_df_dict_50[f'{(k)}']['repeat{}'.format(repeat + 1)] = foldperf
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# exam_fail
# Replica 1
# 0it [00:00, ?it/s]
# Split 1
#   0%|          | 0/200 [00:00<?, ?it/s]
# New Best F1_score found: 1.28%
# Epoch: 2
#  Accuracy: 79.30
# AUC: 62.69
# New Best F1_score found: 35.91%
# Epoch: 3
#  Accuracy: 72.18
# AUC: 65.10
# New Best F1_score found: 40.59%
# Epoch: 4
#  Accuracy: 67.74
# AUC: 66.01
# New Best F1_score found: 40.90%
# Epoch: 5
#  Accuracy: 61.16
# AUC: 66.09
# Epoch:10/200 AVG Training Loss:0.666 AVG Validation Loss:0.665 AVG Training Acc 61.66 % AVG Validation Acc 47.31 %
# Epoch:20/200 AVG Training Loss:0.555 AVG Validation Loss:0.568 AVG Training Acc 76.68 % AVG Validation Acc 67.07 %
# Epoch:30/200 AVG Training Loss:0.499 AVG Validation Loss:0.579 AVG Training Acc 80.31 % AVG Validation Acc 69.76 %
# Epoch:40/200 AVG Training Loss:0.438 AVG Validation Loss:0.565 AVG Training Acc 83.36 % AVG Validation Acc 73.79 %
# Epoch:50/200 AVG Training Loss:0.378 AVG Validation Loss:0.737 AVG Training Acc 84.36 % AVG Validation Acc 74.33 %
# Epoch:60/200 AVG Training Loss:0.330 AVG Validation Loss:0.564 AVG Training Acc 85.69 % AVG Validation Acc 76.75 %
# Epoch:70/200 AVG Training Loss:0.289 AVG Validation Loss:0.500 AVG Training Acc 87.32 % AVG Validation Acc 78.76 %
# Epoch:80/200 AVG Training Loss:0.303 AVG Validation Loss:0.565 AVG Training Acc 87.44 % AVG Validation Acc 75.67 %
# Epoch    82: reducing learning rate of group 0 to 3.3000e-04.
# Epoch:90/200 AVG Training Loss:0.245 AVG Validation Loss:0.521 AVG Training Acc 89.00 % AVG Validation Acc 77.55 %
# Epoch:100/200 AVG Training Loss:0.235 AVG Validation Loss:0.542 AVG Training Acc 89.48 % AVG Validation Acc 78.36 %
# Epoch:110/200 AVG Training Loss:0.245 AVG Validation Loss:0.543 AVG Training Acc 89.09 % AVG Validation Acc 78.76 %
# Epoch   118: reducing learning rate of group 0 to 1.0890e-04.
# Epoch:120/200 AVG Training Loss:0.196 AVG Validation Loss:0.600 AVG Training Acc 91.09 % AVG Validation Acc 77.02 %
# Epoch:130/200 AVG Training Loss:0.178 AVG Validation Loss:0.667 AVG Training Acc 92.01 % AVG Validation Acc 76.61 %
# Epoch:140/200 AVG Training Loss:0.167 AVG Validation Loss:0.691 AVG Training Acc 92.54 % AVG Validation Acc 76.08 %
# Epoch:150/200 AVG Training Loss:0.162 AVG Validation Loss:0.671 AVG Training Acc 92.76 % AVG Validation Acc 76.88 %
# Epoch   154: reducing learning rate of group 0 to 3.5937e-05.
# Epoch:160/200 AVG Training Loss:0.151 AVG Validation Loss:0.726 AVG Training Acc 93.27 % AVG Validation Acc 75.54 %
# Epoch:170/200 AVG Training Loss:0.146 AVG Validation Loss:0.758 AVG Training Acc 93.46 % AVG Validation Acc 76.34 %
# Epoch:180/200 AVG Training Loss:0.143 AVG Validation Loss:0.788 AVG Training Acc 93.74 % AVG Validation Acc 76.08 %
# Epoch:190/200 AVG Training Loss:0.136 AVG Validation Loss:0.821 AVG Training Acc 93.95 % AVG Validation Acc 76.34 %
# Epoch   190: reducing learning rate of group 0 to 1.1859e-05.
# Epoch:200/200 AVG Training Loss:0.135 AVG Validation Loss:0.825 AVG Training Acc 93.99 % AVG Validation Acc 76.34 %
# Split 2
#   0%|          | 0/200 [00:00<?, ?it/s]
# Epoch:10/200 AVG Training Loss:0.664 AVG Validation Loss:0.673 AVG Training Acc 60.02 % AVG Validation Acc 46.37 %
# Epoch:20/200 AVG Training Loss:0.545 AVG Validation Loss:0.622 AVG Training Acc 77.74 % AVG Validation Acc 61.56 %
# Epoch:30/200 AVG Training Loss:0.443 AVG Validation Loss:0.562 AVG Training Acc 82.29 % AVG Validation Acc 75.94 %
# Epoch:40/200 AVG Training Loss:0.413 AVG Validation Loss:0.544 AVG Training Acc 84.08 % AVG Validation Acc 77.42 %
# Epoch:50/200 AVG Training Loss:0.395 AVG Validation Loss:0.506 AVG Training Acc 84.52 % AVG Validation Acc 79.17 %
# Epoch:60/200 AVG Training Loss:0.321 AVG Validation Loss:0.504 AVG Training Acc 86.40 % AVG Validation Acc 79.97 %
# Epoch:70/200 AVG Training Loss:0.283 AVG Validation Loss:0.496 AVG Training Acc 87.58 % AVG Validation Acc 79.57 %
# Epoch:80/200 AVG Training Loss:0.265 AVG Validation Loss:0.496 AVG Training Acc 88.24 % AVG Validation Acc 79.57 %
# Epoch:90/200 AVG Training Loss:0.259 AVG Validation Loss:0.522 AVG Training Acc 88.52 % AVG Validation Acc 78.76 %
# Epoch    92: reducing learning rate of group 0 to 3.3000e-04.
# Epoch:100/200 AVG Training Loss:0.209 AVG Validation Loss:0.569 AVG Training Acc 90.53 % AVG Validation Acc 78.63 %
# Epoch:110/200 AVG Training Loss:0.192 AVG Validation Loss:0.628 AVG Training Acc 91.30 % AVG Validation Acc 78.09 %
# Epoch:120/200 AVG Training Loss:0.173 AVG Validation Loss:0.720 AVG Training Acc 92.16 % AVG Validation Acc 74.73 %
# Epoch   128: reducing learning rate of group 0 to 1.0890e-04.
# Epoch:130/200 AVG Training Loss:0.142 AVG Validation Loss:0.774 AVG Training Acc 93.57 % AVG Validation Acc 74.19 %
# Epoch:140/200 AVG Training Loss:0.120 AVG Validation Loss:0.875 AVG Training Acc 94.61 % AVG Validation Acc 74.60 %
# Epoch:150/200 AVG Training Loss:0.108 AVG Validation Loss:0.923 AVG Training Acc 95.08 % AVG Validation Acc 73.79 %
# Epoch:160/200 AVG Training Loss:0.092 AVG Validation Loss:1.014 AVG Training Acc 95.66 % AVG Validation Acc 73.79 %
# Epoch   164: reducing learning rate of group 0 to 3.5937e-05.
# Epoch:170/200 AVG Training Loss:0.080 AVG Validation Loss:1.087 AVG Training Acc 96.45 % AVG Validation Acc 73.25 %
# Epoch:180/200 AVG Training Loss:0.076 AVG Validation Loss:1.122 AVG Training Acc 96.69 % AVG Validation Acc 73.12 %
# Epoch:190/200 AVG Training Loss:0.070 AVG Validation Loss:1.157 AVG Training Acc 96.89 % AVG Validation Acc 72.58 %
# Epoch:200/200 AVG Training Loss:0.067 AVG Validation Loss:1.191 AVG Training Acc 97.18 % AVG Validation Acc 72.85 %
# Epoch   200: reducing learning rate of group 0 to 1.1859e-05.
# Split 3
#   0%|          | 0/200 [00:00<?, ?it/s]
# Epoch:10/200 AVG Training Loss:0.666 AVG Validation Loss:0.659 AVG Training Acc 59.13 % AVG Validation Acc 47.45 %
# Epoch:20/200 AVG Training Loss:0.573 AVG Validation Loss:0.522 AVG Training Acc 73.56 % AVG Validation Acc 72.04 %
# Epoch:30/200 AVG Training Loss:0.512 AVG Validation Loss:0.562 AVG Training Acc 78.42 % AVG Validation Acc 71.37 %
# Epoch:40/200 AVG Training Loss:0.430 AVG Validation Loss:0.488 AVG Training Acc 82.50 % AVG Validation Acc 80.38 %
# Epoch:50/200 AVG Training Loss:0.334 AVG Validation Loss:0.464 AVG Training Acc 85.86 % AVG Validation Acc 81.72 %
# Epoch:60/200 AVG Training Loss:0.314 AVG Validation Loss:0.478 AVG Training Acc 86.52 % AVG Validation Acc 81.72 %
# Epoch:70/200 AVG Training Loss:0.297 AVG Validation Loss:0.460 AVG Training Acc 86.99 % AVG Validation Acc 81.85 %
# Epoch:80/200 AVG Training Loss:0.286 AVG Validation Loss:0.470 AVG Training Acc 87.43 % AVG Validation Acc 81.72 %
# Epoch:90/200 AVG Training Loss:0.266 AVG Validation Loss:0.495 AVG Training Acc 87.89 % AVG Validation Acc 79.97 %
# Epoch    90: reducing learning rate of group 0 to 3.3000e-04.
# Epoch:100/200 AVG Training Loss:0.241 AVG Validation Loss:0.487 AVG Training Acc 89.06 % AVG Validation Acc 81.45 %
# Epoch:110/200 AVG Training Loss:0.227 AVG Validation Loss:0.614 AVG Training Acc 89.70 % AVG Validation Acc 76.48 %
# New Best F1_score found: 41.53%
# Epoch: 112
#  Accuracy: 81.45
# AUC: 70.48
# Epoch:120/200 AVG Training Loss:0.217 AVG Validation Loss:0.519 AVG Training Acc 90.29 % AVG Validation Acc 81.85 %
# Epoch   126: reducing learning rate of group 0 to 1.0890e-04.
# Epoch:130/200 AVG Training Loss:0.190 AVG Validation Loss:0.558 AVG Training Acc 91.48 % AVG Validation Acc 79.97 %
# New Best F1_score found: 42.91%
# Epoch: 133
#  Accuracy: 81.05
# AUC: 72.36
# New Best F1_score found: 44.35%
# Epoch: 136
#  Accuracy: 81.45
# AUC: 71.97
# Epoch:140/200 AVG Training Loss:0.175 AVG Validation Loss:0.606 AVG Training Acc 92.06 % AVG Validation Acc 80.65 %
# Epoch:150/200 AVG Training Loss:0.172 AVG Validation Loss:0.640 AVG Training Acc 92.31 % AVG Validation Acc 80.11 %
# Epoch:160/200 AVG Training Loss:0.158 AVG Validation Loss:0.657 AVG Training Acc 92.93 % AVG Validation Acc 79.97 %
# Epoch   162: reducing learning rate of group 0 to 3.5937e-05.
# Epoch:170/200 AVG Training Loss:0.145 AVG Validation Loss:0.707 AVG Training Acc 93.56 % AVG Validation Acc 79.97 %
# Epoch:180/200 AVG Training Loss:0.140 AVG Validation Loss:0.727 AVG Training Acc 93.77 % AVG Validation Acc 79.57 %
# Epoch:190/200 AVG Training Loss:0.136 AVG Validation Loss:0.748 AVG Training Acc 94.10 % AVG Validation Acc 79.03 %
# Epoch   198: reducing learning rate of group 0 to 1.1859e-05.
# Epoch:200/200 AVG Training Loss:0.131 AVG Validation Loss:0.757 AVG Training Acc 94.16 % AVG Validation Acc 78.63 %
# Split 4
#   0%|          | 0/200 [00:00<?, ?it/s]
# Epoch:10/200 AVG Training Loss:0.657 AVG Validation Loss:0.640 AVG Training Acc 60.44 % AVG Validation Acc 50.67 %
# Epoch:20/200 AVG Training Loss:0.540 AVG Validation Loss:0.876 AVG Training Acc 77.45 % AVG Validation Acc 57.93 %
# Epoch:30/200 AVG Training Loss:0.455 AVG Validation Loss:0.789 AVG Training Acc 81.72 % AVG Validation Acc 67.74 %
# Epoch:40/200 AVG Training Loss:0.470 AVG Validation Loss:0.526 AVG Training Acc 80.48 % AVG Validation Acc 78.36 %
# Epoch:50/200 AVG Training Loss:0.372 AVG Validation Loss:0.566 AVG Training Acc 85.12 % AVG Validation Acc 76.88 %
# Epoch:60/200 AVG Training Loss:0.311 AVG Validation Loss:0.490 AVG Training Acc 86.42 % AVG Validation Acc 79.44 %
# Epoch:70/200 AVG Training Loss:0.279 AVG Validation Loss:0.494 AVG Training Acc 87.59 % AVG Validation Acc 79.84 %
# Epoch:80/200 AVG Training Loss:0.258 AVG Validation Loss:0.558 AVG Training Acc 88.56 % AVG Validation Acc 79.57 %
# Epoch    83: reducing learning rate of group 0 to 3.3000e-04.
# Epoch:90/200 AVG Training Loss:0.222 AVG Validation Loss:0.545 AVG Training Acc 89.92 % AVG Validation Acc 79.17 %
# Epoch:100/200 AVG Training Loss:0.211 AVG Validation Loss:0.550 AVG Training Acc 90.34 % AVG Validation Acc 78.90 %
# Epoch:110/200 AVG Training Loss:0.194 AVG Validation Loss:0.606 AVG Training Acc 91.12 % AVG Validation Acc 78.23 %
# Epoch   119: reducing learning rate of group 0 to 1.0890e-04.
# Epoch:120/200 AVG Training Loss:0.176 AVG Validation Loss:0.660 AVG Training Acc 92.25 % AVG Validation Acc 78.23 %
# Epoch:130/200 AVG Training Loss:0.133 AVG Validation Loss:0.738 AVG Training Acc 93.84 % AVG Validation Acc 78.63 %
# Epoch:140/200 AVG Training Loss:0.118 AVG Validation Loss:0.772 AVG Training Acc 94.51 % AVG Validation Acc 77.69 %
# Epoch:150/200 AVG Training Loss:0.112 AVG Validation Loss:0.804 AVG Training Acc 94.92 % AVG Validation Acc 75.94 %
# Epoch   155: reducing learning rate of group 0 to 3.5937e-05.
# Epoch:160/200 AVG Training Loss:0.096 AVG Validation Loss:0.881 AVG Training Acc 95.58 % AVG Validation Acc 77.02 %
# Epoch:170/200 AVG Training Loss:0.091 AVG Validation Loss:0.925 AVG Training Acc 95.85 % AVG Validation Acc 76.34 %
# Epoch:180/200 AVG Training Loss:0.086 AVG Validation Loss:0.940 AVG Training Acc 96.16 % AVG Validation Acc 77.15 %
# Epoch:190/200 AVG Training Loss:0.082 AVG Validation Loss:0.976 AVG Training Acc 96.34 % AVG Validation Acc 76.88 %
# Epoch   191: reducing learning rate of group 0 to 1.1859e-05.
# Epoch:200/200 AVG Training Loss:0.078 AVG Validation Loss:0.991 AVG Training Acc 96.46 % AVG Validation Acc 76.61 %
# Split 5
#   0%|          | 0/200 [00:00<?, ?it/s]
# Epoch:10/200 AVG Training Loss:0.658 AVG Validation Loss:0.646 AVG Training Acc 60.71 % AVG Validation Acc 51.08 %
# Epoch    17: reducing learning rate of group 0 to 3.3000e-04.
# Epoch:20/200 AVG Training Loss:0.551 AVG Validation Loss:0.590 AVG Training Acc 76.01 % AVG Validation Acc 63.98 %
# Epoch:30/200 AVG Training Loss:0.526 AVG Validation Loss:0.564 AVG Training Acc 78.69 % AVG Validation Acc 71.37 %
# Epoch:40/200 AVG Training Loss:0.484 AVG Validation Loss:0.523 AVG Training Acc 80.87 % AVG Validation Acc 75.94 %
# Epoch:50/200 AVG Training Loss:0.394 AVG Validation Loss:0.509 AVG Training Acc 84.18 % AVG Validation Acc 78.09 %
# Epoch:60/200 AVG Training Loss:0.353 AVG Validation Loss:0.502 AVG Training Acc 85.47 % AVG Validation Acc 78.76 %
# Epoch    63: reducing learning rate of group 0 to 1.0890e-04.
# Epoch:70/200 AVG Training Loss:0.319 AVG Validation Loss:0.487 AVG Training Acc 86.45 % AVG Validation Acc 79.17 %
# Epoch:80/200 AVG Training Loss:0.311 AVG Validation Loss:0.477 AVG Training Acc 86.58 % AVG Validation Acc 79.84 %
# Epoch:90/200 AVG Training Loss:0.306 AVG Validation Loss:0.474 AVG Training Acc 86.78 % AVG Validation Acc 79.97 %
# Epoch:100/200 AVG Training Loss:0.306 AVG Validation Loss:0.474 AVG Training Acc 86.83 % AVG Validation Acc 79.70 %
# Epoch:110/200 AVG Training Loss:0.301 AVG Validation Loss:0.469 AVG Training Acc 86.98 % AVG Validation Acc 80.11 %
# Epoch:120/200 AVG Training Loss:0.298 AVG Validation Loss:0.467 AVG Training Acc 87.10 % AVG Validation Acc 80.11 %
# Epoch:130/200 AVG Training Loss:0.296 AVG Validation Loss:0.464 AVG Training Acc 87.12 % AVG Validation Acc 80.11 %
# Epoch:140/200 AVG Training Loss:0.293 AVG Validation Loss:0.463 AVG Training Acc 87.26 % AVG Validation Acc 80.11 %
# Epoch:150/200 AVG Training Loss:0.291 AVG Validation Loss:0.469 AVG Training Acc 87.17 % AVG Validation Acc 79.70 %
# Epoch   157: reducing learning rate of group 0 to 3.5937e-05.
# Epoch:160/200 AVG Training Loss:0.285 AVG Validation Loss:0.462 AVG Training Acc 87.35 % AVG Validation Acc 79.97 %
# Epoch:170/200 AVG Training Loss:0.283 AVG Validation Loss:0.459 AVG Training Acc 87.46 % AVG Validation Acc 79.44 %
# Epoch:180/200 AVG Training Loss:0.282 AVG Validation Loss:0.457 AVG Training Acc 87.48 % AVG Validation Acc 79.70 %
# Epoch:190/200 AVG Training Loss:0.280 AVG Validation Loss:0.458 AVG Training Acc 87.48 % AVG Validation Acc 79.57 %
# Epoch:200/200 AVG Training Loss:0.280 AVG Validation Loss:0.452 AVG Training Acc 87.50 % AVG Validation Acc 80.11 %
# Split 6
#   0%|          | 0/200 [00:00<?, ?it/s]
# Epoch:10/200 AVG Training Loss:0.658 AVG Validation Loss:0.642 AVG Training Acc 61.62 % AVG Validation Acc 51.61 %
# Epoch:20/200 AVG Training Loss:0.576 AVG Validation Loss:0.562 AVG Training Acc 74.18 % AVG Validation Acc 66.53 %
# Epoch:30/200 AVG Training Loss:0.478 AVG Validation Loss:0.529 AVG Training Acc 81.04 % AVG Validation Acc 75.40 %
# Epoch:40/200 AVG Training Loss:0.396 AVG Validation Loss:0.501 AVG Training Acc 84.13 % AVG Validation Acc 78.63 %
# Epoch:50/200 AVG Training Loss:0.340 AVG Validation Loss:0.482 AVG Training Acc 85.68 % AVG Validation Acc 79.17 %
# Epoch:60/200 AVG Training Loss:0.315 AVG Validation Loss:0.499 AVG Training Acc 86.94 % AVG Validation Acc 79.17 %
# Epoch:70/200 AVG Training Loss:0.290 AVG Validation Loss:0.474 AVG Training Acc 87.31 % AVG Validation Acc 79.57 %
# Epoch    79: reducing learning rate of group 0 to 3.3000e-04.
# Epoch:80/200 AVG Training Loss:0.275 AVG Validation Loss:0.499 AVG Training Acc 87.69 % AVG Validation Acc 79.57 %
# Epoch:90/200 AVG Training Loss:0.254 AVG Validation Loss:0.481 AVG Training Acc 88.46 % AVG Validation Acc 78.90 %
# Epoch:100/200 AVG Training Loss:0.251 AVG Validation Loss:0.498 AVG Training Acc 88.70 % AVG Validation Acc 79.84 %
# Epoch:110/200 AVG Training Loss:0.218 AVG Validation Loss:0.546 AVG Training Acc 90.07 % AVG Validation Acc 76.75 %
# Epoch   115: reducing learning rate of group 0 to 1.0890e-04.
# Epoch:120/200 AVG Training Loss:0.197 AVG Validation Loss:0.572 AVG Training Acc 91.31 % AVG Validation Acc 77.55 %
# Epoch:130/200 AVG Training Loss:0.177 AVG Validation Loss:0.644 AVG Training Acc 92.19 % AVG Validation Acc 75.54 %
# Epoch:140/200 AVG Training Loss:0.167 AVG Validation Loss:0.680 AVG Training Acc 92.66 % AVG Validation Acc 75.13 %
# Epoch:150/200 AVG Training Loss:0.153 AVG Validation Loss:0.690 AVG Training Acc 93.12 % AVG Validation Acc 75.00 %
# Epoch   151: reducing learning rate of group 0 to 3.5937e-05.
# Epoch:160/200 AVG Training Loss:0.143 AVG Validation Loss:0.728 AVG Training Acc 93.67 % AVG Validation Acc 74.87 %
# Epoch:170/200 AVG Training Loss:0.136 AVG Validation Loss:0.758 AVG Training Acc 94.02 % AVG Validation Acc 74.87 %
# Epoch:180/200 AVG Training Loss:0.131 AVG Validation Loss:0.781 AVG Training Acc 94.14 % AVG Validation Acc 74.73 %
# Epoch   187: reducing learning rate of group 0 to 1.1859e-05.
# Epoch:190/200 AVG Training Loss:0.125 AVG Validation Loss:0.808 AVG Training Acc 94.40 % AVG Validation Acc 75.27 %
# Epoch:200/200 AVG Training Loss:0.123 AVG Validation Loss:0.829 AVG Training Acc 94.52 % AVG Validation Acc 74.60 %
# Split 7
#   0%|          | 0/200 [00:00<?, ?it/s]
# Epoch:10/200 AVG Training Loss:0.661 AVG Validation Loss:0.663 AVG Training Acc 60.17 % AVG Validation Acc 48.59 %
# Epoch:20/200 AVG Training Loss:0.614 AVG Validation Loss:0.561 AVG Training Acc 71.60 % AVG Validation Acc 67.29 %
# Epoch:30/200 AVG Training Loss:0.495 AVG Validation Loss:0.528 AVG Training Acc 79.09 % AVG Validation Acc 76.99 %
# Epoch:40/200 AVG Training Loss:0.422 AVG Validation Loss:0.503 AVG Training Acc 83.21 % AVG Validation Acc 78.87 %
# Epoch:50/200 AVG Training Loss:0.384 AVG Validation Loss:0.515 AVG Training Acc 84.29 % AVG Validation Acc 78.06 %
# Epoch    53: reducing learning rate of group 0 to 3.3000e-04.
# Epoch:60/200 AVG Training Loss:0.302 AVG Validation Loss:0.503 AVG Training Acc 86.62 % AVG Validation Acc 79.54 %
# Epoch:70/200 AVG Training Loss:0.276 AVG Validation Loss:0.526 AVG Training Acc 87.69 % AVG Validation Acc 79.27 %
# Epoch:80/200 AVG Training Loss:0.261 AVG Validation Loss:0.535 AVG Training Acc 88.20 % AVG Validation Acc 78.33 %
# Epoch    89: reducing learning rate of group 0 to 1.0890e-04.
# Epoch:90/200 AVG Training Loss:0.273 AVG Validation Loss:0.514 AVG Training Acc 87.80 % AVG Validation Acc 79.00 %
# Epoch:100/200 AVG Training Loss:0.232 AVG Validation Loss:0.572 AVG Training Acc 89.08 % AVG Validation Acc 77.66 %
# Epoch:110/200 AVG Training Loss:0.220 AVG Validation Loss:0.613 AVG Training Acc 89.65 % AVG Validation Acc 77.25 %
# Epoch:120/200 AVG Training Loss:0.236 AVG Validation Loss:0.616 AVG Training Acc 89.13 % AVG Validation Acc 76.04 %
# Epoch   125: reducing learning rate of group 0 to 3.5937e-05.
# Epoch:130/200 AVG Training Loss:0.203 AVG Validation Loss:0.636 AVG Training Acc 90.70 % AVG Validation Acc 77.52 %
# Epoch:140/200 AVG Training Loss:0.197 AVG Validation Loss:0.656 AVG Training Acc 91.14 % AVG Validation Acc 77.52 %
# Epoch:150/200 AVG Training Loss:0.194 AVG Validation Loss:0.672 AVG Training Acc 90.98 % AVG Validation Acc 77.52 %
# Epoch:160/200 AVG Training Loss:0.190 AVG Validation Loss:0.685 AVG Training Acc 91.25 % AVG Validation Acc 77.12 %
# Epoch   161: reducing learning rate of group 0 to 1.1859e-05.
# Epoch:170/200 AVG Training Loss:0.188 AVG Validation Loss:0.693 AVG Training Acc 91.38 % AVG Validation Acc 77.39 %
# Epoch:180/200 AVG Training Loss:0.186 AVG Validation Loss:0.700 AVG Training Acc 91.61 % AVG Validation Acc 77.25 %
# Epoch:190/200 AVG Training Loss:0.185 AVG Validation Loss:0.708 AVG Training Acc 91.54 % AVG Validation Acc 77.52 %
# Epoch   197: reducing learning rate of group 0 to 3.9135e-06.
# Epoch:200/200 AVG Training Loss:0.184 AVG Validation Loss:0.714 AVG Training Acc 91.64 % AVG Validation Acc 77.39 %
# Split 8
#   0%|          | 0/200 [00:00<?, ?it/s]
# Epoch:10/200 AVG Training Loss:0.655 AVG Validation Loss:0.638 AVG Training Acc 61.11 % AVG Validation Acc 52.76 %
# Epoch:20/200 AVG Training Loss:0.601 AVG Validation Loss:0.532 AVG Training Acc 71.22 % AVG Validation Acc 69.31 %
# Epoch:30/200 AVG Training Loss:0.540 AVG Validation Loss:0.490 AVG Training Acc 76.30 % AVG Validation Acc 77.79 %
# Epoch:40/200 AVG Training Loss:0.452 AVG Validation Loss:0.521 AVG Training Acc 81.72 % AVG Validation Acc 77.66 %
# Epoch:50/200 AVG Training Loss:0.367 AVG Validation Loss:0.520 AVG Training Acc 84.63 % AVG Validation Acc 79.41 %
# Epoch:60/200 AVG Training Loss:0.339 AVG Validation Loss:0.503 AVG Training Acc 85.86 % AVG Validation Acc 79.81 %
# Epoch    65: reducing learning rate of group 0 to 3.3000e-04.
# Epoch:70/200 AVG Training Loss:0.277 AVG Validation Loss:0.491 AVG Training Acc 87.53 % AVG Validation Acc 79.27 %
# Epoch:80/200 AVG Training Loss:0.259 AVG Validation Loss:0.526 AVG Training Acc 88.15 % AVG Validation Acc 76.99 %
# Epoch:90/200 AVG Training Loss:0.240 AVG Validation Loss:0.562 AVG Training Acc 89.09 % AVG Validation Acc 78.73 %
# Epoch:100/200 AVG Training Loss:0.209 AVG Validation Loss:0.590 AVG Training Acc 90.55 % AVG Validation Acc 77.39 %
# Epoch   101: reducing learning rate of group 0 to 1.0890e-04.
# Epoch:110/200 AVG Training Loss:0.184 AVG Validation Loss:0.629 AVG Training Acc 91.80 % AVG Validation Acc 78.60 %
# Epoch:120/200 AVG Training Loss:0.173 AVG Validation Loss:0.667 AVG Training Acc 92.14 % AVG Validation Acc 77.52 %
# Epoch:130/200 AVG Training Loss:0.167 AVG Validation Loss:0.690 AVG Training Acc 92.51 % AVG Validation Acc 75.91 %
# Epoch   137: reducing learning rate of group 0 to 3.5937e-05.
# Epoch:140/200 AVG Training Loss:0.152 AVG Validation Loss:0.754 AVG Training Acc 93.31 % AVG Validation Acc 76.04 %
# Epoch:150/200 AVG Training Loss:0.146 AVG Validation Loss:0.774 AVG Training Acc 93.50 % AVG Validation Acc 76.58 %
# Epoch:160/200 AVG Training Loss:0.139 AVG Validation Loss:0.810 AVG Training Acc 93.78 % AVG Validation Acc 75.77 %
# Epoch:170/200 AVG Training Loss:0.135 AVG Validation Loss:0.843 AVG Training Acc 94.01 % AVG Validation Acc 75.91 %
# Epoch   173: reducing learning rate of group 0 to 1.1859e-05.
# Epoch:180/200 AVG Training Loss:0.132 AVG Validation Loss:0.856 AVG Training Acc 94.24 % AVG Validation Acc 75.77 %
# Epoch:190/200 AVG Training Loss:0.131 AVG Validation Loss:0.869 AVG Training Acc 94.14 % AVG Validation Acc 75.64 %
# Epoch:200/200 AVG Training Loss:0.128 AVG Validation Loss:0.881 AVG Training Acc 94.27 % AVG Validation Acc 74.97 %
# Split 9
#   0%|          | 0/200 [00:00<?, ?it/s]
# Epoch:10/200 AVG Training Loss:0.658 AVG Validation Loss:0.642 AVG Training Acc 59.78 % AVG Validation Acc 52.76 %
# Epoch:20/200 AVG Training Loss:0.586 AVG Validation Loss:0.559 AVG Training Acc 73.96 % AVG Validation Acc 67.29 %
# Epoch:30/200 AVG Training Loss:0.575 AVG Validation Loss:0.565 AVG Training Acc 74.26 % AVG Validation Acc 69.72 %
# Epoch:40/200 AVG Training Loss:0.453 AVG Validation Loss:0.529 AVG Training Acc 81.85 % AVG Validation Acc 77.39 %
# Epoch    41: reducing learning rate of group 0 to 3.3000e-04.
# Epoch:50/200 AVG Training Loss:0.360 AVG Validation Loss:0.518 AVG Training Acc 85.52 % AVG Validation Acc 78.60 %
# Epoch:60/200 AVG Training Loss:0.328 AVG Validation Loss:0.497 AVG Training Acc 86.39 % AVG Validation Acc 79.41 %
# Epoch:70/200 AVG Training Loss:0.318 AVG Validation Loss:0.487 AVG Training Acc 86.77 % AVG Validation Acc 79.68 %
# Epoch:80/200 AVG Training Loss:0.312 AVG Validation Loss:0.486 AVG Training Acc 86.92 % AVG Validation Acc 79.81 %
# Epoch    89: reducing learning rate of group 0 to 1.0890e-04.
# Epoch:90/200 AVG Training Loss:0.298 AVG Validation Loss:0.489 AVG Training Acc 87.32 % AVG Validation Acc 79.68 %
# Epoch:100/200 AVG Training Loss:0.290 AVG Validation Loss:0.488 AVG Training Acc 87.67 % AVG Validation Acc 79.27 %
# Epoch:110/200 AVG Training Loss:0.289 AVG Validation Loss:0.487 AVG Training Acc 87.64 % AVG Validation Acc 79.54 %
# Epoch:120/200 AVG Training Loss:0.285 AVG Validation Loss:0.487 AVG Training Acc 87.76 % AVG Validation Acc 79.68 %
# Epoch   125: reducing learning rate of group 0 to 3.5937e-05.
# Epoch:130/200 AVG Training Loss:0.282 AVG Validation Loss:0.488 AVG Training Acc 87.93 % AVG Validation Acc 79.81 %
# Epoch:140/200 AVG Training Loss:0.280 AVG Validation Loss:0.488 AVG Training Acc 87.90 % AVG Validation Acc 79.68 %
# Epoch:150/200 AVG Training Loss:0.279 AVG Validation Loss:0.488 AVG Training Acc 87.97 % AVG Validation Acc 79.68 %
# Epoch:160/200 AVG Training Loss:0.277 AVG Validation Loss:0.487 AVG Training Acc 88.04 % AVG Validation Acc 79.81 %
# Epoch   161: reducing learning rate of group 0 to 1.1859e-05.
# Epoch:170/200 AVG Training Loss:0.277 AVG Validation Loss:0.487 AVG Training Acc 87.98 % AVG Validation Acc 79.81 %
# Epoch:180/200 AVG Training Loss:0.275 AVG Validation Loss:0.487 AVG Training Acc 87.98 % AVG Validation Acc 79.81 %
# Epoch:190/200 AVG Training Loss:0.275 AVG Validation Loss:0.486 AVG Training Acc 88.01 % AVG Validation Acc 79.81 %
# Epoch   197: reducing learning rate of group 0 to 3.9135e-06.
# Epoch:200/200 AVG Training Loss:0.274 AVG Validation Loss:0.485 AVG Training Acc 88.02 % AVG Validation Acc 79.68 %
# Split 10
#   0%|          | 0/200 [00:00<?, ?it/s]
# Epoch:10/200 AVG Training Loss:0.647 AVG Validation Loss:0.662 AVG Training Acc 62.59 % AVG Validation Acc 47.11 %
# Epoch:20/200 AVG Training Loss:0.524 AVG Validation Loss:0.599 AVG Training Acc 78.74 % AVG Validation Acc 67.43 %
# Epoch:30/200 AVG Training Loss:0.455 AVG Validation Loss:0.572 AVG Training Acc 81.59 % AVG Validation Acc 74.83 %
# Epoch:40/200 AVG Training Loss:0.385 AVG Validation Loss:0.556 AVG Training Acc 84.66 % AVG Validation Acc 76.04 %
# Epoch:50/200 AVG Training Loss:0.333 AVG Validation Loss:0.505 AVG Training Acc 86.08 % AVG Validation Acc 79.27 %
# Epoch:60/200 AVG Training Loss:0.296 AVG Validation Loss:0.493 AVG Training Acc 87.00 % AVG Validation Acc 79.00 %
# Epoch:70/200 AVG Training Loss:0.278 AVG Validation Loss:0.502 AVG Training Acc 87.74 % AVG Validation Acc 77.79 %
# Epoch:80/200 AVG Training Loss:0.263 AVG Validation Loss:0.522 AVG Training Acc 88.24 % AVG Validation Acc 77.93 %
# Epoch    83: reducing learning rate of group 0 to 3.3000e-04.
# Epoch:90/200 AVG Training Loss:0.233 AVG Validation Loss:0.552 AVG Training Acc 89.17 % AVG Validation Acc 79.41 %
# Epoch:100/200 AVG Training Loss:0.218 AVG Validation Loss:0.580 AVG Training Acc 89.86 % AVG Validation Acc 76.58 %
# Epoch:110/200 AVG Training Loss:0.202 AVG Validation Loss:0.593 AVG Training Acc 90.48 % AVG Validation Acc 76.31 %
# Epoch   119: reducing learning rate of group 0 to 1.0890e-04.
# Epoch:120/200 AVG Training Loss:0.182 AVG Validation Loss:0.625 AVG Training Acc 91.47 % AVG Validation Acc 75.64 %
# Epoch:130/200 AVG Training Loss:0.158 AVG Validation Loss:0.733 AVG Training Acc 92.36 % AVG Validation Acc 76.18 %
# Epoch:140/200 AVG Training Loss:0.146 AVG Validation Loss:0.786 AVG Training Acc 92.99 % AVG Validation Acc 74.97 %
# Epoch:150/200 AVG Training Loss:0.139 AVG Validation Loss:0.863 AVG Training Acc 93.14 % AVG Validation Acc 75.77 %
# Epoch   155: reducing learning rate of group 0 to 3.5937e-05.
# Epoch:160/200 AVG Training Loss:0.127 AVG Validation Loss:0.880 AVG Training Acc 93.86 % AVG Validation Acc 75.50 %
# Epoch:170/200 AVG Training Loss:0.122 AVG Validation Loss:0.893 AVG Training Acc 94.23 % AVG Validation Acc 75.37 %
# Epoch:180/200 AVG Training Loss:0.116 AVG Validation Loss:0.914 AVG Training Acc 94.73 % AVG Validation Acc 74.83 %
# Epoch:190/200 AVG Training Loss:0.112 AVG Validation Loss:0.945 AVG Training Acc 94.78 % AVG Validation Acc 74.56 %
# Epoch   191: reducing learning rate of group 0 to 1.1859e-05.
# Epoch:200/200 AVG Training Loss:0.109 AVG Validation Loss:0.950 AVG Training Acc 94.84 % AVG Validation Acc 74.70 %
# Replica 2
# 0it [00:00, ?it/s]
# Split 1
#   0%|          | 0/200 [00:00<?, ?it/s]
# New Best F1_score found: 39.42%
# Epoch: 4
#  Accuracy: 71.91
# AUC: 66.26
# New Best F1_score found: 41.03%
# Epoch: 5
#  Accuracy: 62.90
# AUC: 66.30
# Epoch:10/200 AVG Training Loss:0.657 AVG Validation Loss:0.643 AVG Training Acc 60.32 % AVG Validation Acc 54.70 %
# Epoch:20/200 AVG Training Loss:0.587 AVG Validation Loss:0.539 AVG Training Acc 74.04 % AVG Validation Acc 72.31 %
# Epoch:30/200 AVG Training Loss:0.475 AVG Validation Loss:0.596 AVG Training Acc 81.20 % AVG Validation Acc 70.30 %
# Epoch:40/200 AVG Training Loss:0.448 AVG Validation Loss:0.553 AVG Training Acc 82.14 % AVG Validation Acc 74.73 %
# Epoch:50/200 AVG Training Loss:0.415 AVG Validation Loss:0.521 AVG Training Acc 83.69 % AVG Validation Acc 78.23 %
# Epoch:60/200 AVG Training Loss:0.364 AVG Validation Loss:0.584 AVG Training Acc 84.20 % AVG Validation Acc 76.34 %
# Epoch:70/200 AVG Training Loss:0.299 AVG Validation Loss:0.495 AVG Training Acc 86.89 % AVG Validation Acc 78.23 %
# Epoch:80/200 AVG Training Loss:0.270 AVG Validation Loss:0.505 AVG Training Acc 87.78 % AVG Validation Acc 78.23 %
# Epoch    88: reducing learning rate of group 0 to 3.3000e-04.
# Epoch:90/200 AVG Training Loss:0.242 AVG Validation Loss:0.536 AVG Training Acc 89.16 % AVG Validation Acc 77.15 %
# Epoch:100/200 AVG Training Loss:0.231 AVG Validation Loss:0.562 AVG Training Acc 89.64 % AVG Validation Acc 76.75 %
# Epoch:110/200 AVG Training Loss:0.207 AVG Validation Loss:0.607 AVG Training Acc 90.53 % AVG Validation Acc 75.94 %
# Epoch:120/200 AVG Training Loss:0.179 AVG Validation Loss:0.726 AVG Training Acc 91.93 % AVG Validation Acc 75.27 %
# Epoch   124: reducing learning rate of group 0 to 1.0890e-04.
# Epoch:130/200 AVG Training Loss:0.154 AVG Validation Loss:0.686 AVG Training Acc 92.79 % AVG Validation Acc 76.48 %
# Epoch:140/200 AVG Training Loss:0.144 AVG Validation Loss:0.729 AVG Training Acc 93.56 % AVG Validation Acc 76.08 %
# Epoch:150/200 AVG Training Loss:0.133 AVG Validation Loss:0.783 AVG Training Acc 93.98 % AVG Validation Acc 75.27 %
# Epoch:160/200 AVG Training Loss:0.120 AVG Validation Loss:0.857 AVG Training Acc 94.38 % AVG Validation Acc 75.27 %
# Epoch   160: reducing learning rate of group 0 to 3.5937e-05.
# Epoch:170/200 AVG Training Loss:0.109 AVG Validation Loss:0.874 AVG Training Acc 95.09 % AVG Validation Acc 74.19 %
# Epoch:180/200 AVG Training Loss:0.104 AVG Validation Loss:0.893 AVG Training Acc 95.25 % AVG Validation Acc 74.19 %
# Epoch:190/200 AVG Training Loss:0.100 AVG Validation Loss:0.915 AVG Training Acc 95.43 % AVG Validation Acc 74.19 %
# Epoch   196: reducing learning rate of group 0 to 1.1859e-05.
# Epoch:200/200 AVG Training Loss:0.095 AVG Validation Loss:0.937 AVG Training Acc 95.70 % AVG Validation Acc 75.27 %
# Split 2
#   0%|          | 0/200 [00:00<?, ?it/s]
# Epoch:10/200 AVG Training Loss:0.657 AVG Validation Loss:0.662 AVG Training Acc 60.58 % AVG Validation Acc 49.19 %
# Epoch:20/200 AVG Training Loss:0.594 AVG Validation Loss:0.581 AVG Training Acc 71.90 % AVG Validation Acc 63.84 %
# Epoch:30/200 AVG Training Loss:0.500 AVG Validation Loss:0.674 AVG Training Acc 79.58 % AVG Validation Acc 62.10 %
# Epoch:40/200 AVG Training Loss:0.526 AVG Validation Loss:0.538 AVG Training Acc 79.95 % AVG Validation Acc 73.66 %
# Epoch:50/200 AVG Training Loss:0.409 AVG Validation Loss:0.528 AVG Training Acc 83.78 % AVG Validation Acc 76.21 %
# Epoch:60/200 AVG Training Loss:0.306 AVG Validation Loss:0.506 AVG Training Acc 86.77 % AVG Validation Acc 79.03 %
# Epoch:70/200 AVG Training Loss:0.294 AVG Validation Loss:0.488 AVG Training Acc 87.15 % AVG Validation Acc 79.84 %
# Epoch:80/200 AVG Training Loss:0.263 AVG Validation Loss:0.523 AVG Training Acc 88.32 % AVG Validation Acc 79.97 %
# Epoch    87: reducing learning rate of group 0 to 3.3000e-04.
# Epoch:90/200 AVG Training Loss:0.235 AVG Validation Loss:0.522 AVG Training Acc 89.35 % AVG Validation Acc 79.57 %
# Epoch:100/200 AVG Training Loss:0.221 AVG Validation Loss:0.529 AVG Training Acc 90.02 % AVG Validation Acc 79.30 %
# Epoch:110/200 AVG Training Loss:0.195 AVG Validation Loss:0.543 AVG Training Acc 91.09 % AVG Validation Acc 77.96 %
# Epoch:120/200 AVG Training Loss:0.162 AVG Validation Loss:0.687 AVG Training Acc 92.55 % AVG Validation Acc 77.42 %
# Epoch   123: reducing learning rate of group 0 to 1.0890e-04.
# Epoch:130/200 AVG Training Loss:0.129 AVG Validation Loss:0.685 AVG Training Acc 94.48 % AVG Validation Acc 76.88 %
# Epoch:140/200 AVG Training Loss:0.111 AVG Validation Loss:0.766 AVG Training Acc 95.38 % AVG Validation Acc 76.61 %
# New Best F1_score found: 41.38%
# Epoch: 141
#  Accuracy: 77.15
# AUC: 71.70
# Epoch:150/200 AVG Training Loss:0.096 AVG Validation Loss:0.826 AVG Training Acc 96.06 % AVG Validation Acc 75.81 %
# Epoch   159: reducing learning rate of group 0 to 3.5937e-05.
# Epoch:160/200 AVG Training Loss:0.088 AVG Validation Loss:0.877 AVG Training Acc 96.55 % AVG Validation Acc 75.27 %
# Epoch:170/200 AVG Training Loss:0.075 AVG Validation Loss:0.920 AVG Training Acc 97.19 % AVG Validation Acc 76.34 %
# Epoch:180/200 AVG Training Loss:0.069 AVG Validation Loss:0.960 AVG Training Acc 97.32 % AVG Validation Acc 75.13 %
# Epoch:190/200 AVG Training Loss:0.064 AVG Validation Loss:1.001 AVG Training Acc 97.58 % AVG Validation Acc 75.00 %
# Epoch   195: reducing learning rate of group 0 to 1.1859e-05.
# Epoch:200/200 AVG Training Loss:0.060 AVG Validation Loss:1.033 AVG Training Acc 97.82 % AVG Validation Acc 75.27 %
# Split 3
#   0%|          | 0/200 [00:00<?, ?it/s]
# Epoch:10/200 AVG Training Loss:0.667 AVG Validation Loss:0.673 AVG Training Acc 59.90 % AVG Validation Acc 44.49 %
# Epoch:20/200 AVG Training Loss:0.609 AVG Validation Loss:0.550 AVG Training Acc 70.17 % AVG Validation Acc 67.07 %
# Epoch:30/200 AVG Training Loss:0.504 AVG Validation Loss:0.513 AVG Training Acc 79.85 % AVG Validation Acc 76.75 %
# Epoch:40/200 AVG Training Loss:0.426 AVG Validation Loss:0.527 AVG Training Acc 83.66 % AVG Validation Acc 77.02 %
# Epoch:50/200 AVG Training Loss:0.363 AVG Validation Loss:0.806 AVG Training Acc 84.99 % AVG Validation Acc 72.85 %
# Epoch:60/200 AVG Training Loss:0.342 AVG Validation Loss:0.481 AVG Training Acc 85.77 % AVG Validation Acc 81.05 %
# Epoch:70/200 AVG Training Loss:0.307 AVG Validation Loss:0.455 AVG Training Acc 86.84 % AVG Validation Acc 82.26 %
# Epoch:80/200 AVG Training Loss:0.292 AVG Validation Loss:0.494 AVG Training Acc 87.13 % AVG Validation Acc 82.39 %
# Epoch:90/200 AVG Training Loss:0.273 AVG Validation Loss:0.491 AVG Training Acc 87.71 % AVG Validation Acc 80.38 %
# New Best F1_score found: 45.11%
# Epoch: 90
#  Accuracy: 80.38
# AUC: 72.21
# Epoch    92: reducing learning rate of group 0 to 3.3000e-04.
# New Best F1_score found: 45.64%
# Epoch: 94
#  Accuracy: 82.39
# AUC: 73.35
# Epoch:100/200 AVG Training Loss:0.224 AVG Validation Loss:0.542 AVG Training Acc 89.56 % AVG Validation Acc 79.03 %
# Epoch:110/200 AVG Training Loss:0.202 AVG Validation Loss:0.574 AVG Training Acc 90.75 % AVG Validation Acc 79.17 %
# Epoch:120/200 AVG Training Loss:0.169 AVG Validation Loss:0.648 AVG Training Acc 92.47 % AVG Validation Acc 75.54 %
# Epoch   128: reducing learning rate of group 0 to 1.0890e-04.
# Epoch:130/200 AVG Training Loss:0.145 AVG Validation Loss:0.692 AVG Training Acc 93.83 % AVG Validation Acc 76.08 %
# Epoch:140/200 AVG Training Loss:0.123 AVG Validation Loss:0.787 AVG Training Acc 94.70 % AVG Validation Acc 75.13 %
# Epoch:150/200 AVG Training Loss:0.106 AVG Validation Loss:0.866 AVG Training Acc 95.38 % AVG Validation Acc 74.73 %
# Epoch:160/200 AVG Training Loss:0.109 AVG Validation Loss:0.894 AVG Training Acc 95.23 % AVG Validation Acc 74.87 %
# Epoch   164: reducing learning rate of group 0 to 3.5937e-05.
# Epoch:170/200 AVG Training Loss:0.084 AVG Validation Loss:0.967 AVG Training Acc 96.41 % AVG Validation Acc 73.92 %
# Epoch:180/200 AVG Training Loss:0.079 AVG Validation Loss:1.005 AVG Training Acc 96.70 % AVG Validation Acc 73.79 %
# Epoch:190/200 AVG Training Loss:0.074 AVG Validation Loss:1.052 AVG Training Acc 96.96 % AVG Validation Acc 73.92 %
# Epoch:200/200 AVG Training Loss:0.070 AVG Validation Loss:1.095 AVG Training Acc 97.09 % AVG Validation Acc 74.06 %
# Epoch   200: reducing learning rate of group 0 to 1.1859e-05.
# Split 4
#   0%|          | 0/200 [00:00<?, ?it/s]
# Epoch:10/200 AVG Training Loss:0.640 AVG Validation Loss:0.643 AVG Training Acc 65.11 % AVG Validation Acc 49.87 %
# Epoch:20/200 AVG Training Loss:0.532 AVG Validation Loss:0.546 AVG Training Acc 78.34 % AVG Validation Acc 72.04 %
# Epoch:30/200 AVG Training Loss:0.457 AVG Validation Loss:0.534 AVG Training Acc 82.28 % AVG Validation Acc 76.21 %
# Epoch:40/200 AVG Training Loss:0.391 AVG Validation Loss:0.545 AVG Training Acc 84.55 % AVG Validation Acc 77.28 %
# Epoch:50/200 AVG Training Loss:0.325 AVG Validation Loss:0.506 AVG Training Acc 85.87 % AVG Validation Acc 79.30 %
# Epoch:60/200 AVG Training Loss:0.283 AVG Validation Loss:0.482 AVG Training Acc 87.43 % AVG Validation Acc 80.51 %
# Epoch:70/200 AVG Training Loss:0.257 AVG Validation Loss:0.568 AVG Training Acc 88.60 % AVG Validation Acc 74.33 %
# Epoch    73: reducing learning rate of group 0 to 3.3000e-04.
# Epoch:80/200 AVG Training Loss:0.223 AVG Validation Loss:0.539 AVG Training Acc 89.95 % AVG Validation Acc 78.90 %
# Epoch:90/200 AVG Training Loss:0.207 AVG Validation Loss:0.592 AVG Training Acc 90.61 % AVG Validation Acc 77.69 %
# Epoch:100/200 AVG Training Loss:0.201 AVG Validation Loss:0.527 AVG Training Acc 90.76 % AVG Validation Acc 79.57 %
# Epoch   109: reducing learning rate of group 0 to 1.0890e-04.
# Epoch:110/200 AVG Training Loss:0.213 AVG Validation Loss:0.556 AVG Training Acc 90.36 % AVG Validation Acc 79.44 %
# Epoch:120/200 AVG Training Loss:0.155 AVG Validation Loss:0.648 AVG Training Acc 93.03 % AVG Validation Acc 78.49 %
# Epoch:130/200 AVG Training Loss:0.143 AVG Validation Loss:0.757 AVG Training Acc 93.55 % AVG Validation Acc 77.69 %
# Epoch:140/200 AVG Training Loss:0.141 AVG Validation Loss:0.803 AVG Training Acc 93.82 % AVG Validation Acc 79.84 %
# Epoch   145: reducing learning rate of group 0 to 3.5937e-05.
# Epoch:150/200 AVG Training Loss:0.126 AVG Validation Loss:0.801 AVG Training Acc 94.23 % AVG Validation Acc 76.75 %
# Epoch:160/200 AVG Training Loss:0.121 AVG Validation Loss:0.826 AVG Training Acc 94.48 % AVG Validation Acc 76.88 %
# Epoch:170/200 AVG Training Loss:0.117 AVG Validation Loss:0.852 AVG Training Acc 94.65 % AVG Validation Acc 77.15 %
# Epoch:180/200 AVG Training Loss:0.113 AVG Validation Loss:0.880 AVG Training Acc 94.83 % AVG Validation Acc 76.75 %
# Epoch   181: reducing learning rate of group 0 to 1.1859e-05.
# Epoch:190/200 AVG Training Loss:0.111 AVG Validation Loss:0.892 AVG Training Acc 94.86 % AVG Validation Acc 76.88 %
# Epoch:200/200 AVG Training Loss:0.109 AVG Validation Loss:0.899 AVG Training Acc 94.93 % AVG Validation Acc 76.61 %
# Split 5
#   0%|          | 0/200 [00:00<?, ?it/s]
# Epoch:10/200 AVG Training Loss:0.691 AVG Validation Loss:0.661 AVG Training Acc 42.94 % AVG Validation Acc 50.54 %
# Epoch:20/200 AVG Training Loss:0.589 AVG Validation Loss:0.565 AVG Training Acc 72.81 % AVG Validation Acc 66.67 %
# Epoch:30/200 AVG Training Loss:0.562 AVG Validation Loss:0.604 AVG Training Acc 75.06 % AVG Validation Acc 63.31 %
# Epoch:40/200 AVG Training Loss:0.470 AVG Validation Loss:0.568 AVG Training Acc 81.25 % AVG Validation Acc 73.52 %
# Epoch:50/200 AVG Training Loss:0.444 AVG Validation Loss:0.546 AVG Training Acc 82.67 % AVG Validation Acc 75.67 %
# Epoch:60/200 AVG Training Loss:0.386 AVG Validation Loss:0.490 AVG Training Acc 84.42 % AVG Validation Acc 79.44 %
# Epoch:70/200 AVG Training Loss:0.320 AVG Validation Loss:0.472 AVG Training Acc 86.35 % AVG Validation Acc 80.24 %
# Epoch:80/200 AVG Training Loss:0.302 AVG Validation Loss:0.480 AVG Training Acc 86.88 % AVG Validation Acc 80.24 %
# Epoch    86: reducing learning rate of group 0 to 3.3000e-04.
# Epoch:90/200 AVG Training Loss:0.266 AVG Validation Loss:0.489 AVG Training Acc 87.96 % AVG Validation Acc 80.11 %
# Epoch:100/200 AVG Training Loss:0.250 AVG Validation Loss:0.480 AVG Training Acc 88.49 % AVG Validation Acc 79.70 %
# Epoch:110/200 AVG Training Loss:0.240 AVG Validation Loss:0.541 AVG Training Acc 89.06 % AVG Validation Acc 79.03 %
# Epoch:120/200 AVG Training Loss:0.222 AVG Validation Loss:0.504 AVG Training Acc 89.98 % AVG Validation Acc 78.36 %
# Epoch   122: reducing learning rate of group 0 to 1.0890e-04.
# Epoch:130/200 AVG Training Loss:0.195 AVG Validation Loss:0.530 AVG Training Acc 91.40 % AVG Validation Acc 77.42 %
# Epoch:140/200 AVG Training Loss:0.189 AVG Validation Loss:0.579 AVG Training Acc 91.52 % AVG Validation Acc 77.02 %
# Epoch:150/200 AVG Training Loss:0.185 AVG Validation Loss:0.706 AVG Training Acc 91.52 % AVG Validation Acc 74.19 %
# Epoch   158: reducing learning rate of group 0 to 3.5937e-05.
# Epoch:160/200 AVG Training Loss:0.171 AVG Validation Loss:0.650 AVG Training Acc 92.38 % AVG Validation Acc 76.21 %
# Epoch:170/200 AVG Training Loss:0.155 AVG Validation Loss:0.652 AVG Training Acc 93.05 % AVG Validation Acc 76.21 %
# Epoch:180/200 AVG Training Loss:0.149 AVG Validation Loss:0.664 AVG Training Acc 93.41 % AVG Validation Acc 75.54 %
# Epoch:190/200 AVG Training Loss:0.144 AVG Validation Loss:0.689 AVG Training Acc 93.66 % AVG Validation Acc 75.40 %
# Epoch   194: reducing learning rate of group 0 to 1.1859e-05.
# Epoch:200/200 AVG Training Loss:0.140 AVG Validation Loss:0.704 AVG Training Acc 93.94 % AVG Validation Acc 75.27 %
# Split 6
#   0%|          | 0/200 [00:00<?, ?it/s]
# Epoch:10/200 AVG Training Loss:0.658 AVG Validation Loss:0.632 AVG Training Acc 63.48 % AVG Validation Acc 55.38 %
# Epoch:20/200 AVG Training Loss:0.542 AVG Validation Loss:1.388 AVG Training Acc 75.78 % AVG Validation Acc 46.37 %
# Epoch:30/200 AVG Training Loss:0.463 AVG Validation Loss:0.522 AVG Training Acc 81.48 % AVG Validation Acc 76.48 %
# Epoch:40/200 AVG Training Loss:0.410 AVG Validation Loss:0.518 AVG Training Acc 83.39 % AVG Validation Acc 77.55 %
# Epoch:50/200 AVG Training Loss:0.342 AVG Validation Loss:0.508 AVG Training Acc 84.92 % AVG Validation Acc 78.90 %
# Epoch:60/200 AVG Training Loss:0.301 AVG Validation Loss:0.462 AVG Training Acc 87.19 % AVG Validation Acc 80.11 %
# Epoch:70/200 AVG Training Loss:0.287 AVG Validation Loss:0.471 AVG Training Acc 87.36 % AVG Validation Acc 79.84 %
# Epoch    79: reducing learning rate of group 0 to 3.3000e-04.
# Epoch:80/200 AVG Training Loss:0.272 AVG Validation Loss:0.495 AVG Training Acc 88.04 % AVG Validation Acc 80.24 %
# Epoch:90/200 AVG Training Loss:0.249 AVG Validation Loss:0.550 AVG Training Acc 88.44 % AVG Validation Acc 79.17 %
# Epoch:100/200 AVG Training Loss:0.238 AVG Validation Loss:0.552 AVG Training Acc 88.90 % AVG Validation Acc 78.76 %
# Epoch:110/200 AVG Training Loss:0.215 AVG Validation Loss:0.641 AVG Training Acc 89.92 % AVG Validation Acc 78.49 %
# Epoch   115: reducing learning rate of group 0 to 1.0890e-04.
# Epoch:120/200 AVG Training Loss:0.176 AVG Validation Loss:0.647 AVG Training Acc 91.70 % AVG Validation Acc 77.02 %
# Epoch:130/200 AVG Training Loss:0.157 AVG Validation Loss:0.705 AVG Training Acc 92.82 % AVG Validation Acc 77.55 %
# Epoch:140/200 AVG Training Loss:0.138 AVG Validation Loss:0.755 AVG Training Acc 93.61 % AVG Validation Acc 76.88 %
# Epoch:150/200 AVG Training Loss:0.129 AVG Validation Loss:0.805 AVG Training Acc 94.21 % AVG Validation Acc 75.67 %
# Epoch   151: reducing learning rate of group 0 to 3.5937e-05.
# Epoch:160/200 AVG Training Loss:0.119 AVG Validation Loss:0.853 AVG Training Acc 94.52 % AVG Validation Acc 76.48 %
# Epoch:170/200 AVG Training Loss:0.113 AVG Validation Loss:0.884 AVG Training Acc 94.84 % AVG Validation Acc 76.08 %
# Epoch:180/200 AVG Training Loss:0.107 AVG Validation Loss:0.930 AVG Training Acc 95.23 % AVG Validation Acc 75.54 %
# Epoch   187: reducing learning rate of group 0 to 1.1859e-05.
# Epoch:190/200 AVG Training Loss:0.102 AVG Validation Loss:0.962 AVG Training Acc 95.47 % AVG Validation Acc 75.67 %
# Epoch:200/200 AVG Training Loss:0.100 AVG Validation Loss:0.979 AVG Training Acc 95.44 % AVG Validation Acc 75.54 %
# Split 7
#   0%|          | 0/200 [00:00<?, ?it/s]
# Epoch:10/200 AVG Training Loss:0.649 AVG Validation Loss:0.655 AVG Training Acc 63.08 % AVG Validation Acc 50.20 %
# Epoch:20/200 AVG Training Loss:0.590 AVG Validation Loss:0.540 AVG Training Acc 72.68 % AVG Validation Acc 72.01 %
# Epoch:30/200 AVG Training Loss:0.505 AVG Validation Loss:0.603 AVG Training Acc 79.14 % AVG Validation Acc 67.16 %
# Epoch:40/200 AVG Training Loss:0.422 AVG Validation Loss:0.513 AVG Training Acc 83.40 % AVG Validation Acc 78.47 %
# Epoch:50/200 AVG Training Loss:0.355 AVG Validation Loss:0.506 AVG Training Acc 85.91 % AVG Validation Acc 78.87 %
# Epoch:60/200 AVG Training Loss:0.306 AVG Validation Loss:0.487 AVG Training Acc 86.91 % AVG Validation Acc 79.41 %
# Epoch:70/200 AVG Training Loss:0.294 AVG Validation Loss:0.474 AVG Training Acc 87.32 % AVG Validation Acc 79.68 %
# Epoch:80/200 AVG Training Loss:0.284 AVG Validation Loss:0.469 AVG Training Acc 87.61 % AVG Validation Acc 79.68 %
# Epoch:90/200 AVG Training Loss:0.280 AVG Validation Loss:0.474 AVG Training Acc 87.70 % AVG Validation Acc 79.00 %
# Epoch    98: reducing learning rate of group 0 to 3.3000e-04.
# Epoch:100/200 AVG Training Loss:0.255 AVG Validation Loss:0.494 AVG Training Acc 88.48 % AVG Validation Acc 78.87 %
# Epoch:110/200 AVG Training Loss:0.233 AVG Validation Loss:0.534 AVG Training Acc 89.29 % AVG Validation Acc 78.33 %
# Epoch:120/200 AVG Training Loss:0.218 AVG Validation Loss:0.568 AVG Training Acc 89.87 % AVG Validation Acc 78.33 %
# Epoch:130/200 AVG Training Loss:0.198 AVG Validation Loss:0.622 AVG Training Acc 90.90 % AVG Validation Acc 72.95 %
# Epoch   134: reducing learning rate of group 0 to 1.0890e-04.
# Epoch:140/200 AVG Training Loss:0.166 AVG Validation Loss:0.656 AVG Training Acc 92.24 % AVG Validation Acc 76.18 %
# Epoch:150/200 AVG Training Loss:0.146 AVG Validation Loss:0.725 AVG Training Acc 93.39 % AVG Validation Acc 75.37 %
# Epoch:160/200 AVG Training Loss:0.130 AVG Validation Loss:0.784 AVG Training Acc 94.13 % AVG Validation Acc 74.83 %
# Epoch:170/200 AVG Training Loss:0.134 AVG Validation Loss:0.808 AVG Training Acc 93.96 % AVG Validation Acc 75.37 %
# Epoch   170: reducing learning rate of group 0 to 3.5937e-05.
# Epoch:180/200 AVG Training Loss:0.108 AVG Validation Loss:0.879 AVG Training Acc 95.38 % AVG Validation Acc 75.24 %
# Epoch:190/200 AVG Training Loss:0.102 AVG Validation Loss:0.918 AVG Training Acc 95.65 % AVG Validation Acc 74.97 %
# Epoch:200/200 AVG Training Loss:0.097 AVG Validation Loss:0.952 AVG Training Acc 95.83 % AVG Validation Acc 74.43 %
# Split 8
#   0%|          | 0/200 [00:00<?, ?it/s]
# Epoch:10/200 AVG Training Loss:0.662 AVG Validation Loss:0.651 AVG Training Acc 59.83 % AVG Validation Acc 50.61 %
# Epoch:20/200 AVG Training Loss:0.600 AVG Validation Loss:0.507 AVG Training Acc 71.05 % AVG Validation Acc 74.56 %
# Epoch:30/200 AVG Training Loss:0.511 AVG Validation Loss:2.100 AVG Training Acc 74.95 % AVG Validation Acc 27.99 %
# Epoch:40/200 AVG Training Loss:0.591 AVG Validation Loss:0.468 AVG Training Acc 77.79 % AVG Validation Acc 79.27 %
# Epoch:50/200 AVG Training Loss:0.400 AVG Validation Loss:0.468 AVG Training Acc 83.99 % AVG Validation Acc 79.27 %
# Epoch:60/200 AVG Training Loss:0.330 AVG Validation Loss:0.465 AVG Training Acc 86.11 % AVG Validation Acc 80.08 %
# Epoch:70/200 AVG Training Loss:0.295 AVG Validation Loss:0.524 AVG Training Acc 87.09 % AVG Validation Acc 78.06 %
# Epoch:80/200 AVG Training Loss:0.283 AVG Validation Loss:0.466 AVG Training Acc 87.30 % AVG Validation Acc 80.89 %
# Epoch:90/200 AVG Training Loss:0.267 AVG Validation Loss:0.513 AVG Training Acc 88.03 % AVG Validation Acc 78.73 %
# Epoch    97: reducing learning rate of group 0 to 3.3000e-04.
# Epoch:100/200 AVG Training Loss:0.235 AVG Validation Loss:0.481 AVG Training Acc 89.47 % AVG Validation Acc 79.00 %
# Epoch:110/200 AVG Training Loss:0.213 AVG Validation Loss:0.546 AVG Training Acc 90.28 % AVG Validation Acc 77.79 %
# Epoch:120/200 AVG Training Loss:0.206 AVG Validation Loss:0.542 AVG Training Acc 90.66 % AVG Validation Acc 77.52 %
# Epoch:130/200 AVG Training Loss:0.207 AVG Validation Loss:0.605 AVG Training Acc 90.72 % AVG Validation Acc 76.04 %
# Epoch   133: reducing learning rate of group 0 to 1.0890e-04.
# Epoch:140/200 AVG Training Loss:0.167 AVG Validation Loss:0.575 AVG Training Acc 92.74 % AVG Validation Acc 76.45 %
# Epoch:150/200 AVG Training Loss:0.150 AVG Validation Loss:0.606 AVG Training Acc 93.65 % AVG Validation Acc 76.04 %
# Epoch:160/200 AVG Training Loss:0.152 AVG Validation Loss:0.632 AVG Training Acc 93.47 % AVG Validation Acc 75.91 %
# Epoch   169: reducing learning rate of group 0 to 3.5937e-05.
# Epoch:170/200 AVG Training Loss:0.138 AVG Validation Loss:0.711 AVG Training Acc 94.13 % AVG Validation Acc 75.64 %
# Epoch:180/200 AVG Training Loss:0.121 AVG Validation Loss:0.730 AVG Training Acc 95.09 % AVG Validation Acc 76.04 %
# Epoch:190/200 AVG Training Loss:0.116 AVG Validation Loss:0.748 AVG Training Acc 95.20 % AVG Validation Acc 75.24 %
# Epoch:200/200 AVG Training Loss:0.111 AVG Validation Loss:0.764 AVG Training Acc 95.56 % AVG Validation Acc 75.24 %
# Split 9
#   0%|          | 0/200 [00:00<?, ?it/s]
# Epoch:10/200 AVG Training Loss:0.683 AVG Validation Loss:0.684 AVG Training Acc 60.85 % AVG Validation Acc 44.41 %
# ...
# Epoch:10/200 AVG Training Loss:0.680 AVG Validation Loss:0.696 AVG Training Acc 63.92 % AVG Validation Acc 42.93 %
# Epoch:20/200 AVG Training Loss:0.594 AVG Validation Loss:0.572 AVG Training Acc 71.32 % AVG Validation Acc 66.89 %
# Epoch:30/200 AVG Training Loss:0.517 AVG Validation Loss:0.596 AVG Training Acc 78.78 % AVG Validation Acc 68.37 %
# Epoch:40/200 AVG Training Loss:0.476 AVG Validation Loss:0.563 AVG Training Acc 81.43 % AVG Validation Acc 74.56 %
# Epoch:50/200 AVG Training Loss:0.416 AVG Validation Loss:0.553 AVG Training Acc 83.58 % AVG Validation Acc 76.85 %
# Epoch:60/200 AVG Training Loss:0.369 AVG Validation Loss:0.523 AVG Training Acc 85.10 % AVG Validation Acc 77.39 %
# Epoch:70/200 AVG Training Loss:0.320 AVG Validation Loss:0.499 AVG Training Acc 86.78 % AVG Validation Acc 78.33 %
# Epoch:80/200 AVG Training Loss:0.288 AVG Validation Loss:0.486 AVG Training Acc 87.61 % AVG Validation Acc 79.27 %
# Epoch:90/200 AVG Training Loss:0.267 AVG Validation Loss:0.498 AVG Training Acc 88.25 % AVG Validation Acc 78.20 %
# Epoch:100/200 AVG Training Loss:0.286 AVG Validation Loss:0.499 AVG Training Acc 87.36 % AVG Validation Acc 78.60 %
# Epoch   103: reducing learning rate of group 0 to 3.3000e-04.
# Epoch:110/200 AVG Training Loss:0.242 AVG Validation Loss:0.528 AVG Training Acc 89.33 % AVG Validation Acc 78.06 %
# Epoch:120/200 AVG Training Loss:0.232 AVG Validation Loss:0.601 AVG Training Acc 89.67 % AVG Validation Acc 75.77 %
# Epoch:130/200 AVG Training Loss:0.223 AVG Validation Loss:0.567 AVG Training Acc 90.25 % AVG Validation Acc 79.27 %
# Epoch   139: reducing learning rate of group 0 to 1.0890e-04.
# Epoch:140/200 AVG Training Loss:0.194 AVG Validation Loss:0.608 AVG Training Acc 91.41 % AVG Validation Acc 75.77 %
# Epoch:150/200 AVG Training Loss:0.173 AVG Validation Loss:0.625 AVG Training Acc 92.55 % AVG Validation Acc 76.45 %
# Epoch:160/200 AVG Training Loss:0.163 AVG Validation Loss:0.672 AVG Training Acc 93.00 % AVG Validation Acc 76.72 %
# Epoch:170/200 AVG Training Loss:0.159 AVG Validation Loss:0.682 AVG Training Acc 92.99 % AVG Validation Acc 75.64 %
# Epoch   175: reducing learning rate of group 0 to 3.5937e-05.
# Epoch:180/200 AVG Training Loss:0.141 AVG Validation Loss:0.737 AVG Training Acc 94.01 % AVG Validation Acc 75.50 %
# Epoch:190/200 AVG Training Loss:0.136 AVG Validation Loss:0.760 AVG Training Acc 94.19 % AVG Validation Acc 75.10 %
# Epoch:200/200 AVG Training Loss:0.134 AVG Validation Loss:0.793 AVG Training Acc 94.30 % AVG Validation Acc 74.70 %
# exam_gifted
# Replica 1
# 0it [00:00, ?it/s]
# Split 1
#   0%|          | 0/200 [00:00<?, ?it/s]
# New Best F1_score found: 0.97%
# Epoch: 1
#  Accuracy: 72.45
# AUC: 49.46
# New Best F1_score found: 13.23%
# Epoch: 2
#  Accuracy: 70.03
# AUC: 53.17
# New Best F1_score found: 24.93%
# Epoch: 3
#  Accuracy: 65.99
# AUC: 54.04
# New Best F1_score found: 29.22%
# Epoch: 4
#  Accuracy: 62.23
# AUC: 54.13
# New Best F1_score found: 33.18%
# Epoch: 5
#  Accuracy: 61.02
# AUC: 53.99
# New Best F1_score found: 33.78%
# Epoch: 6
#  Accuracy: 59.95
# AUC: 54.15
# Epoch:10/200 AVG Training Loss:0.675 AVG Validation Loss:0.687 AVG Training Acc 56.74 % AVG Validation Acc 61.16 %
# New Best F1_score found: 35.35%
# Epoch: 10
#  Accuracy: 61.16
# AUC: 55.66
# New Best F1_score found: 36.54%
# Epoch: 16
#  Accuracy: 56.59
# AUC: 55.23
# Epoch    17: reducing learning rate of group 0 to 3.3000e-04.
# Epoch:20/200 AVG Training Loss:0.580 AVG Validation Loss:0.700 AVG Training Acc 72.25 % AVG Validation Acc 59.01 %
# Epoch:30/200 AVG Training Loss:0.444 AVG Validation Loss:0.614 AVG Training Acc 78.92 % AVG Validation Acc 71.91 %
# Epoch:40/200 AVG Training Loss:0.428 AVG Validation Loss:0.602 AVG Training Acc 79.90 % AVG Validation Acc 72.45 %
# Epoch:50/200 AVG Training Loss:0.417 AVG Validation Loss:0.602 AVG Training Acc 80.47 % AVG Validation Acc 72.85 %
# Epoch:60/200 AVG Training Loss:0.406 AVG Validation Loss:0.593 AVG Training Acc 80.82 % AVG Validation Acc 72.58 %
# Epoch:70/200 AVG Training Loss:0.413 AVG Validation Loss:0.596 AVG Training Acc 80.58 % AVG Validation Acc 72.45 %
# Epoch:80/200 AVG Training Loss:0.397 AVG Validation Loss:0.586 AVG Training Acc 81.39 % AVG Validation Acc 73.12 %
# Epoch    88: reducing learning rate of group 0 to 1.0890e-04.
# Epoch:90/200 AVG Training Loss:0.389 AVG Validation Loss:0.586 AVG Training Acc 81.76 % AVG Validation Acc 72.58 %
# Epoch:100/200 AVG Training Loss:0.385 AVG Validation Loss:0.587 AVG Training Acc 82.00 % AVG Validation Acc 72.85 %
# Epoch:110/200 AVG Training Loss:0.384 AVG Validation Loss:0.589 AVG Training Acc 82.10 % AVG Validation Acc 73.12 %
# Epoch:120/200 AVG Training Loss:0.384 AVG Validation Loss:0.587 AVG Training Acc 82.16 % AVG Validation Acc 73.12 %
# Epoch   124: reducing learning rate of group 0 to 3.5937e-05.
# Epoch:130/200 AVG Training Loss:0.378 AVG Validation Loss:0.591 AVG Training Acc 82.35 % AVG Validation Acc 72.85 %
# Epoch:140/200 AVG Training Loss:0.377 AVG Validation Loss:0.594 AVG Training Acc 82.30 % AVG Validation Acc 72.98 %
# Epoch:150/200 AVG Training Loss:0.375 AVG Validation Loss:0.597 AVG Training Acc 82.35 % AVG Validation Acc 73.52 %
# Epoch:160/200 AVG Training Loss:0.373 AVG Validation Loss:0.601 AVG Training Acc 82.66 % AVG Validation Acc 72.98 %
# Epoch   160: reducing learning rate of group 0 to 1.1859e-05.
# Epoch:170/200 AVG Training Loss:0.370 AVG Validation Loss:0.603 AVG Training Acc 82.87 % AVG Validation Acc 72.98 %
# Epoch:180/200 AVG Training Loss:0.370 AVG Validation Loss:0.605 AVG Training Acc 82.82 % AVG Validation Acc 72.98 %
# Epoch:190/200 AVG Training Loss:0.369 AVG Validation Loss:0.605 AVG Training Acc 82.93 % AVG Validation Acc 72.98 %
# Epoch   196: reducing learning rate of group 0 to 3.9135e-06.
# Epoch:200/200 AVG Training Loss:0.368 AVG Validation Loss:0.607 AVG Training Acc 82.86 % AVG Validation Acc 72.98 %
# Split 2
#   0%|          | 0/200 [00:00<?, ?it/s]
# New Best F1_score found: 38.31%
# Epoch: 5
#  Accuracy: 66.67
# AUC: 60.64
# New Best F1_score found: 38.66%
# Epoch: 6
#  Accuracy: 65.46
# AUC: 60.75
# Epoch:10/200 AVG Training Loss:0.681 AVG Validation Loss:0.679 AVG Training Acc 54.48 % AVG Validation Acc 65.99 %
# New Best F1_score found: 40.77%
# Epoch: 12
#  Accuracy: 46.51
# AUC: 53.65
# New Best F1_score found: 42.96%
# Epoch: 13
#  Accuracy: 27.55
# AUC: 49.13
# Epoch    17: reducing learning rate of group 0 to 3.3000e-04.
# Epoch:20/200 AVG Training Loss:0.650 AVG Validation Loss:0.755 AVG Training Acc 65.79 % AVG Validation Acc 61.56 %
# Epoch:30/200 AVG Training Loss:0.610 AVG Validation Loss:0.980 AVG Training Acc 68.19 % AVG Validation Acc 40.73 %
# Epoch:40/200 AVG Training Loss:0.608 AVG Validation Loss:0.691 AVG Training Acc 72.68 % AVG Validation Acc 67.20 %
# Epoch:50/200 AVG Training Loss:0.531 AVG Validation Loss:0.678 AVG Training Acc 75.23 % AVG Validation Acc 68.55 %
# Epoch:60/200 AVG Training Loss:0.541 AVG Validation Loss:0.622 AVG Training Acc 75.79 % AVG Validation Acc 71.91 %
# Epoch:70/200 AVG Training Loss:0.462 AVG Validation Loss:0.596 AVG Training Acc 78.96 % AVG Validation Acc 71.64 %
# Epoch:80/200 AVG Training Loss:0.431 AVG Validation Loss:0.581 AVG Training Acc 79.87 % AVG Validation Acc 72.18 %
# Epoch:90/200 AVG Training Loss:0.417 AVG Validation Loss:0.591 AVG Training Acc 80.68 % AVG Validation Acc 71.77 %
# Epoch:100/200 AVG Training Loss:0.412 AVG Validation Loss:0.580 AVG Training Acc 80.91 % AVG Validation Acc 72.18 %
# Epoch   109: reducing learning rate of group 0 to 1.0890e-04.
# Epoch:110/200 AVG Training Loss:0.408 AVG Validation Loss:0.577 AVG Training Acc 80.91 % AVG Validation Acc 72.45 %
# Epoch:120/200 AVG Training Loss:0.401 AVG Validation Loss:0.576 AVG Training Acc 81.30 % AVG Validation Acc 72.04 %
# Epoch:130/200 AVG Training Loss:0.401 AVG Validation Loss:0.575 AVG Training Acc 81.33 % AVG Validation Acc 72.31 %
# Epoch:140/200 AVG Training Loss:0.400 AVG Validation Loss:0.577 AVG Training Acc 81.38 % AVG Validation Acc 72.31 %
# Epoch:150/200 AVG Training Loss:0.400 AVG Validation Loss:0.577 AVG Training Acc 81.27 % AVG Validation Acc 72.18 %
# Epoch:160/200 AVG Training Loss:0.399 AVG Validation Loss:0.585 AVG Training Acc 81.31 % AVG Validation Acc 72.31 %
# Epoch   163: reducing learning rate of group 0 to 3.5937e-05.
# Epoch:170/200 AVG Training Loss:0.397 AVG Validation Loss:0.582 AVG Training Acc 81.46 % AVG Validation Acc 72.31 %
# Epoch:180/200 AVG Training Loss:0.396 AVG Validation Loss:0.582 AVG Training Acc 81.49 % AVG Validation Acc 72.45 %
# Epoch:190/200 AVG Training Loss:0.395 AVG Validation Loss:0.583 AVG Training Acc 81.60 % AVG Validation Acc 72.85 %
# Epoch   199: reducing learning rate of group 0 to 1.1859e-05.
# Epoch:200/200 AVG Training Loss:0.395 AVG Validation Loss:0.584 AVG Training Acc 81.67 % AVG Validation Acc 73.12 %
# Split 3
#   0%|          | 0/200 [00:00<?, ?it/s]
# Epoch:10/200 AVG Training Loss:0.682 AVG Validation Loss:0.682 AVG Training Acc 54.55 % AVG Validation Acc 62.10 %
# New Best F1_score found: 45.94%
# Epoch: 12
#  Accuracy: 63.31
# AUC: 64.28
# Epoch    17: reducing learning rate of group 0 to 3.3000e-04.
# Epoch:20/200 AVG Training Loss:0.624 AVG Validation Loss:0.668 AVG Training Acc 66.37 % AVG Validation Acc 67.20 %
# Epoch:30/200 AVG Training Loss:0.520 AVG Validation Loss:0.605 AVG Training Acc 76.57 % AVG Validation Acc 72.04 %
# Epoch:40/200 AVG Training Loss:0.434 AVG Validation Loss:0.588 AVG Training Acc 80.05 % AVG Validation Acc 72.45 %
# Epoch:50/200 AVG Training Loss:0.444 AVG Validation Loss:0.591 AVG Training Acc 79.15 % AVG Validation Acc 72.72 %
# Epoch:60/200 AVG Training Loss:0.421 AVG Validation Loss:0.569 AVG Training Acc 81.06 % AVG Validation Acc 73.39 %
# Epoch:70/200 AVG Training Loss:0.405 AVG Validation Loss:0.575 AVG Training Acc 80.93 % AVG Validation Acc 72.45 %
# Epoch    71: reducing learning rate of group 0 to 1.0890e-04.
# Epoch:80/200 AVG Training Loss:0.399 AVG Validation Loss:0.580 AVG Training Acc 81.20 % AVG Validation Acc 72.98 %
# Epoch:90/200 AVG Training Loss:0.397 AVG Validation Loss:0.583 AVG Training Acc 81.41 % AVG Validation Acc 72.58 %
# Epoch:100/200 AVG Training Loss:0.395 AVG Validation Loss:0.585 AVG Training Acc 81.56 % AVG Validation Acc 72.72 %
# Epoch   107: reducing learning rate of group 0 to 3.5937e-05.
# Epoch:110/200 AVG Training Loss:0.393 AVG Validation Loss:0.587 AVG Training Acc 81.57 % AVG Validation Acc 72.04 %
# Epoch:120/200 AVG Training Loss:0.392 AVG Validation Loss:0.588 AVG Training Acc 81.67 % AVG Validation Acc 71.91 %
# Epoch:130/200 AVG Training Loss:0.390 AVG Validation Loss:0.590 AVG Training Acc 81.73 % AVG Validation Acc 71.64 %
# Epoch:140/200 AVG Training Loss:0.390 AVG Validation Loss:0.593 AVG Training Acc 81.79 % AVG Validation Acc 71.51 %
# Epoch   143: reducing learning rate of group 0 to 1.1859e-05.
# Epoch:150/200 AVG Training Loss:0.389 AVG Validation Loss:0.593 AVG Training Acc 81.97 % AVG Validation Acc 71.64 %
# Epoch:160/200 AVG Training Loss:0.389 AVG Validation Loss:0.594 AVG Training Acc 81.97 % AVG Validation Acc 71.51 %
# Epoch:170/200 AVG Training Loss:0.388 AVG Validation Loss:0.594 AVG Training Acc 81.94 % AVG Validation Acc 71.64 %
# Epoch   179: reducing learning rate of group 0 to 3.9135e-06.
# Epoch:180/200 AVG Training Loss:0.388 AVG Validation Loss:0.595 AVG Training Acc 82.00 % AVG Validation Acc 71.77 %
# Epoch:190/200 AVG Training Loss:0.389 AVG Validation Loss:0.595 AVG Training Acc 81.81 % AVG Validation Acc 71.77 %
# Epoch:200/200 AVG Training Loss:0.388 AVG Validation Loss:0.595 AVG Training Acc 81.95 % AVG Validation Acc 71.77 %
# Split 4
#   0%|          | 0/200 [00:00<?, ?it/s]
# Epoch:10/200 AVG Training Loss:0.678 AVG Validation Loss:0.685 AVG Training Acc 55.41 % AVG Validation Acc 65.46 %
# Epoch    17: reducing learning rate of group 0 to 3.3000e-04.
# Epoch:20/200 AVG Training Loss:0.674 AVG Validation Loss:0.675 AVG Training Acc 57.73 % AVG Validation Acc 68.95 %
# Epoch:30/200 AVG Training Loss:0.629 AVG Validation Loss:0.658 AVG Training Acc 65.77 % AVG Validation Acc 70.56 %
# Epoch:40/200 AVG Training Loss:0.490 AVG Validation Loss:0.692 AVG Training Acc 79.45 % AVG Validation Acc 69.35 %
# Epoch:50/200 AVG Training Loss:0.443 AVG Validation Loss:0.632 AVG Training Acc 79.13 % AVG Validation Acc 71.24 %
# Epoch:60/200 AVG Training Loss:0.423 AVG Validation Loss:0.600 AVG Training Acc 80.13 % AVG Validation Acc 71.37 %
# Epoch:70/200 AVG Training Loss:0.412 AVG Validation Loss:0.609 AVG Training Acc 80.57 % AVG Validation Acc 71.10 %
# Epoch    74: reducing learning rate of group 0 to 1.0890e-04.
# Epoch:80/200 AVG Training Loss:0.405 AVG Validation Loss:0.596 AVG Training Acc 80.92 % AVG Validation Acc 71.51 %
# Epoch:90/200 AVG Training Loss:0.412 AVG Validation Loss:0.595 AVG Training Acc 80.71 % AVG Validation Acc 71.51 %
# Epoch:100/200 AVG Training Loss:0.402 AVG Validation Loss:0.600 AVG Training Acc 81.17 % AVG Validation Acc 71.91 %
# Epoch:110/200 AVG Training Loss:0.402 AVG Validation Loss:0.590 AVG Training Acc 81.20 % AVG Validation Acc 71.64 %
# Epoch   110: reducing learning rate of group 0 to 3.5937e-05.
# Epoch:120/200 AVG Training Loss:0.400 AVG Validation Loss:0.594 AVG Training Acc 81.41 % AVG Validation Acc 72.31 %
# Epoch:130/200 AVG Training Loss:0.399 AVG Validation Loss:0.597 AVG Training Acc 81.37 % AVG Validation Acc 72.31 %
# Epoch:140/200 AVG Training Loss:0.397 AVG Validation Loss:0.595 AVG Training Acc 81.37 % AVG Validation Acc 72.31 %
# Epoch   146: reducing learning rate of group 0 to 1.1859e-05.
# Epoch:150/200 AVG Training Loss:0.397 AVG Validation Loss:0.594 AVG Training Acc 81.49 % AVG Validation Acc 72.31 %
# Epoch:160/200 AVG Training Loss:0.396 AVG Validation Loss:0.594 AVG Training Acc 81.51 % AVG Validation Acc 72.18 %
# Epoch:170/200 AVG Training Loss:0.396 AVG Validation Loss:0.594 AVG Training Acc 81.48 % AVG Validation Acc 72.18 %
# Epoch:180/200 AVG Training Loss:0.396 AVG Validation Loss:0.593 AVG Training Acc 81.47 % AVG Validation Acc 72.18 %
# Epoch   182: reducing learning rate of group 0 to 3.9135e-06.
# Epoch:190/200 AVG Training Loss:0.395 AVG Validation Loss:0.593 AVG Training Acc 81.32 % AVG Validation Acc 72.31 %
# Epoch:200/200 AVG Training Loss:0.396 AVG Validation Loss:0.593 AVG Training Acc 81.46 % AVG Validation Acc 72.31 %
# Split 5
#   0%|          | 0/200 [00:00<?, ?it/s]
# Epoch:10/200 AVG Training Loss:0.683 AVG Validation Loss:0.684 AVG Training Acc 54.06 % AVG Validation Acc 64.52 %
# Epoch    17: reducing learning rate of group 0 to 3.3000e-04.
# Epoch:20/200 AVG Training Loss:0.610 AVG Validation Loss:0.634 AVG Training Acc 68.16 % AVG Validation Acc 70.16 %
# Epoch:30/200 AVG Training Loss:0.457 AVG Validation Loss:0.618 AVG Training Acc 79.16 % AVG Validation Acc 70.83 %
# Epoch:40/200 AVG Training Loss:0.419 AVG Validation Loss:0.592 AVG Training Acc 80.38 % AVG Validation Acc 72.04 %
# Epoch:50/200 AVG Training Loss:0.406 AVG Validation Loss:0.585 AVG Training Acc 80.92 % AVG Validation Acc 72.04 %
# Epoch:60/200 AVG Training Loss:0.402 AVG Validation Loss:0.586 AVG Training Acc 81.09 % AVG Validation Acc 72.18 %
# Epoch    61: reducing learning rate of group 0 to 1.0890e-04.
# Epoch:70/200 AVG Training Loss:0.391 AVG Validation Loss:0.584 AVG Training Acc 81.77 % AVG Validation Acc 72.31 %
# Epoch:80/200 AVG Training Loss:0.387 AVG Validation Loss:0.587 AVG Training Acc 81.96 % AVG Validation Acc 71.51 %
# Epoch:90/200 AVG Training Loss:0.384 AVG Validation Loss:0.589 AVG Training Acc 82.05 % AVG Validation Acc 71.51 %
# Epoch    97: reducing learning rate of group 0 to 3.5937e-05.
# Epoch:100/200 AVG Training Loss:0.377 AVG Validation Loss:0.589 AVG Training Acc 82.67 % AVG Validation Acc 71.51 %
# Epoch:110/200 AVG Training Loss:0.376 AVG Validation Loss:0.595 AVG Training Acc 82.81 % AVG Validation Acc 71.64 %
# Epoch:120/200 AVG Training Loss:0.374 AVG Validation Loss:0.596 AVG Training Acc 82.98 % AVG Validation Acc 71.51 %
# Epoch:130/200 AVG Training Loss:0.373 AVG Validation Loss:0.598 AVG Training Acc 83.02 % AVG Validation Acc 71.24 %
# Epoch   133: reducing learning rate of group 0 to 1.1859e-05.
# Epoch:140/200 AVG Training Loss:0.372 AVG Validation Loss:0.602 AVG Training Acc 83.06 % AVG Validation Acc 70.97 %

# %%
#for each target and number of replicas
results_50 = {}

total_results_50 = pd.DataFrame(columns =['Target', 'Repeat', 'Fold', 'Accuracy', 'Precision_(Binary)', 'Recall_(Binary)', 
                                       'F1-score_(Binary)', 'AUC'])

for i in targets:
    results_50[i] = {}
    for k in range(1, replicas + 1):
        results_50[i][f'repeat{k}'] = pd.DataFrame.from_dict(target_df_dict_50[i][f'repeat{k}'], orient = 'index') # convert dict to dataframe
        
        #explode to get eacxh epoch as a row
        results_50[i][f'repeat{k}'] = results_50[i][f'repeat{k}'].explode(list(results_50[i][f'repeat{k}'].columns))
        results_50[i][f'repeat{k}']['fold'] = results_50[i][f'repeat{k}'].index
        results_50[i][f'repeat{k}'].reset_index(drop = True, inplace = True)
        
        #obtain the result that was obtained at the last possible choice
        placeholder_df = results_50[i][f'repeat{k}'].groupby('fold')[['val_acc', 'precision',
                                                                      'recall', 'f1_score', 'auroc']].last().reset_index()
        
        #making adjustments to concat with total_results properly
        placeholder_df.columns = ['Fold', 'Accuracy', 'Precision_(Binary)', 'Recall_(Binary)', 'F1-score_(Binary)', 'AUC']
        placeholder_df = placeholder_df.reindex(columns = total_results_50.columns)
        
        #fill new missing values
        placeholder_df['Target'], placeholder_df['Repeat'] = i, k
        total_results_50 = total_results_50.append(placeholder_df, ignore_index = True)

# %% [markdown]
# ### Test on data - The first 75 days
#
# Same hyper-parameters.

# %%
#create main dict results for 75 days
target_df_dict_75 = {}

for k in tqdm(targets):
    print(k)
    
    #create main dict results
    
    target_df_dict_75[f'{(k)}'] = {}
    y = df_targets[k].values

    #create a list containing one value per row
    all_indices = list(range(len(df_targets)))
    
    #using train test split to later apply the rule accordingly
    train_ind, test_ind = train_test_split(all_indices, test_size=0.2, 
                                           random_state = 5, stratify = y)
    
    #applied train_test_split rules accordingly
    X_train_val = nd_array_100[train_ind,:51,:]
    y_train_val = y[train_ind]
    
    X_test = nd_array_100[test_ind, :51, :]
    y_test = y[test_ind]    
        
    #reset "best accuracy for treshold i and target k"     
    for repeat in range(replicas):
        print('Replica {}'.format(repeat+1))
        
        foldperf={}
        best_f1_score = 0
        
        #make train_val split
        for fold, (train_idx,val_idx) in tqdm(enumerate(splits.split(X_train_val, y_train_val))):
            print('Split {}'.format(fold + 1))
            
            #make split between train and Val
            X_train, y_train = X_train_val[train_idx], y_train_val[train_idx]
            X_val, y_val = X_train_val[val_idx], y_train_val[val_idx]
            
            #scaling requires one scaler per channel (feature)
            scalers = {}
            for feature in range(X_train.shape[2]):
                           
                scalers[feature] = combination[0][7]
                X_train[:, :, feature] = scalers[feature].fit_transform(X_train[:, :, feature]) 

            for col in range(X_val.shape[2]):
                X_val[:, :, feature] = scalers[feature].transform(X_val[:, :, feature]) 
            
            #need to oversample - will use smote
            #will also require oneoversampler per channel (feature)
            samplers = {}
            
            #create new nd_array with the correct size - 2 * majority class 
            X_train_res = np.zeros(shape = (2* (int(sc.stats.mode(y_train)[1])), X_train.shape[1], X_train.shape[2]))
            for feature in range(X_train.shape[2]):
                           
                samplers[feature] = SMOTE()
                X_train_res[:, :, feature], y_train_res = samplers[feature].fit_resample(X_train[:, :, feature], y_train) 
            
            #second, convert everything to pytorch tensor - we will convert to tensor dataset and 
            X_train_tensors = torch.from_numpy(X_train_res)
            X_val_tensors = torch.from_numpy(X_val)
            
            #convert X tensors to format FloatTensor
            X_train_tensors = X_train_tensors.type(torch.cuda.FloatTensor)
            X_val_tensors = X_val_tensors.type(torch.cuda.FloatTensor)
            
            #create y_tensor
            y_train_tensors = torch.from_numpy(y_train_res)
            y_val_tensors = torch.from_numpy(y_val)
            
            #convert y tensors to format longtensor
            y_train_tensors = y_train_tensors.type(torch.cuda.FloatTensor)
            y_val_tensors = y_val_tensors.type(torch.cuda.FloatTensor)
            
            #create Tensor Datasets and dataloaders for both Train and Val
            train_dataset = TensorDataset(X_train_tensors, y_train_tensors)
            val_dataset = TensorDataset(X_val_tensors, y_val_tensors)
            train_loader = DataLoader(train_dataset, batch_size=batch_size)
            val_loader = DataLoader(val_dataset, batch_size=batch_size)
    
            #creates new model for each 
            model = LSTM_Uni(num_classes, input_size, hidden_size, num_layers, X_train_tensors.shape[1], dropout).to('cuda') #our lstm class
  
            #running condition on optimizer
            if combination[0][6] == 'adam':
                optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
            
            elif combination[0][6] == 'rmsprop':
                optimizer = torch.optim.RMSprop(model.parameters(), lr=learning_rate)
            
            elif combination[0][6] == 'adagrad':
                optimizer = torch.optim.Adagrad(model.parameters(), lr=learning_rate)
            
            else:
                optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
            
            scheduler = ReduceLROnPlateau(optimizer, 
                                 'min', 
                                 patience = 15,
                                 cooldown = 20,
                                threshold=0.00001,
                                factor = 0.33,
                                verbose = True)
            
            history = {'train_loss': [], 'val_loss': [],'train_acc':[],'val_acc':[], 'precision': [],
                      'recall' : [], 'auroc': [], 'f1_score' : []}

            for epoch in tqdm(range(num_epochs)):
                train_loss, train_correct=train_epoch(model,train_loader,criterion,optimizer)
                val_loss, val_correct, precision, recall, auroc, f1 = valid_epoch(model,val_loader,criterion)

                train_loss = train_loss / len(train_loader.sampler)
                train_acc = train_correct / len(train_loader.sampler) * 100
                val_loss = val_loss / len(val_loader.sampler)
                val_acc = val_correct / len(val_loader.sampler) * 100
        
        
                if (epoch+1) % 10 == 0: 
                 print("Epoch:{}/{} AVG Training Loss:{:.3f} AVG Validation Loss:{:.3f} AVG Training Acc {:.2f} % AVG Validation Acc {:.2f} %".format(epoch + 1,
                                                                                                             num_epochs,
                                                                                                             train_loss,
                                                                                                             val_loss,
                                                                                                             train_acc,
                                                                                                             val_acc))
                history['train_loss'].append(train_loss)
                history['val_loss'].append(val_loss)
                history['train_acc'].append(train_acc)
                history['val_acc'].append(val_acc)
                history['precision'].append(precision)
                history['recall'].append(recall)
                history['auroc'].append(auroc)
                history['f1_score'].append(f1)
                scheduler.step(val_loss)
    
                if f1 > best_f1_score:
            
                #replace best accuracy and save best model
                    print(f'New Best F1_score found: {f1*100:.2f}%\nEpoch: {epoch + 1}\n', 
                         f'Accuracy: {val_acc:.2f}\nAUC: {auroc*100:.2f}')
                    best_f1_score = f1
                    best = deepcopy(model)
                    curr_epoch = epoch + 1
                    
            #store fold performance
            foldperf['fold{}'.format(fold+1)] = history
    
        #create dict to store fold performance
        target_df_dict_75[f'{(k)}']['repeat{}'.format(repeat + 1)] = foldperf

# %%
#for each target and number of replicas
results_75 = {}

total_results_75 = pd.DataFrame(columns =['Target', 'Repeat', 'Fold', 'Accuracy', 'Precision_(Binary)', 'Recall_(Binary)', 
                                       'F1-score_(Binary)', 'AUC'])

for i in targets:
    results_75[i] = {}
    for k in range(1, replicas + 1):
        results_75[i][f'repeat{k}'] = pd.DataFrame.from_dict(target_df_dict_75[i][f'repeat{k}'], orient = 'index') # convert dict to dataframe
        
        #explode to get eacxh epoch as a row
        results_75[i][f'repeat{k}'] = results_75[i][f'repeat{k}'].explode(list(results_75[i][f'repeat{k}'].columns))
        results_75[i][f'repeat{k}']['fold'] = results_75[i][f'repeat{k}'].index
        results_75[i][f'repeat{k}'].reset_index(drop = True, inplace = True)
        
        #obtain the result that was obtained at the last possible choice
        placeholder_df = results_75[i][f'repeat{k}'].groupby('fold')[['val_acc', 'precision',
                                                                      'recall', 'f1_score', 'auroc']].last().reset_index()
        
        #making adjustments to concat with total_results properly
        placeholder_df.columns = ['Fold', 'Accuracy', 'Precision_(Binary)', 'Recall_(Binary)', 'F1-score_(Binary)', 'AUC']
        placeholder_df = placeholder_df.reindex(columns = total_results_75.columns)
        
        #fill new missing values
        placeholder_df['Target'], placeholder_df['Repeat'] = i, k
        total_results_75 = total_results_75.append(placeholder_df, ignore_index = True)

# %% [markdown]
# ### Saving results

# %%
#saving agregate results in Excel File
with pd.ExcelWriter('../Data/Modeling Stage/Results/IMS/Clicks per day/model_7_results.xlsx') as writer:
    total_results_25.to_excel(writer, sheet_name = 'total_results_25', index = False)
    total_results_50.to_excel(writer, sheet_name = 'total_results_50', index = False)
    total_results_75.to_excel(writer, sheet_name = 'total_results_75', index = False)
    
#saving raw_results in json file
import json
daily_clicks_raw_results = [target_df_dict_25, 
               target_df_dict_50, 
               target_df_dict_75]

# e.g. file = './data.json' 
with open("../Data/Modeling Stage/Results/IMS/Clicks per day/model_7_raw_results.json", 'w') as f: 
    json.dump(daily_clicks_raw_results, f,  indent=4)
