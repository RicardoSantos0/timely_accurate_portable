# %% [markdown]
# ## Getting Support Figures
#
# In this notebook, we'll just post the code used to obtain figures that will be relevant for the MSc Thesis that do not use, in any regard, the educational dataset.

# %%
#importar packages para manipulação dos diretórios
import os
import glob

#packages standard para tratamento de dados
import pandas as pd
import numpy as np
import scipy as sc

#visualização
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

#packages geográficos
import requests

sns.set()
# %matplotlib inline

# %% [markdown]
# #### Uploading Files

# %%
#AVISO: NÃO MUDAR LOCALIZAÇÕES DOS SCRIPTS OU FICHEIROS

historico = pd.read_csv('../Data/EDM_LA_nbr of papers.csv', sep = ';')

#Resultados
resultados = pd.read_excel("../Data/Modeling Stage/Results/IMS/Model_Results.xlsx", 
                               sheet_name = None)

# %%
resultados
# Out:
# {'At risk students':    Moment of prediction                            Model  Accuracy  \
#  0          10% Duration          Traditional Classifiers  0.802000
#  1          10% Duration                              KNN  0.786000
#  2          10% Duration                               LR  0.799000
#  3          10% Duration                               NB  0.542000
#  4          10% Duration                             CART  0.779000
#  5          10% Duration                              SVM  0.799000
#  6          10% Duration                             LSTM  0.792882
#  7          10% Duration  Traditional Classifiers - SMOTE  0.733000
#  8          10% Duration                     LSTM - SMOTE  0.587216
#  9          25% Duration          Traditional Classifiers  0.804000
#  10         25% Duration                              KNN  0.799000
#  11         25% Duration                               LR  0.799000
#  12         25% Duration                               NB  0.601000
#  13         25% Duration                             CART  0.783000
#  14         25% Duration                              SVM  0.802000
#  15         25% Duration                             LSTM  0.789636
#  16         25% Duration  Traditional Classifiers - SMOTE  0.725000
#  17         25% Duration                     LSTM - SMOTE  0.590434
#  18         33% Duration          Traditional Classifiers  0.812000
#  19         33% Duration                              KNN  0.799000
#  20         33% Duration                               LR  0.802000
#  21         33% Duration                               NB  0.562000
#  22         33% Duration                             CART  0.795000
#  23         33% Duration                              SVM  0.805000
#  24         33% Duration                             LSTM  0.786162
#  25         33% Duration  Traditional Classifiers - SMOTE  0.736000
#  26         33% Duration                     LSTM - SMOTE  0.593926
#  27         50% Duration          Traditional Classifiers  0.825000
#  28         50% Duration                              KNN  0.814000
#  29         50% Duration                               LR  0.802000
#  30         50% Duration                               NB  0.614000
#  31         50% Duration                             CART  0.813000
#  32         50% Duration                              SVM  0.809000
#  33         50% Duration                             LSTM  0.793044
#  34         50% Duration  Traditional Classifiers - SMOTE  0.764000
#  35         50% Duration                     LSTM - SMOTE  0.612012
#  36         10% Duration                Best Static Model  0.800000
#  37         10% Duration        Best Static Model - SMOTE  0.624000
#  38         25% Duration                Best Static Model  0.803000
#  39         25% Duration        Best Static Model - SMOTE  0.728000
#  40         33% Duration                Best Static Model  0.808000
#  41         33% Duration        Best Static Model - SMOTE  0.730000
#  42         50% Duration                Best Static Model  0.810000
#  43         50% Duration        Best Static Model - SMOTE  0.722000
#  44        100% Duration                Best Static Model  0.817000
#  45        100% Duration        Best Static Model - SMOTE  0.736000
#  46        100% Duration          Traditional Classifiers  0.886000
#  47        100% Duration                              KNN  0.841000
#  48        100% Duration                               LR  0.804000
#  49        100% Duration                               NB  0.758000
#  50        100% Duration                             CART  0.866000
#  51        100% Duration                              SVM  0.843000
#  52        100% Duration                             LSTM  0.791855
#  53        100% Duration  Traditional Classifiers - SMOTE  0.849000
#  54        100% Duration                     LSTM - SMOTE  0.606500
#
#      Accuracy (sd)  Precision  Precision (sd)    Recall  Recall (sd)     AUROC  \
#  0        0.023000   0.713000        0.208000  0.028000     0.013000  0.681000
#  1        0.029000   0.393000        0.095000  0.101000     0.070000  0.638000
#  2        0.023000   0.235000        0.401000  0.002000     0.001000  0.664000
#  3        0.024000   0.259000        0.026000  0.651000     0.128000  0.629000
#  4        0.024000   0.327000        0.072000  0.093000     0.026000  0.622000
#  5        0.024000   0.097000        0.275000  0.001000     0.001000  0.619000
#  6        0.005909   0.300855        0.185121  0.026542     0.019571  0.613547
#  7        0.024000   0.354000        0.029000  0.396000     0.041000  0.674000
#  8        0.028461   0.258983        0.016812  0.561794     0.049679  0.605824
#  9        0.024000   0.607000        0.120000  0.086000     0.028000  0.728000
#  10       0.026000   0.504000        0.068000  0.167000     0.039000  0.692000
#  11       0.023000   0.495000        0.146000  0.045000     0.019000  0.684000
#  12       0.025000   0.272000        0.018000  0.581000     0.049000  0.636000
#  13       0.029000   0.407000        0.067000  0.163000     0.037000  0.655000
#  14       0.028000   0.599000        0.142000  0.065000     0.024000  0.678000
#  15       0.025369   0.372446        0.129280  0.071183     0.039714  0.635719
#  16       0.023000   0.376000        0.027000  0.500000     0.043000  0.725000
#  17       0.054000   0.261015        0.015963  0.562912     0.052578  0.614280
#  18       0.025000   0.678000        0.086000  0.123000     0.027000  0.749000
#  19       0.025000   0.502000        0.068000  0.174000     0.035000  0.700000
#  20       0.023000   0.549000        0.099000  0.088000     0.022000  0.694000
#  21       0.025000   0.263000        0.016000  0.653000     0.047000  0.651000
#  22       0.027000   0.484000        0.059000  0.222000     0.038000  0.674000
#  23       0.027000   0.566000        0.096000  0.090000     0.023000  0.708000
#  24       0.011107   0.413688        0.089825  0.143318     0.043237  0.639798
#  25       0.025000   0.387000        0.029000  0.527000     0.050000  0.741000
#  26       0.026811   0.262348        0.016727  0.559342     0.051923  0.618995
#  27       0.020000   0.732000        0.064000  0.205000     0.035000  0.793000
#  28       0.024000   0.593000        0.062000  0.241000     0.034000  0.732000
#  29       0.020000   0.583000        0.119000  0.069000     0.019000  0.693000
#  30       0.025000   0.283000        0.018000  0.595000     0.047000  0.659000
#  31       0.026000   0.581000        0.048000  0.310000     0.035000  0.700000
#  32       0.023000   0.655000        0.092000  0.114000     0.026000  0.755000
#  33       0.010015   0.458269        0.101847  0.172439     0.054815  0.649291
#  34       0.020000   0.436000        0.028000  0.577000     0.040000  0.788000
#  35       0.037466   0.271068        0.021211  0.542429     0.062537  0.624036
#  36            NaN   0.602000             NaN  0.024000          NaN  0.678000
#  37            NaN   0.297000             NaN  0.633000          NaN  0.670000
#  38            NaN   0.623000             NaN  0.061000          NaN  0.713000
#  39            NaN   0.368000             NaN  0.485000          NaN  0.711000
#  40            NaN   0.643000             NaN  0.104000          NaN  0.718000
#  41            NaN   0.370000             NaN  0.485000          NaN  0.714000
#  42            NaN   0.660000             NaN  0.116000          NaN  0.730000
#  43            NaN   0.367000             NaN  0.523000          NaN  0.724000
#  44            NaN   0.727000             NaN  0.149000          NaN  0.756000
#  45            NaN   0.392000             NaN  0.557000          NaN  0.752000
#  46       0.011000   0.817000        0.035000  0.563000     0.044000  0.923000
#  47       0.017000   0.706000        0.048000  0.362000     0.036000  0.845000
#  48       0.018000   0.532000        0.060000  0.206000     0.033000  0.781000
#  49       0.018000   0.411000        0.034000  0.447000     0.063000  0.719000
#  50       0.024000   0.686000        0.038000  0.623000     0.044000  0.834000
#  51       0.014000   0.787000        0.054000  0.300000     0.046000  0.888000
#  52       0.010778   0.467576        0.069425  0.209756     0.040223  0.679971
#  53       0.011000   0.588000        0.024000  0.844000     0.032000  0.921000
#  54       0.040061   0.274978        0.021019  0.576412     0.073190  0.638375
#
#      AUROC (sd)
#  0     0.023000
#  1     0.029000
#  2     0.023000
#  3     0.024000
#  4     0.024000
#  5     0.024000
#  6     0.024000
#  7     0.024000
#  8     0.024353
#  9     0.024000
#  10    0.026000
#  11    0.023000
#  12    0.025000
#  13    0.029000
#  14    0.028000
#  15    0.025369
#  16    0.023000
#  17    0.023716
#  18    0.025000
#  19    0.025000
#  20    0.023000
#  21    0.025000
#  22    0.027000
#  23    0.027000
#  24    0.024280
#  25    0.025000
#  26    0.025266
#  27    0.020000
#  28    0.024000
#  29    0.020000
#  30    0.025000
#  31    0.026000
#  32    0.023000
#  33    0.025591
#  34    0.020000
#  35    0.026755
#  36         NaN
#  37         NaN
#  38         NaN
#  39         NaN
#  40         NaN
#  41         NaN
#  42         NaN
#  43         NaN
#  44         NaN
#  45         NaN
#  46    0.011000
#  47    0.017000
#  48    0.018000
#  49    0.018000
#  50    0.024000
#  51    0.014000
#  52    0.024746
#  53    0.011000
#  54    0.028277  ,
#  'High performing students':    Moment of prediction                            Model  Accuracy  \
#  0          10% Duration          Traditional Classifiers  0.723000
#  1          10% Duration                             LSTM  0.719504
#  2          10% Duration  Traditional Classifiers - SMOTE  0.592000
#  3          10% Duration                     LSTM - SMOTE  0.489005
#  4          25% Duration          Traditional Classifiers  0.725000
#  5          25% Duration                             LSTM  0.716811
#  6          25% Duration  Traditional Classifiers - SMOTE  0.581000
#  7          25% Duration                     LSTM - SMOTE  0.487430
#  8          33% Duration          Traditional Classifiers  0.731000
#  9          33% Duration                             LSTM  0.714641
#  10         33% Duration  Traditional Classifiers - SMOTE  0.599000
#  11         33% Duration                     LSTM - SMOTE  0.499985
#  12         50% Duration          Traditional Classifiers  0.735000
#  13         50% Duration                             LSTM  0.714874
#  14         50% Duration  Traditional Classifiers - SMOTE  0.611000
#  15         50% Duration                     LSTM - SMOTE  0.504932
#  16        100% Duration          Traditional Classifiers  0.782000
#  17        100% Duration                             LSTM  0.708320
#  18        100% Duration  Traditional Classifiers - SMOTE  0.763000
#  19         10% Duration                Best Static Model  0.723000
#  20         10% Duration        Best Static Model - SMOTE  0.586000
#  21         25% Duration                Best Static Model  0.725000
#  22         25% Duration        Best Static Model - SMOTE  0.595000
#  23         33% Duration                Best Static Model  0.727000
#  24         33% Duration        Best Static Model - SMOTE  0.702000
#  25         50% Duration                Best Static Model  0.729000
#  26         50% Duration        Best Static Model - SMOTE  0.582000
#  27        100% Duration                Best Static Model  0.728000
#  28        100% Duration        Best Static Model - SMOTE  0.595000
#  29        100% Duration                     LSTM - SMOTE  0.473121
#
#      Accuracy (sd)  Precision  Precision (sd)    Recall  Recall (sd)     AUROC  \
#  0        0.020000   0.504000        0.137000  0.033000     0.012000  0.598000
#  1        0.004524   0.275377        0.216809  0.013469     0.014318  0.563380
#  2        0.020000   0.592000        0.034000  0.508000    -0.034000  0.596000
#  3        0.050646   0.303340        0.014677  0.647460     0.101150  0.554848
#  4        0.023000   0.544000        0.117000  0.044000     0.016000  0.611000
#  5        0.006919   0.366182        0.160916  0.030760     0.022375  0.562709
#  6        0.022000   0.342000        0.019000  0.552000     0.035000  0.608000
#  7        0.487430   0.299114        0.013970  0.631092     0.082355  0.543162
#  8        0.021000   0.572000        0.076000  0.110000     0.021000  0.624000
#  9        0.008741   0.412522        0.103028  0.064223     0.028174  0.565369
#  10       0.022000   0.353000        0.020000  0.537000     0.034000  0.617000
#  11       0.036221   0.301258        0.015720  0.608078     0.070454  0.548835
#  12       0.021000   0.655000        0.085000  0.095000     0.019000  0.644000
#  13       0.008262   0.368140        0.141175  0.045505     0.028738  0.567493
#  14       0.022000   0.365000        0.020000  0.548000     0.037000  0.632000
#  15       0.025241   0.306155        0.013333  0.620828     0.047397  0.556631
#  16       0.017000   0.668000        0.034000  0.423000     0.029000  0.796000
#  17       0.011941   0.400928        0.101595  0.116629     0.049173  0.589280
#  18       0.017000   0.575000        0.029000  0.560000     0.034000  0.781000
#  19            NaN   0.533000             NaN  0.033000          NaN  0.593000
#  20            NaN   0.337000             NaN  0.520000          NaN  0.590000
#  21            NaN   0.558000             NaN  0.040000          NaN  0.603000
#  22            NaN   0.346000             NaN  0.519000          NaN  0.622000
#  23            NaN   0.591000             NaN  0.048000          NaN  0.606000
#  24            NaN   0.422000             NaN  0.207000          NaN  0.601000
#  25            NaN   0.602000             NaN  0.060000          NaN  0.611000
#  26            NaN   0.343000             NaN  0.555000          NaN  0.610000
#  27            NaN   0.584000             NaN  0.068000          NaN  0.634000
#  28            NaN   0.355000             NaN  0.564000          NaN  0.626000
#  29       0.050118   0.304450        0.017195  0.693678     0.081547  0.560310
#
#      AUROC (sd)
#  0     0.020000
#  1     0.021348
#  2     0.020000
#  3     0.022857
#  4     0.023000
#  5     0.023183
#  6     0.022000
#  7     0.023054
#  8     0.021000
#  9     0.020759
#  10    0.022000
#  11    0.025544
#  12    0.021000
#  13    0.022003
#  14    0.022000
#  15    0.021250
#  16    0.017000
#  17    0.022377
#  18    0.017000
#  19         NaN
#  20         NaN
#  21         NaN
#  22         NaN
#  23         NaN
#  24         NaN
#  25         NaN
#  26         NaN
#  27         NaN
#  28         NaN
#  29    0.026087  ,
#  'At-risk - R_Gonz':    Moment of prediction                            Model  Accuracy  \
#  0          10% Duration          Traditional Classifiers  0.686000
#  1          10% Duration                             LSTM  0.618262
#  2          10% Duration  Traditional Classifiers - SMOTE  0.633000
#  3          10% Duration                     LSTM - SMOTE  0.488615
#  4          25% Duration          Traditional Classifiers  0.743000
#  5          25% Duration                             LSTM  0.620872
#  6          25% Duration  Traditional Classifiers - SMOTE  0.722000
#  7          25% Duration                     LSTM - SMOTE  0.488962
#  8          33% Duration          Traditional Classifiers  0.780000
#  9          33% Duration                             LSTM  0.617976
#  10         33% Duration  Traditional Classifiers - SMOTE  0.740000
#  11         33% Duration                     LSTM - SMOTE  0.515208
#  12         50% Duration          Traditional Classifiers  0.820000
#  13         50% Duration                             LSTM  0.623657
#  14         50% Duration  Traditional Classifiers - SMOTE  0.890000
#  15         50% Duration                     LSTM - SMOTE  0.523035
#  16        100% Duration          Traditional Classifiers  0.948000
#  17        100% Duration                             LSTM  0.622370
#  18        100% Duration  Traditional Classifiers - SMOTE  0.948000
#  19         10% Duration                Best Static Model  0.675000
#  20         10% Duration        Best Static Model - SMOTE  0.630000
#  21         25% Duration                Best Static Model  0.717000
#  22         25% Duration        Best Static Model - SMOTE  0.681000
#  23         33% Duration                Best Static Model  0.754000
#  24         33% Duration        Best Static Model - SMOTE  0.719000
#  25         50% Duration                Best Static Model  0.761000
#  26         50% Duration        Best Static Model - SMOTE  0.737000
#  27        100% Duration                Best Static Model  0.800000
#  28        100% Duration        Best Static Model - SMOTE  0.781000
#  29        100% Duration                     LSTM - SMOTE  0.552819
#
#      Accuracy (sd)  Precision  Precision (sd)    Recall  Recall (sd)     AUROC  \
#  0        0.016000   0.638000        0.036000  0.416000     0.051000  0.726000
#  1        0.003105   0.440858        0.251984  0.012469     0.020907  0.552065
#  2        0.015000   0.512000        0.013000  0.747000     0.023000  0.725000
#  3        0.028766   0.403317        0.012453  0.705934     0.075157  0.542259
#  4        0.013000   0.724000        0.023000  0.527000     0.026000  0.806000
#  5        0.007691   0.510662        0.106792  0.086964     0.031143  0.560671
#  6        0.013000   0.608000        0.018000  0.762000     0.026000  0.818000
#  7        0.023229   0.399419        0.011483  0.674084     0.072151  0.535994
#  8        0.011000   0.779000        0.020000  0.591000     0.024000  0.847000
#  9        0.006654   0.458260        0.151123  0.055752     0.041589  0.554722
#  10       0.011000   0.626000        0.015000  0.790000     0.021000  0.848000
#  11       0.024569   0.409453        0.012904  0.610174     0.082971  0.545803
#  12       0.010000   0.791000        0.018000  0.716000     0.023000  0.891000
#  13       0.009295   0.499139        0.144225  0.122662     0.069956  0.578732
#  14       0.010000   0.705000        0.017000  0.822000     0.018000  0.890000
#  15       0.027067   0.411334        0.017356  0.579238     0.090474  0.548466
#  16       0.011000   0.950000        0.011000  0.911000     0.014000  0.986000
#  17       0.012459   0.495892        0.102263  0.263225     0.081345  0.605754
#  18       0.003000   0.942000        0.012000  0.922000     0.013000  0.986000
#  19            NaN   0.733000             NaN  0.234000          NaN  0.727000
#  20            NaN   0.510000             NaN  0.684000          NaN  0.706000
#  21            NaN   0.787000             NaN  0.352000          NaN  0.773000
#  22            NaN   0.569000             NaN  0.691000          NaN  0.758000
#  23            NaN   0.800000             NaN  0.474000          NaN  0.805000
#  24            NaN   0.611000             NaN  0.723000          NaN  0.805000
#  25            NaN   0.787000             NaN  0.512000          NaN  0.821000
#  26            NaN   0.638000             NaN  0.719000          NaN  0.815000
#  27            NaN   0.818000             NaN  0.610000          NaN  0.510000
#  28            NaN   0.702000             NaN  0.738000          NaN  0.850000
#  29       0.019344   0.438379        0.015421  0.612064     0.065700  0.592565
#
#      AUROC (sd) Unnamed: 10
#  0     0.016000         MLP
#  1     0.016575         NaN
#  2     0.015000          RF
#  3     0.017726         NaN
#  4     0.013000      Gboost
#  5     0.018651         NaN
#  6     0.013000          RF
#  7     0.018536         NaN
#  8     0.011000          RF
#  9     0.019314         NaN
#  10    0.011000          RF
#  11    0.017984         NaN
#  12    0.010000          RF
#  13    0.024610         NaN
#  14    0.009000          RF
#  15    0.022502         NaN
#  16    0.003000      GBoost
#  17    0.020547         NaN
#  18    0.003000          RF
#  19         NaN          RF
#  20         NaN          RF
#  21         NaN          RF
#  22         NaN         MLP
#  23         NaN          RF
#  24         NaN          RF
#  25         NaN          RF
#  26         NaN          RF
#  27         NaN          RF
#  28         NaN          RF
#  29    0.018888         NaN  ,
#  'High performing - R_Gonz':    Moment of prediction                            Model  Accuracy  \
#  0          10% Duration          Traditional Classifiers  0.810000
#  1          10% Duration                             LSTM  0.800674
#  2          10% Duration  Traditional Classifiers - SMOTE  0.757000
#  3          10% Duration                     LSTM - SMOTE  0.444894
#  4          25% Duration          Traditional Classifiers  0.836000
#  5          25% Duration                             LSTM  0.800568
#  6          25% Duration  Traditional Classifiers - SMOTE  0.815000
#  7          25% Duration                     LSTM - SMOTE  0.354985
#  8          33% Duration          Traditional Classifiers  0.848000
#  9          33% Duration                             LSTM  0.798148
#  10         33% Duration  Traditional Classifiers - SMOTE  0.828000
#  11         33% Duration                     LSTM - SMOTE  0.449377
#  12         50% Duration          Traditional Classifiers  0.865000
#  13         50% Duration                             LSTM  0.800842
#  14         50% Duration  Traditional Classifiers - SMOTE  0.791000
#  15         50% Duration                     LSTM - SMOTE  0.413847
#  16        100% Duration          Traditional Classifiers  0.986000
#  17        100% Duration                             LSTM  0.796948
#  18        100% Duration  Traditional Classifiers - SMOTE  0.984000
#  19         10% Duration                Best Static Model  0.810000
#  20         10% Duration        Best Static Model - SMOTE  0.743000
#  21         25% Duration                Best Static Model  0.807000
#  22         25% Duration        Best Static Model - SMOTE  0.746000
#  23         33% Duration                Best Static Model  0.809000
#  24         33% Duration        Best Static Model - SMOTE  0.760000
#  25         50% Duration                Best Static Model  0.810000
#  26         50% Duration        Best Static Model - SMOTE  0.761000
#  27        100% Duration                Best Static Model  0.829000
#  28        100% Duration        Best Static Model - SMOTE  0.801000
#  29        100% Duration                     LSTM - SMOTE  0.518274
#
#      Accuracy (sd)  Precision  Precision (sd)    Recall  Recall (sd)     AUROC  \
#  0        0.018000   0.779000        0.100000  0.063000     0.019000  0.707000
#  1        0.001703   0.144588        0.268324  0.003165     0.006379  0.539315
#  2        0.015000   0.409000        0.055000  0.412000     0.067000  0.704000
#  3        0.148411   0.210520        0.017530  0.627546     0.216075  0.526133
#  4        0.017000   0.740000        0.046000  0.268000     0.026000  0.797000
#  5        0.002627   0.382257        0.244017  0.015993     0.017025  0.553078
#  6        0.017000   0.534000        0.029000  0.544000     0.036000  0.795000
#  7        0.078981   0.201541        0.009199  0.754150     0.113154  0.513987
#  8        0.016000   0.741000        0.040000  0.360000     0.030000  0.832000
#  9        0.004907   0.307931        0.202942  0.035856     0.037506  0.583884
#  10       0.016000   0.544000        0.027000  0.614000     0.035000  0.828000
#  11       0.091609   0.209365        0.015335  0.628479     0.124602  0.527728
#  12       0.012000   0.726000        0.032000  0.519000     0.034000  0.883000
#  13       0.001092   0.151209        0.280583  0.002030     0.004329  0.509139
#  14       0.011000   0.700000        0.016000  0.792000     0.020000  0.874000
#  15       0.074214   0.202101        0.010849  0.658828     0.112343  0.511987
#  16       0.003000   0.961000        0.012000  0.968000     0.011000  0.994000
#  17       0.005691   0.419762        0.127399  0.069708     0.029494  0.561967
#  18       0.003000   0.949000        0.014000  0.972000     0.010000  0.994000
#  19            NaN   0.779000             NaN  0.063000          NaN  0.707000
#  20            NaN   0.379000             NaN  0.393000          NaN  0.682000
#  21            NaN   0.812000             NaN  0.034000          NaN  0.710000
#  22            NaN   0.384000             NaN  0.455000          NaN  0.699000
#  23            NaN   0.835000             NaN  0.051000          NaN  0.733000
#  24            NaN   0.413000             NaN  0.474000          NaN  0.717000
#  25            NaN   0.805000             NaN  0.060000          NaN  0.754000
#  26            NaN   0.431000             NaN  0.520000          NaN  0.744000
#  27            NaN   0.806000             NaN  0.181000          NaN  0.806000
#  28            NaN   0.499000             NaN  0.570000          NaN  0.804000
#  29       0.129904   0.223538        0.023130  0.544984     0.180286  0.542799
#
#      AUROC (sd) Unnamed: 10
#  0     0.018000          RF
#  1     0.020480         NaN
#  2     0.018000          RF
#  3     0.022745         NaN
#  4     0.017000          RF
#  5     0.022491         NaN
#  6     0.017000          RF
#  7     0.027037         NaN
#  8     0.016000          RF
#  9     0.026577         NaN
#  10    0.016000          RF
#  11    0.030972         NaN
#  12    0.012000      GBoost
#  13    0.023608         NaN
#  14    0.011000      GBoost
#  15    0.027351         NaN
#  16    0.003000      GBoost
#  17    0.022311         NaN
#  18    0.003000          RF
#  19         NaN          RF
#  20         NaN          RF
#  21         NaN          RF
#  22         NaN          RF
#  23         NaN          RF
#  24         NaN          RF
#  25         NaN          RF
#  26         NaN          RF
#  27         NaN          RF
#  28         NaN          RF
#  29    0.027657         NaN  }

# %% [markdown]
# #### Figure 1: Evolution of Published Works in EDM and LA

# %%
# setting up for figure
# x_axis = historico['Year'] 
# LA = historico['Learning Analytics']
# EDM = historico['Educational Data Mining']

# fig = go.Figure()

# fig.add_trace(
#     go.Bar(
#         x= x_axis,
#         y= LA,
#         name='<b>Learning Analytics</b>',
#         marker_color='rgb(92, 102, 108)'
#         )
#     )

# fig.add_trace(
#     go.Bar(
#         x=x_axis,
#         y=EDM,
#         name='<b>Educational Data Mining</b>',
#         marker_color='rgb(191, 215, 47)'
#         )
#     )

# fig.update_layout(
#     font=dict(
#         family="Calibri, serif",
#         color = 'black'),
#     xaxis_tickfont_size=14,
#     xaxis_title = '<b>Year</b>',
#     yaxis=dict(
#         title='<b>Number of Research Papers</b>',
#         titlefont_size=16,
#         tickfont_size=14,
#     ),
#     legend=dict(
#         x=0,
#         y=1.0,
#         bgcolor='rgba(0, 0, 0, 0)',
#         bordercolor='rgba(255, 255, 255, 0)'
#     ),
#     barmode='group',
#     bargroupgap=0.1 # gap between bars of the same location coordinate.
# )

# fig.show()

# fig.write_image("../Images/figure_1.png", )            
# fig.show()

# %%
#set seaborn plotting aesthetics
#settub
sns.set_theme(context='paper', font='Times New Roman', rc={"figure.figsize":(16, 10)}, font_scale=2)

ax = historico.plot(kind = 'bar', x = 'Year', color=['#BFD72F', '#5C666C'], )

ax.set(ylabel = 'Number of Papers',
      xlabel = 'Year')

# adding text annotations
#plt.text(8, 500, "1st EDM\nConference", horizontalalignment='center', size='medium', color='#BFD72F', weight='bold')
#plt.text(11, 900, "1st LA\nConference", horizontalalignment='center', size='medium', color='#5C666C', weight='bold')
ax.legend(loc='upper left')

#plt.savefig("../Images/figure_1_tnr.png", dpi=300)

# %% [markdown]
# The following cell results include results in our different performance metrics

# %%
#editing

resultados['At risk students']['State'] = 'Students at risk'
resultados['High performing students']['State'] = 'High performing students'

IMS_results = pd.concat([resultados['At risk students'], resultados['High performing students']])

# %%
test = IMS_results.melt(id_vars = ['Moment of prediction', 'Model', 'State'], value_vars=['AUROC', 'Accuracy',  
                                                                                                   'Recall', 'Precision'],
                                                                                           var_name = 'Performance Metric',
                                                                                           value_name = 'Value')

test = test[(test['Moment of prediction'] != '100% Duration') & (test['Model'].isin(['Best Static Model',
                                                                                    'Best Static Model - SMOTE',
                                                                                    'LSTM',
                                                                                    'LSTM - SMOTE']))]

test['Performance Metric'] = test['Performance Metric'].str.replace('AUROC', 'AUC')

# %%
test = test.sort_values(["Moment of prediction", "Model"])

# %%
colors = ["#bfd72f", "#5C666C", "#335000", '#000c12']

# %%
#set seaborn plotting aesthetics
sns.set_theme(context='paper', font='Times New Roman', rc={"figure.figsize":(24, 16)}, font_scale=5.5)


g = sns.FacetGrid(test, col= 'State', row = 'Performance Metric', hue="Model", 
                margin_titles=True, height=5, 
                 aspect= 2.5, ylim = (-0.1,1.05), despine = False, legend_out=True)
                  
g.map(sns.lineplot, 'Moment of prediction', 'Value', linewidth = 3,
     marker = 'o', markersize=15).add_legend()                  
g.set_axis_labels("Moment of Prediction", '')
g.set_titles(col_template="{col_name}", row_template="{row_name}")

g.set(yticks=[0, 0.2, 0.4, 0.6, 0.8, 1])
g.tight_layout()

#plt.savefig("../Images/Model_Performances_IMS_paper.png", dpi=300)
# Out:
# C:\Users\Kisshin\Conda\anaconda3\envs\deep_torch\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations
#   self._figure.tight_layout(*args, **kwargs)

# %%
g = sns.relplot(x = 'Moment of prediction', y = 'Value', data=test,
               col='State', row='Performance Metric',
                kind="line", style="Model",
                alpha = 0.90,
                dashes=False,
                hue_order = ['Best Static Model',
                            'Best Static Model - SMOTE',
                           'LSTM',
                           'LSTM - SMOTE'],
                markers=[ "P", "X", "^", "v"],
                markersize=55, linewidth = 2,
               height=7.5, aspect= 2.5,
                markeredgecolor="white",
                markeredgewidth=2,
                facet_kws={"margin_titles": True,
                           'sharey' : False},
               color = 'black',)

g.set_axis_labels("Moment of Prediction", '')
g.set_titles(col_template="{col_name}", row_template="{row_name}")

g.set(ylim = (-0.1, 1.1), yticks=[0, 0.2, 0.4, 0.6, 0.8, 1])
g.tight_layout()

#commenting to avoid overwrite
plt.savefig("../Images/Model_Performances_IMS_symbols_paper_no_assign.png", dpi=300)

# %% [markdown]
# ### Doing the same for the González work:

# %%
#editing

resultados['At-risk - R_Gonz']['State'] = 'At-risk'
resultados['High performing - R_Gonz']['State'] = 'High performing students'

R_G_results = pd.concat([resultados['At-risk - R_Gonz'], resultados['High performing - R_Gonz']])

# %%
new_test = R_G_results.melt(id_vars = ['Moment of prediction', 'Model', 'State'], value_vars=['AUROC', 'Accuracy',  
                                                                                                   'Recall', 'Precision'],
                                                                                           var_name = 'Performance Metric',
                                                                                           value_name = 'Value')

new_test = new_test[(new_test['Moment of prediction'] != '100% Duration') & (new_test['Model'].isin(['Best Static Model',
                                                                                    'Best Static Model - SMOTE',
                                                                                    'LSTM',
                                                                                    'LSTM - SMOTE']))]


new_test['Performance Metric'] = new_test['Performance Metric'].str.replace('AUROC', 'AUC')

# %%
new_test = new_test.sort_values(["Moment of prediction", "Model"])

# %%
#set seaborn plotting aesthetics
sns.set_theme(context='paper', font='Times New Roman', rc={"figure.figsize":(24, 16)}, font_scale=5.5)


g = sns.FacetGrid(new_test, col= 'State', row = 'Performance Metric', hue="Model", 
                margin_titles=True, height=5, 
                 aspect= 2.5, ylim = (-0.05,1.05), despine = False, legend_out=True)
                  
g.map(sns.lineplot, 'Moment of prediction', 'Value', linewidth = 3,
     marker = 'o', markersize=20).add_legend()                  
g.set_axis_labels("Moment of Prediction", '')
g.set_titles(col_template="{col_name}", row_template="{row_name}")

g.set(yticks=[0, 0.2, 0.4, 0.6, 0.8, 1])
g.tight_layout()

#plt.savefig("../Images/Model_Performances_R_G_paper.png", dpi=300)
# Out:
# C:\Users\Kisshin\Conda\anaconda3\envs\deep_torch\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations
#   self._figure.tight_layout(*args, **kwargs)

# %%
g = sns.relplot(x = 'Moment of prediction', y = 'Value', data=new_test,
               col='State', row='Performance Metric',
                kind="line", style="Model",
                alpha = 0.90,
                dashes=False,
                hue_order = ['Best Static Model',
                            'Best Static Model - SMOTE',
                           'LSTM',
                           'LSTM - SMOTE'],
                markers=[ "P", "X", "^", "v"],
                markersize=55, linewidth = 2,
               height=7.5, aspect= 2.5,
                markeredgecolor="white",
                markeredgewidth=2,
                facet_kws={"margin_titles": True,
                           'sharey' : False},
               color = 'black',)

g.set_axis_labels("Moment of Prediction", '')
g.set_titles(col_template="{col_name}", row_template="{row_name}")

g.set(ylim = (-0.1, 1.1), yticks=[0, 0.2, 0.4, 0.6, 0.8, 1])
g.tight_layout()

#commenting to avoid overwrite
plt.savefig("../Images/Model_Performances_R_G_symbols_paper_no_assign.png", dpi=300)

# %% [markdown]
# ### Part 2
#
# Descriptive statistics per course:
#
# 1. need to import the original df with the course encoding and the remaining info
# 2. need to import the actual 50% dataset to obtain the descriptive statistics for each feature

# %%
#imports dataframes with 50% logs
dataset_50 = pd.read_excel("../Data/Modeling Stage/Nova_IMS_Non_temporal_datasets.xlsx", 
                                dtype = {
                                    'course_encoding' : int,
                                    'userid' : int},
                               sheet_name = 'Date_threshold_50')

#save tables 
student_list = pd.read_csv('../Data/Modeling Stage/Nova_IMS_Filtered_targets.csv', 
                         dtype = {
                                   'course_encoding': int,
                                   'userid' : int,
                                   })

#obtain original dataset and merge accordingly
original_targets = pd.read_csv('../Data/Modeling Stage/Nova_IMS_targets_table.csv').drop(['Unnamed: 0', 
                                                                                          'exam_mark', 'final_mark', 'ds_discip_pt'], axis = 1)

#import support table to deal with remaining issues related with temporal features
class_list = pd.read_csv('../Data/Modeling Stage/Nova_IMS_updated_classlist.csv', parse_dates = True)
class_list['Days_up_to_50'] = (pd.to_datetime(class_list['Date_threshold_50']) - pd.to_datetime(class_list['Week before start'])).dt.days

#creat dict to correct dates
class_durations = pd.Series(class_list['Days_up_to_50'].values, index= class_list['course_encoding']).to_dict()

#drop unnamed 0 column
#merge with the targets we calculated on the other 
dataset_50 = dataset_50.merge(student_list, on = ['course_encoding', 'userid'], how = 'inner')
dataset_50.drop(['Unnamed: 0', 'exam_mark', 'final_mark'], axis = 1, inplace = True)    
    
#merge with original dataset
dataset_50 = pd.merge(dataset_50, original_targets, on = ['cd_curso', 'semestre', 'courseid', 'userid'])

#convert results to object and need to convert column names to string
dataset_50['course_encoding'], dataset_50['userid'] = dataset_50['course_encoding'].astype(object), dataset_50['userid'].astype(object)
dataset_50['Level'] = dataset_50['nm_curso_pt'].apply(lambda x: x.split(' ')[0])

#Fill nas on following columns
dataset_50['Number of clicks'] = dataset_50['Number of clicks'].fillna(0)
dataset_50['Number of sessions'] = dataset_50['Number of sessions'].fillna(0)
dataset_50['Total time online (min)'] = dataset_50['Total time online (min)'].fillna(0)
dataset_50['Clicks per day'] = dataset_50['Clicks per day'].fillna(0)
dataset_50['Days with no interaction (%)'] = dataset_50['Days with no interaction (%)'].fillna(100) 
dataset_50['Clicks (% of course total)'] = dataset_50['Clicks (% of course total)'].fillna(0)

#largest period of inactivity
dataset_50['Largest period of inactivity (h)'] = np.where(dataset_50['Largest period of inactivity (h)'].isna(), 
                                                       dataset_50['course_encoding'].map(class_durations) * 24,
                                                       dataset_50['Largest period of inactivity (h)'])

#number of days without clicking
dataset_50['Days with no interaction'] = np.where(dataset_50['Days with no interaction'].isna(), 
                                                       dataset_50['course_encoding'].map(class_durations),
                                                       dataset_50['Days with no interaction'])

# %% [markdown]
# Using a groupby per program level to obtain the most relevant descriptive statistics.

# %%
dataset_50.groupby(['Level', 'exam_fail']).agg({
                                'course_encoding' : 'nunique',
                                'nm_curso_pt' : 'nunique',
                                 'userid' : ['nunique', 'count'],
                                })
# Out:
#                         course_encoding nm_curso_pt  userid
#                                 nunique     nunique nunique count
# Level         exam_fail
# Licenciatura  0                      55           2     362  2469
#               1                      55           2     286   918
# Mestrado      0                      62           6     786  4180
#               1                      62           6     437   833
# Pós-Graduação 0                      21           6     304   775
#               1                      21           6      82   121

# %%
dataset_50.describe().T
# Out:
#                                    count           mean           std  \
# cd_curso                          9296.0    7891.340146   2036.308851
# courseid                          9296.0  180822.354346  81881.938686
# Number of clicks                  9296.0     129.635219     97.983796
# Number of sessions                9296.0      31.418029     22.310633
# Largest period of inactivity (h)  9296.0     277.876470    180.521260
# Total time online (min)           9296.0     238.704066    210.499035
# Average session duration (min)    9266.0       7.422052      4.203705
# Start of Session 1 (%)            9266.0       2.509766      7.739658
# Start of Session 2 (%)            9226.0       4.889705      8.103853
# Start of Session 3 (%)            9181.0       6.864748      8.667187
# Start of Session 4 (%)            9118.0       8.741778      9.260873
# Start of Session 5 (%)            9052.0      10.538571      9.775849
# Start of Session 6 (%)            8988.0      12.409388     10.423789
# Start of Session 7 (%)            8888.0      14.092230     10.822305
# Start of Session 8 (%)            8778.0      15.723017     11.285994
# Start of Session 9 (%)            8662.0      17.294057     11.653474
# Start of Session 10 (%)           8522.0      18.793641     11.975450
# Days with no interaction          9296.0      48.395977     15.248472
# Clicks on forum                   6055.0      10.216846     14.052584
# Links viewed                      6436.0      14.743785     10.756719
# Clicks on folder                  4991.0      12.961330     14.525436
# Clicks on course                  9265.0      60.161144     45.858994
# Resources viewed                  8530.0      27.998242     25.239337
# Discussions viewed                4001.0       6.769808      8.360368
# Quizzes started                   1420.0       2.242254      2.997846
# Files downloaded                  2028.0       3.744576      3.566943
# Assignments submitted             1315.0       4.749049      4.901401
# Assignments viewed                2214.0      10.314815     16.312188
# Forum posts                        171.0       1.824561      1.036785
# Number of days                    9266.0      73.144831     15.890348
# Clicks per day                    9296.0       1.821583      1.410180
# Clicks per session                9266.0       4.263029      1.984076
# Clicks (% of course total)        9296.0       1.484509      1.309439
# Submissions (% of course total)   1315.0       3.269962      4.993513
# Days with no interaction (%)      9296.0      65.948230     14.399179
# Average grade of assignments      2485.0      14.229667      4.318038
# exam_fail                         9296.0       0.201377      0.401051
# exam_gifted                       9296.0       0.276893      0.447487
#
#                                             min            25%            50%  \
# cd_curso                             859.000000    7512.000000    9155.000000
# courseid                          100001.000000  100073.000000  200101.000000
# Number of clicks                       0.000000      65.000000     109.000000
# Number of sessions                     0.000000      17.000000      27.000000
# Largest period of inactivity (h)       0.000000     167.316667     239.950000
# Total time online (min)                0.000000      93.000000     191.000000
# Average session duration (min)         0.000000       4.571429       6.918904
# Start of Session 1 (%)               -11.666667      -1.666667       0.000000
# Start of Session 2 (%)               -11.666667       0.000000       2.189781
# Start of Session 3 (%)               -10.000000       0.729927       5.000000
# Start of Session 4 (%)               -10.000000       2.189781       6.172840
# Start of Session 5 (%)               -10.000000       3.333333       7.407407
# Start of Session 6 (%)                -8.333333       5.109489      10.218978
# Start of Session 7 (%)                -6.666667       5.839416      11.666667
# Start of Session 8 (%)                -6.666667       7.299270      13.138686
# Start of Session 9 (%)                -6.666667       8.029197      15.328467
# Start of Session 10 (%)               -6.666667      10.218978      16.058394
# Days with no interaction               1.000000      37.000000      52.000000
# Clicks on forum                        1.000000       2.000000       5.000000
# Links viewed                           1.000000       7.000000      13.000000
# Clicks on folder                       1.000000       3.000000       8.000000
# Clicks on course                       1.000000      31.000000      50.000000
# Resources viewed                       1.000000      11.000000      21.000000
# Discussions viewed                     1.000000       1.000000       4.000000
# Quizzes started                        1.000000       1.000000       1.000000
# Files downloaded                       1.000000       1.000000       3.000000
# Assignments submitted                  1.000000       2.000000       2.000000
# Assignments viewed                     1.000000       1.000000       4.000000
# Forum posts                            1.000000       1.000000       2.000000
# Number of days                        39.000000      81.000000      81.000000
# Clicks per day                         0.000000       0.938272       1.529583
# Clicks per session                     1.000000       3.135442       3.921311
# Clicks (% of course total)             0.000000       0.670928       1.114279
# Submissions (% of course total)        0.105708       1.000000       1.883830
# Days with no interaction (%)           1.234568      58.024691      67.901235
# Average grade of assignments           0.000000      11.880000      15.343333
# exam_fail                              0.000000       0.000000       0.000000
# exam_gifted                            0.000000       0.000000       0.000000
#
#                                             75%            max
# cd_curso                            9434.000000    9435.000000
# courseid                          200193.000000  400131.000000
# Number of clicks                     169.000000    1546.000000
# Number of sessions                    40.000000     307.000000
# Largest period of inactivity (h)     335.737500    1944.000000
# Total time online (min)              324.000000    3917.000000
# Average session duration (min)         9.666667      69.000000
# Start of Session 1 (%)                 5.109489      53.284672
# Start of Session 2 (%)                 7.299270      53.284672
# Start of Session 3 (%)                10.218978      54.320988
# Start of Session 4 (%)                12.408759      54.320988
# Start of Session 5 (%)                15.328467      55.555556
# Start of Session 6 (%)                17.518248      53.284672
# Start of Session 7 (%)                20.437956      55.555556
# Start of Session 8 (%)                21.897810      55.555556
# Start of Session 9 (%)                23.357664      55.555556
# Start of Session 10 (%)               26.277372      55.555556
# Days with no interaction              60.000000      81.000000
# Clicks on forum                       13.000000     269.000000
# Links viewed                          20.000000      89.000000
# Clicks on folder                      17.000000     202.000000
# Clicks on course                      78.000000     665.000000
# Resources viewed                      38.000000     483.000000
# Discussions viewed                     9.000000     167.000000
# Quizzes started                        3.000000      43.000000
# Files downloaded                       5.000000      49.000000
# Assignments submitted                  4.000000      30.000000
# Assignments viewed                    10.000000     147.000000
# Forum posts                            2.000000       7.000000
# Number of days                        81.000000      81.000000
# Clicks per day                         2.333333      28.743590
# Clicks per session                     4.923077      49.000000
# Clicks (% of course total)             1.863371      28.623188
# Submissions (% of course total)        4.545455     100.000000
# Days with no interaction (%)          76.543210     100.000000
# Average grade of assignments          17.435000      20.000000
# exam_fail                              0.000000       1.000000
# exam_gifted                            1.000000       1.000000

# %%
len(student_list['userid'].unique())
# Out:
# 1590

# %% [markdown]
# ### Repeat for the 100 duration for END
#
# Obtaion descriptive statistics for both classification problems (i.e. The number of students that are excelling)

# %%
#imports dataframes with 50% logs
dataset_100 = pd.read_excel("../Data/Modeling Stage/Nova_IMS_Non_temporal_datasets.xlsx", 
                                dtype = {
                                    'course_encoding' : int,
                                    'userid' : int},
                               sheet_name = 'Date_threshold_100')

#save tables 
student_list = pd.read_csv('../Data/Modeling Stage/Nova_IMS_Filtered_targets.csv', 
                         dtype = {
                                   'course_encoding': int,
                                   'userid' : int,
                                   })

#obtain original dataset and merge accordingly
original_targets = pd.read_csv('../Data/Modeling Stage/Nova_IMS_targets_table.csv').drop(['Unnamed: 0', 
                                                                                          'exam_mark', 'final_mark', 'ds_discip_pt'], axis = 1)

#import support table to deal with remaining issues related with temporal features
class_list = pd.read_csv('../Data/Modeling Stage/Nova_IMS_updated_classlist.csv', parse_dates = True)
class_list['Days_up_to_100'] = (pd.to_datetime(class_list['Date_threshold_100']) - pd.to_datetime(class_list['Week before start'])).dt.days

#creat dict to correct dates
class_durations = pd.Series(class_list['Days_up_to_100'].values, index= class_list['course_encoding']).to_dict()

#drop unnamed 0 column
#merge with the targets we calculated on the other 
dataset_100 = dataset_100.merge(student_list, on = ['course_encoding', 'userid'], how = 'inner')
dataset_100.drop(['Unnamed: 0', 'exam_mark', 'final_mark'], axis = 1, inplace = True)    
    
#merge with original dataset
dataset_100 = pd.merge(dataset_100, original_targets, on = ['cd_curso', 'semestre', 'courseid', 'userid'])

#convert results to object and need to convert column names to string
dataset_100['course_encoding'], dataset_100['userid'] = dataset_100['course_encoding'].astype(object), dataset_100['userid'].astype(object)
dataset_100['Level'] = dataset_100['nm_curso_pt'].apply(lambda x: x.split(' ')[0])

#Fill nas on following columns
dataset_100['Number of clicks'] = dataset_100['Number of clicks'].fillna(0)
dataset_100['Number of sessions'] = dataset_100['Number of sessions'].fillna(0)
dataset_100['Total time online (min)'] = dataset_100['Total time online (min)'].fillna(0)
dataset_100['Clicks per day'] = dataset_100['Clicks per day'].fillna(0)
dataset_100['Days with no interaction (%)'] = dataset_100['Days with no interaction (%)'].fillna(100) 
dataset_100['Clicks (% of course total)'] = dataset_100['Clicks (% of course total)'].fillna(0)

#largest period of inactivity
dataset_100['Largest period of inactivity (h)'] = np.where(dataset_100['Largest period of inactivity (h)'].isna(), 
                                                       dataset_100['course_encoding'].map(class_durations) * 24,
                                                       dataset_100['Largest period of inactivity (h)'])

#number of days without clicking
dataset_100['Days with no interaction'] = np.where(dataset_100['Days with no interaction'].isna(), 
                                                       dataset_100['course_encoding'].map(class_durations),
                                                       dataset_100['Days with no interaction'])

# %% [markdown]
# Obtain descriptive statistics for each problem.

# %%
dataset_100.groupby(['Level', 'exam_gifted']).agg({
                                'course_encoding' : 'nunique',
                                'nm_curso_pt' : 'nunique',
                                 'userid' : ['nunique', 'count'],
                                })
# Out:
#                           course_encoding nm_curso_pt  userid
#                                   nunique     nunique nunique count
# Level         exam_gifted
# Licenciatura  0                        55           2     406  2618
#               1                        55           2     302   769
# Mestrado      0                        62           6     834  3470
#               1                        62           6     623  1543
# Pós-Graduação 0                        21           6     301   634
#               1                        21           6     187   262

# %% [markdown]
# # Part 3
#
# Obtaining relevant figures to show results:
#
# Figure 1 - bar plot of the Performance Metrics for all Models.

# %%
#import results with SMOTE and only keep models of interest for conf paper
results_50 = pd.read_excel("../Data/Modeling Stage/Results/IMS/Non temporal models/simple_models_no_assign_results_Date_threshold_50_30_replicas_SMOTE.xlsx", 
                               sheet_name = 'exam_fail').drop(['Baseline - Majority Class', 'BNB', 'J48 DT', 'RF', 'AdaBoost', 'GBoost' ,'ExtraTree'], axis = 1)

#rename
results_50 = results_50.rename(columns = {
                                        'Unnamed: 0' : 'Metric',
                                        'NN' : 'MLP'
                                        })

# %% [markdown]
# We will need to apply some important transformations to the data (thanks CHATGPT)
#
# The first will be to separate means and standard deviations

# %%
# If the string does not contain the "+/-" symbol, return the mean value as the first element of the tuple and 0 as the second element
extract_values = lambda x: (float(x.split('+/-')[0]) if "+/-" in x else float(x),
                            float(x.split('+/-')[1]) if "+/-" in x else 0)

# Iterate over the columns of the DataFrame, excluding the first column
for col in results_50.columns[1:]:
    # Create new columns for the mean and standard deviation values
    mean_col = 'Mean ' + col
    std_dev_col = 'Std Dev ' + col
    
    # Apply the lambda function to the column and store the results in the new columns
    results_50[mean_col], results_50[std_dev_col] = zip(*results_50[col].apply(extract_values))
    
    #drop column
    results_50.drop(col, axis = 1, inplace = True)
    
#st column val accuracy and train accuracy with the standard deviations of AUC
train_auc = results_50.loc[9, results_50.columns.str.startswith('Std Dev')]
val_auc = results_50.loc[10, results_50.columns.str.startswith('Std Dev')]

#update row 0 and 1
results_50.loc[0, results_50.columns.str.startswith('Std Dev')] = train_auc
results_50.loc[1, results_50.columns.str.startswith('Std Dev')] = val_auc

# Melt the DataFrame, specifying the 'Metric' column as the index and all other columns
melted_df = results_50.melt(id_vars='Metric', value_vars= results_50.columns[1:],
                    var_name='Model', value_name='Value')

# Create a new column  two new columns in the melted DataFrame, 'Type' by extracting the first word from the '~Model' column
melted_df['Type'] = melted_df.apply(lambda x: x['Model'].split(' ')[0], axis=1)

# Remove the references to Mean and Std Dev in Variable column
melted_df['Model'] = melted_df['Model'].str.replace(r'(Mean|Std Dev)', '', regex=True)

# %%
#now setting rows to remove: we are only interested in the values for validation
melted_df = melted_df[melted_df['Metric'].str.contains('Validation')]

# And now, for plotting purposes, remove all references to work validation
melted_df['Metric'] = melted_df['Metric'].str.replace(r'(Validation| - )', '', regex=True)

# %%
#need to create a pivot before having this finally be ready
pivot_results = pd.pivot_table(data = melted_df, index=['Metric','Model'], columns = 'Type', values = 'Value').reset_index()

# %%
#set seaborn plotting aesthetics
sns.set_theme(context='paper', font='Arial', rc={"figure.figsize":(24, 16)}, font_scale=3.8)

AUC_plot = pivot_results[pivot_results['Metric'] == 'AUC'].reset_index(drop = True)

# Create the bar chart
sns.barplot(x="Model", y="Mean", data=AUC_plot, color='#21272b')

# Add the error bars to the chart
for i in range(len(AUC_plot)):
    plt.errorbar(i, AUC_plot.loc[i, "Mean"], yerr=AUC_plot.loc[i, "Std"], capsize=5, fmt='none', ecolor='black')

# Set the chart labels and title
plt.xlabel("Model")
plt.ylabel("Average AUC")

# Set the limits of the y-axis
plt.ylim(0, 1)

#commenting to avoid overwrite
plt.savefig("../Images/INTED_Avg_AUC.png", dpi=300)
